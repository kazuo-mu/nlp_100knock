# %% [markdown]
# # 第6章: 英語テキストの処理

# %% [markdown]
# ## 50. 文区切り

# %%
import re

fname = 'data/nlp.txt'

def nlp_lines():
    
    with open(fname) as lines:
        
        pattern = re.compile(r'''
            ( 
              
                ^
                .*?
                [\.|\;|\:|\?|\!]
            )
            \s
            (
                [A-Z].*
            )
        ''', re.MULTILINE  + re.VERBOSE + re.DOTALL)
    
        for line in lines:
        
            line = line.strip()
        
            while line:
                match = pattern.match(line)
                if match:
                
                    yield match.group(1)
                    line = match.group(2)
                
                else:
                    yield line
                    line = ''

# %%
for line in nlp_lines():
    print(line)
# Out:
# Natural language processing
# From Wikipedia, the free encyclopedia
# Natural language processing (NLP) is a field of computer science, artificial intelligence, and linguistics concerned with the interactions between computers and human (natural) languages.
# As such, NLP is related to the area of humani-computer interaction.
# Many challenges in NLP involve natural language understanding, that is, enabling computers to derive meaning from human or natural language input, and others involve natural language generation.
# History
# The history of NLP generally starts in the 1950s, although work can be found from earlier periods.
# In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence.
# The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.
# The authors claimed that within three or five years, machine translation would be a solved problem.
# However, real progress was much slower, and after the ALPAC report in 1966, which found that ten year long research had failed to fulfill the expectations, funding for machine translation was dramatically reduced.
# Little further research in machine translation was conducted until the late 1980s, when the first statistical machine translation systems were developed.
# Some notably successful NLP systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapist, written by Joseph Weizenbaum between 1964 to 1966.
# Using almost no information about human thought or emotion, ELIZA sometimes provided a startlingly human-like interaction.
# When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".
# During the 1970s many programmers began to write 'conceptual ontologies', which structured real-world information into computer-understandable data.
# Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).
# During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky.
# Up to the 1980s, most NLP systems were based on complex sets of hand-written rules.
# Starting in the late 1980s, however, there was a revolution in NLP with the introduction of machine learning algorithms for language processing.
# This was due to both the steady increase in computational power resulting from Moore's Law and the gradual lessening of the dominance of Chomskyan theories of linguistics (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.
# Some of the earliest-used machine learning algorithms, such as decision trees, produced systems of hard if-then rules similar to existing hand-written rules.
# However, Part of speech tagging introduced the use of Hidden Markov Models to NLP, and increasingly, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to the features making up the input data.
# The cache language models upon which many speech recognition systems now rely are examples of such statistical models.
# Such models are generally more robust when given unfamiliar input, especially input that contains errors (as is very common for real-world data), and produce more reliable results when integrated into a larger system comprising multiple subtasks.
# Many of the notable early successes occurred in the field of machine translation, due especially to work at IBM Research, where successively more complicated statistical models were developed.
# These systems were able to take advantage of existing multilingual textual corpora that had been produced by the Parliament of Canada and the European Union as a result of laws calling for the translation of all governmental proceedings into all official languages of the corresponding systems of government.
# However, most other systems depended on corpora specifically developed for the tasks implemented by these systems, which was (and often continues to be) a major limitation in the success of these systems.
# As a result, a great deal of research has gone into methods of more effectively learning from limited amounts of data.
# Recent research has increasingly focused on unsupervised and semi-supervised learning algorithms.
# Such algorithms are able to learn from data that has not been hand-annotated with the desired answers, or using a combination of annotated and non-annotated data.
# Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data.
# However, there is an enormous amount of non-annotated data available (including, among other things, the entire content of the World Wide Web), which can often make up for the inferior results.
# NLP using machine learning
# Modern NLP algorithms are based on machine learning, especially statistical machine learning.
# The paradigm of machine learning is different from that of most prior attempts at language processing.
# Prior implementations of language-processing tasks typically involved the direct hand coding of large sets of rules.
# The machine-learning paradigm calls instead for using general learning algorithms - often, although not always, grounded in statistical inference - to automatically learn such rules through the analysis of large corpora of typical real-world examples.
# A corpus (plural, "corpora") is a set of documents (or sometimes, individual sentences) that have been hand-annotated with the correct values to be learned.
# Many different classes of machine learning algorithms have been applied to NLP tasks.
# These algorithms take as input a large set of "features" that are generated from the input data.
# Some of the earliest-used algorithms, such as decision trees, produced systems of hard if-then rules similar to the systems of hand-written rules that were then common.
# Increasingly, however, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to each input feature.
# Such models have the advantage that they can express the relative certainty of many different possible answers rather than only one, producing more reliable results when such a model is included as a component of a larger system.
# Systems based on machine-learning algorithms have many advantages over hand-produced rules:
# The learning procedures used during machine learning automatically focus on the most common cases, whereas when writing rules by hand it is often not obvious at all where the effort should be directed.
# Automatic learning procedures can make use of statistical inference algorithms to produce models that are robust to unfamiliar input (e.g. containing words or structures that have not been seen before) and to erroneous input (e.g. with misspelled words or words accidentally omitted).
# Generally, handling such input gracefully with hand-written rules -- or more generally, creating systems of hand-written rules that make soft decisions -- extremely difficult, error-prone and time-consuming.
# Systems based on automatically learning the rules can be made more accurate simply by supplying more input data.
# However, systems based on hand-written rules can only be made more accurate by increasing the complexity of the rules, which is a much more difficult task.
# In particular, there is a limit to the complexity of systems based on hand-crafted rules, beyond which the systems become more and more unmanageable.
# However, creating more data to input to machine-learning systems simply requires a corresponding increase in the number of man-hours worked, generally without significant increases in the complexity of the annotation process.
# The subfield of NLP devoted to learning approaches is known as Natural Language Learning (NLL) and its conference CoNLL and peak body SIGNLL are sponsored by ACL, recognizing also their links with Computational Linguistics and Language Acquisition.
# When the aims of computational language learning research is to understand more about human language acquisition, or psycholinguistics, NLL overlaps into the related field of Computational Psycholinguistics.

# %% [markdown]
# ## 51. 単語の切り出し

# %%
def nlp_words():
    for line in nlp_lines():
        words = line.split(' ')
        
        for word in words:
            yield word
        yield ''

# %%
for word in nlp_words():
    print(word)
# Out:
# Natural
# language
# processing
#
# From
# Wikipedia,
# the
# free
# encyclopedia
#
# Natural
# language
# processing
# (NLP)
# is
# a
# field
# of
# computer
# science,
# artificial
# intelligence,
# and
# linguistics
# concerned
# with
# the
# interactions
# between
# computers
# and
# human
# (natural)
# languages.
#
# As
# such,
# NLP
# is
# related
# to
# the
# area
# of
# humani-computer
# interaction.
#
# Many
# challenges
# in
# NLP
# involve
# natural
# language
# understanding,
# that
# is,
# enabling
# computers
# to
# derive
# meaning
# from
# human
# or
# natural
# language
# input,
# and
# others
# involve
# natural
# language
# generation.
#
# History
#
# The
# history
# of
# NLP
# generally
# starts
# in
# the
# 1950s,
# although
# work
# can
# be
# found
# from
# earlier
# periods.
#
# In
# 1950,
# Alan
# Turing
# published
# an
# article
# titled
# "Computing
# Machinery
# and
# Intelligence"
# which
# proposed
# what
# is
# now
# called
# the
# Turing
# test
# as
# a
# criterion
# of
# intelligence.
#
# The
# Georgetown
# experiment
# in
# 1954
# involved
# fully
# automatic
# translation
# of
# more
# than
# sixty
# Russian
# sentences
# into
# English.
#
# The
# authors
# claimed
# that
# within
# three
# or
# five
# years,
# machine
# translation
# would
# be
# a
# solved
# problem.
#
# However,
# real
# progress
# was
# much
# slower,
# and
# after
# the
# ALPAC
# report
# in
# 1966,
# which
# found
# that
# ten
# year
# long
# research
# had
# failed
# to
# fulfill
# the
# expectations,
# funding
# for
# machine
# translation
# was
# dramatically
# reduced.
#
# Little
# further
# research
# in
# machine
# translation
# was
# conducted
# until
# the
# late
# 1980s,
# when
# the
# first
# statistical
# machine
# translation
# systems
# were
# developed.
#
# Some
# notably
# successful
# NLP
# systems
# developed
# in
# the
# 1960s
# were
# SHRDLU,
# a
# natural
# language
# system
# working
# in
# restricted
# "blocks
# worlds"
# with
# restricted
# vocabularies,
# and
# ELIZA,
# a
# simulation
# of
# a
# Rogerian
# psychotherapist,
# written
# by
# Joseph
# Weizenbaum
# between
# 1964
# to
# 1966.
#
# Using
# almost
# no
# information
# about
# human
# thought
# or
# emotion,
# ELIZA
# sometimes
# provided
# a
# startlingly
# human-like
# interaction.
#
# When
# the
# "patient"
# exceeded
# the
# very
# small
# knowledge
# base,
# ELIZA
# might
# provide
# a
# generic
# response,
# for
# example,
# responding
# to
# "My
# head
# hurts"
# with
# "Why
# do
# you
# say
# your
# head
# hurts?".
#
# During
# the
# 1970s
# many
# programmers
# began
# to
# write
# 'conceptual
# ontologies',
# which
# structured
# real-world
# information
# into
# computer-understandable
# data.
#
# Examples
# are
# MARGIE
# (Schank,
# 1975),
# SAM
# (Cullingford,
# 1978),
# PAM
# (Wilensky,
# 1978),
# TaleSpin
# (Meehan,
# 1976),
# QUALM
# (Lehnert,
# 1977),
# Politics
# (Carbonell,
# 1979),
# and
# Plot
# Units
# (Lehnert
# 1981).
#
# During
# this
# time,
# many
# chatterbots
# were
# written
# including
# PARRY,
# Racter,
# and
# Jabberwacky.
#
# Up
# to
# the
# 1980s,
# most
# NLP
# systems
# were
# based
# on
# complex
# sets
# of
# hand-written
# rules.
#
# Starting
# in
# the
# late
# 1980s,
# however,
# there
# was
# a
# revolution
# in
# NLP
# with
# the
# introduction
# of
# machine
# learning
# algorithms
# for
# language
# processing.
#
# This
# was
# due
# to
# both
# the
# steady
# increase
# in
# computational
# power
# resulting
# from
# Moore's
# Law
# and
# the
# gradual
# lessening
# of
# the
# dominance
# of
# Chomskyan
# theories
# of
# linguistics
# (e.g.
# transformational
# grammar),
# whose
# theoretical
# underpinnings
# discouraged
# the
# sort
# of
# corpus
# linguistics
# that
# underlies
# the
# machine-learning
# approach
# to
# language
# processing.
#
# Some
# of
# the
# earliest-used
# machine
# learning
# algorithms,
# such
# as
# decision
# trees,
# produced
# systems
# of
# hard
# if-then
# rules
# similar
# to
# existing
# hand-written
# rules.
#
# However,
# Part
# of
# speech
# tagging
# introduced
# the
# use
# of
# Hidden
# Markov
# Models
# to
# NLP,
# and
# increasingly,
# research
# has
# focused
# on
# statistical
# models,
# which
# make
# soft,
# probabilistic
# decisions
# based
# on
# attaching
# real-valued
# weights
# to
# the
# features
# making
# up
# the
# input
# data.
#
# The
# cache
# language
# models
# upon
# which
# many
# speech
# recognition
# systems
# now
# rely
# are
# examples
# of
# such
# statistical
# models.
#
# Such
# models
# are
# generally
# more
# robust
# when
# given
# unfamiliar
# input,
# especially
# input
# that
# contains
# errors
# (as
# is
# very
# common
# for
# real-world
# data),
# and
# produce
# more
# reliable
# results
# when
# integrated
# into
# a
# larger
# system
# comprising
# multiple
# subtasks.
#
# Many
# of
# the
# notable
# early
# successes
# occurred
# in
# the
# field
# of
# machine
# translation,
# due
# especially
# to
# work
# at
# IBM
# Research,
# where
# successively
# more
# complicated
# statistical
# models
# were
# developed.
#
# These
# systems
# were
# able
# to
# take
# advantage
# of
# existing
# multilingual
# textual
# corpora
# that
# had
# been
# produced
# by
# the
# Parliament
# of
# Canada
# and
# the
# European
# Union
# as
# a
# result
# of
# laws
# calling
# for
# the
# translation
# of
# all
# governmental
# proceedings
# into
# all
# official
# languages
# of
# the
# corresponding
# systems
# of
# government.
#
# However,
# most
# other
# systems
# depended
# on
# corpora
# specifically
# developed
# for
# the
# tasks
# implemented
# by
# these
# systems,
# which
# was
# (and
# often
# continues
# to
# be)
# a
# major
# limitation
# in
# the
# success
# of
# these
# systems.
#
# As
# a
# result,
# a
# great
# deal
# of
# research
# has
# gone
# into
# methods
# of
# more
# effectively
# learning
# from
# limited
# amounts
# of
# data.
#
# Recent
# research
# has
# increasingly
# focused
# on
# unsupervised
# and
# semi-supervised
# learning
# algorithms.
#
# Such
# algorithms
# are
# able
# to
# learn
# from
# data
# that
# has
# not
# been
# hand-annotated
# with
# the
# desired
# answers,
# or
# using
# a
# combination
# of
# annotated
# and
# non-annotated
# data.
#
# Generally,
# this
# task
# is
# much
# more
# difficult
# than
# supervised
# learning,
# and
# typically
# produces
# less
# accurate
# results
# for
# a
# given
# amount
# of
# input
# data.
#
# However,
# there
# is
# an
# enormous
# amount
# of
# non-annotated
# data
# available
# (including,
# among
# other
# things,
# the
# entire
# content
# of
# the
# World
# Wide
# Web),
# which
# can
# often
# make
# up
# for
# the
# inferior
# results.
#
# NLP
# using
# machine
# learning
#
# Modern
# NLP
# algorithms
# are
# based
# on
# machine
# learning,
# especially
# statistical
# machine
# learning.
#
# The
# paradigm
# of
# machine
# learning
# is
# different
# from
# that
# of
# most
# prior
# attempts
# at
# language
# processing.
#
# Prior
# implementations
# of
# language-processing
# tasks
# typically
# involved
# the
# direct
# hand
# coding
# of
# large
# sets
# of
# rules.
#
# The
# machine-learning
# paradigm
# calls
# instead
# for
# using
# general
# learning
# algorithms
# -
# often,
# although
# not
# always,
# grounded
# in
# statistical
# inference
# -
# to
# automatically
# learn
# such
# rules
# through
# the
# analysis
# of
# large
# corpora
# of
# typical
# real-world
# examples.
#
# A
# corpus
# (plural,
# "corpora")
# is
# a
# set
# of
# documents
# (or
# sometimes,
# individual
# sentences)
# that
# have
# been
# hand-annotated
# with
# the
# correct
# values
# to
# be
# learned.
#
# Many
# different
# classes
# of
# machine
# learning
# algorithms
# have
# been
# applied
# to
# NLP
# tasks.
#
# These
# algorithms
# take
# as
# input
# a
# large
# set
# of
# "features"
# that
# are
# generated
# from
# the
# input
# data.
#
# Some
# of
# the
# earliest-used
# algorithms,
# such
# as
# decision
# trees,
# produced
# systems
# of
# hard
# if-then
# rules
# similar
# to
# the
# systems
# of
# hand-written
# rules
# that
# were
# then
# common.
#
# Increasingly,
# however,
# research
# has
# focused
# on
# statistical
# models,
# which
# make
# soft,
# probabilistic
# decisions
# based
# on
# attaching
# real-valued
# weights
# to
# each
# input
# feature.
#
# Such
# models
# have
# the
# advantage
# that
# they
# can
# express
# the
# relative
# certainty
# of
# many
# different
# possible
# answers
# rather
# than
# only
# one,
# producing
# more
# reliable
# results
# when
# such
# a
# model
# is
# included
# as
# a
# component
# of
# a
# larger
# system.
#
# Systems
# based
# on
# machine-learning
# algorithms
# have
# many
# advantages
# over
# hand-produced
# rules:
#
# The
# learning
# procedures
# used
# during
# machine
# learning
# automatically
# focus
# on
# the
# most
# common
# cases,
# whereas
# when
# writing
# rules
# by
# hand
# it
# is
# often
# not
# obvious
# at
# all
# where
# the
# effort
# should
# be
# directed.
#
# Automatic
# learning
# procedures
# can
# make
# use
# of
# statistical
# inference
# algorithms
# to
# produce
# models
# that
# are
# robust
# to
# unfamiliar
# input
# (e.g.
# containing
# words
# or
# structures
# that
# have
# not
# been
# seen
# before)
# and
# to
# erroneous
# input
# (e.g.
# with
# misspelled
# words
# or
# words
# accidentally
# omitted).
#
# Generally,
# handling
# such
# input
# gracefully
# with
# hand-written
# rules
# --
# or
# more
# generally,
# creating
# systems
# of
# hand-written
# rules
# that
# make
# soft
# decisions
# --
# extremely
# difficult,
# error-prone
# and
# time-consuming.
#
# Systems
# based
# on
# automatically
# learning
# the
# rules
# can
# be
# made
# more
# accurate
# simply
# by
# supplying
# more
# input
# data.
#
# However,
# systems
# based
# on
# hand-written
# rules
# can
# only
# be
# made
# more
# accurate
# by
# increasing
# the
# complexity
# of
# the
# rules,
# which
# is
# a
# much
# more
# difficult
# task.
#
# In
# particular,
# there
# is
# a
# limit
# to
# the
# complexity
# of
# systems
# based
# on
# hand-crafted
# rules,
# beyond
# which
# the
# systems
# become
# more
# and
# more
# unmanageable.
#
# However,
# creating
# more
# data
# to
# input
# to
# machine-learning
# systems
# simply
# requires
# a
# corresponding
# increase
# in
# the
# number
# of
# man-hours
# worked,
# generally
# without
# significant
# increases
# in
# the
# complexity
# of
# the
# annotation
# process.
#
# The
# subfield
# of
# NLP
# devoted
# to
# learning
# approaches
# is
# known
# as
# Natural
# Language
# Learning
# (NLL)
# and
# its
# conference
# CoNLL
# and
# peak
# body
# SIGNLL
# are
# sponsored
# by
# ACL,
# recognizing
# also
# their
# links
# with
# Computational
# Linguistics
# and
# Language
# Acquisition.
#
# When
# the
# aims
# of
# computational
# language
# learning
# research
# is
# to
# understand
# more
# about
# human
# language
# acquisition,
# or
# psycholinguistics,
# NLL
# overlaps
# into
# the
# related
# field
# of
# Computational
# Psycholinguistics.

# %% [markdown]
# ## 52. ステミング

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

for word in nlp_words():
    word = word.strip(',.:;(){}[]')
    stem = stemmer.stem(word)
    print(('{}\t{}').format(word, stem))
# Out:
# Natural	natur
# language	languag
# processing	process
#
# From	from
# Wikipedia	wikipedia
# the	the
# free	free
# encyclopedia	encyclopedia
#
# Natural	natur
# language	languag
# processing	process
# NLP	nlp
# is	is
# a	a
# field	field
# of	of
# computer	comput
# science	scienc
# artificial	artifici
# intelligence	intellig
# and	and
# linguistics	linguist
# concerned	concern
# with	with
# the	the
# interactions	interact
# between	between
# computers	comput
# and	and
# human	human
# natural	natur
# languages	languag
#
# As	As
# such	such
# NLP	nlp
# is	is
# related	relat
# to	to
# the	the
# area	area
# of	of
# humani-computer	humani-comput
# interaction	interact
#
# Many	mani
# challenges	challeng
# in	in
# NLP	nlp
# involve	involv
# natural	natur
# language	languag
# understanding	understand
# that	that
# is	is
# enabling	enabl
# computers	comput
# to	to
# derive	deriv
# meaning	mean
# from	from
# human	human
# or	or
# natural	natur
# language	languag
# input	input
# and	and
# others	other
# involve	involv
# natural	natur
# language	languag
# generation	gener
#
# History	histori
#
# The	the
# history	histori
# of	of
# NLP	nlp
# generally	gener
# starts	start
# in	in
# the	the
# 1950s	1950
# although	although
# work	work
# can	can
# be	be
# found	found
# from	from
# earlier	earlier
# periods	period
#
# In	In
# 1950	1950
# Alan	alan
# Turing	ture
# published	publish
# an	an
# article	articl
# titled	titl
# "Computing	"comput
# Machinery	machineri
# and	and
# Intelligence"	intelligence"
# which	which
# proposed	propos
# what	what
# is	is
# now	now
# called	call
# the	the
# Turing	ture
# test	test
# as	as
# a	a
# criterion	criterion
# of	of
# intelligence	intellig
#
# The	the
# Georgetown	georgetown
# experiment	experi
# in	in
# 1954	1954
# involved	involv
# fully	fulli
# automatic	automat
# translation	translat
# of	of
# more	more
# than	than
# sixty	sixti
# Russian	russian
# sentences	sentenc
# into	into
# English	english
#
# The	the
# authors	author
# claimed	claim
# that	that
# within	within
# three	three
# or	or
# five	five
# years	year
# machine	machin
# translation	translat
# would	would
# be	be
# a	a
# solved	solv
# problem	problem
#
# However	howev
# real	real
# progress	progress
# was	wa
# much	much
# slower	slower
# and	and
# after	after
# the	the
# ALPAC	alpac
# report	report
# in	in
# 1966	1966
# which	which
# found	found
# that	that
# ten	ten
# year	year
# long	long
# research	research
# had	had
# failed	fail
# to	to
# fulfill	fulfil
# the	the
# expectations	expect
# funding	fund
# for	for
# machine	machin
# translation	translat
# was	wa
# dramatically	dramat
# reduced	reduc
#
# Little	littl
# further	further
# research	research
# in	in
# machine	machin
# translation	translat
# was	wa
# conducted	conduct
# until	until
# the	the
# late	late
# 1980s	1980
# when	when
# the	the
# first	first
# statistical	statist
# machine	machin
# translation	translat
# systems	system
# were	were
# developed	develop
#
# Some	some
# notably	notabl
# successful	success
# NLP	nlp
# systems	system
# developed	develop
# in	in
# the	the
# 1960s	1960
# were	were
# SHRDLU	shrdlu
# a	a
# natural	natur
# language	languag
# system	system
# working	work
# in	in
# restricted	restrict
# "blocks	"block
# worlds"	worlds"
# with	with
# restricted	restrict
# vocabularies	vocabulari
# and	and
# ELIZA	eliza
# a	a
# simulation	simul
# of	of
# a	a
# Rogerian	rogerian
# psychotherapist	psychotherapist
# written	written
# by	by
# Joseph	joseph
# Weizenbaum	weizenbaum
# between	between
# 1964	1964
# to	to
# 1966	1966
#
# Using	use
# almost	almost
# no	no
# information	inform
# about	about
# human	human
# thought	thought
# or	or
# emotion	emot
# ELIZA	eliza
# sometimes	sometim
# provided	provid
# a	a
# startlingly	startlingli
# human-like	human-lik
# interaction	interact
#
# When	when
# the	the
# "patient"	"patient"
# exceeded	exceed
# the	the
# very	veri
# small	small
# knowledge	knowledg
# base	base
# ELIZA	eliza
# might	might
# provide	provid
# a	a
# generic	gener
# response	respons
# for	for
# example	exampl
# responding	respond
# to	to
# "My	"mi
# head	head
# hurts"	hurts"
# with	with
# "Why	"whi
# do	do
# you	you
# say	say
# your	your
# head	head
# hurts?"	hurts?"
#
# During	dure
# the	the
# 1970s	1970
# many	mani
# programmers	programm
# began	began
# to	to
# write	write
# 'conceptual	'conceptu
# ontologies'	ontologies'
# which	which
# structured	structur
# real-world	real-world
# information	inform
# into	into
# computer-understandable	computer-understand
# data	data
#
# Examples	exampl
# are	are
# MARGIE	margi
# Schank	schank
# 1975	1975
# SAM	sam
# Cullingford	cullingford
# 1978	1978
# PAM	pam
# Wilensky	wilenski
# 1978	1978
# TaleSpin	talespin
# Meehan	meehan
# 1976	1976
# QUALM	qualm
# Lehnert	lehnert
# 1977	1977
# Politics	polit
# Carbonell	carbonel
# 1979	1979
# and	and
# Plot	plot
# Units	unit
# Lehnert	lehnert
# 1981	1981
#
# During	dure
# this	thi
# time	time
# many	mani
# chatterbots	chatterbot
# were	were
# written	written
# including	includ
# PARRY	parri
# Racter	racter
# and	and
# Jabberwacky	jabberwacki
#
# Up	Up
# to	to
# the	the
# 1980s	1980
# most	most
# NLP	nlp
# systems	system
# were	were
# based	base
# on	on
# complex	complex
# sets	set
# of	of
# hand-written	hand-written
# rules	rule
#
# Starting	start
# in	in
# the	the
# late	late
# 1980s	1980
# however	howev
# there	there
# was	wa
# a	a
# revolution	revolut
# in	in
# NLP	nlp
# with	with
# the	the
# introduction	introduct
# of	of
# machine	machin
# learning	learn
# algorithms	algorithm
# for	for
# language	languag
# processing	process
#
# This	thi
# was	wa
# due	due
# to	to
# both	both
# the	the
# steady	steadi
# increase	increas
# in	in
# computational	comput
# power	power
# resulting	result
# from	from
# Moore's	moore'
# Law	law
# and	and
# the	the
# gradual	gradual
# lessening	lessen
# of	of
# the	the
# dominance	domin
# of	of
# Chomskyan	chomskyan
# theories	theori
# of	of
# linguistics	linguist
# e.g	e.g
# transformational	transform
# grammar	grammar
# whose	whose
# theoretical	theoret
# underpinnings	underpin
# discouraged	discourag
# the	the
# sort	sort
# of	of
# corpus	corpu
# linguistics	linguist
# that	that
# underlies	underli
# the	the
# machine-learning	machine-learn
# approach	approach
# to	to
# language	languag
# processing	process
#
# Some	some
# of	of
# the	the
# earliest-used	earliest-us
# machine	machin
# learning	learn
# algorithms	algorithm
# such	such
# as	as
# decision	decis
# trees	tree
# produced	produc
# systems	system
# of	of
# hard	hard
# if-then	if-then
# rules	rule
# similar	similar
# to	to
# existing	exist
# hand-written	hand-written
# rules	rule
#
# However	howev
# Part	part
# of	of
# speech	speech
# tagging	tag
# introduced	introduc
# the	the
# use	use
# of	of
# Hidden	hidden
# Markov	markov
# Models	model
# to	to
# NLP	nlp
# and	and
# increasingly	increasingli
# research	research
# has	ha
# focused	focus
# on	on
# statistical	statist
# models	model
# which	which
# make	make
# soft	soft
# probabilistic	probabilist
# decisions	decis
# based	base
# on	on
# attaching	attach
# real-valued	real-valu
# weights	weight
# to	to
# the	the
# features	featur
# making	make
# up	up
# the	the
# input	input
# data	data
#
# The	the
# cache	cach
# language	languag
# models	model
# upon	upon
# which	which
# many	mani
# speech	speech
# recognition	recognit
# systems	system
# now	now
# rely	reli
# are	are
# examples	exampl
# of	of
# such	such
# statistical	statist
# models	model
#
# Such	such
# models	model
# are	are
# generally	gener
# more	more
# robust	robust
# when	when
# given	given
# unfamiliar	unfamiliar
# input	input
# especially	especi
# input	input
# that	that
# contains	contain
# errors	error
# as	as
# is	is
# very	veri
# common	common
# for	for
# real-world	real-world
# data	data
# and	and
# produce	produc
# more	more
# reliable	reliabl
# results	result
# when	when
# integrated	integr
# into	into
# a	a
# larger	larger
# system	system
# comprising	compris
# multiple	multipl
# subtasks	subtask
#
# Many	mani
# of	of
# the	the
# notable	notabl
# early	earli
# successes	success
# occurred	occur
# in	in
# the	the
# field	field
# of	of
# machine	machin
# translation	translat
# due	due
# especially	especi
# to	to
# work	work
# at	at
# IBM	ibm
# Research	research
# where	where
# successively	success
# more	more
# complicated	complic
# statistical	statist
# models	model
# were	were
# developed	develop
#
# These	these
# systems	system
# were	were
# able	abl
# to	to
# take	take
# advantage	advantag
# of	of
# existing	exist
# multilingual	multilingu
# textual	textual
# corpora	corpora
# that	that
# had	had
# been	been
# produced	produc
# by	by
# the	the
# Parliament	parliament
# of	of
# Canada	canada
# and	and
# the	the
# European	european
# Union	union
# as	as
# a	a
# result	result
# of	of
# laws	law
# calling	call
# for	for
# the	the
# translation	translat
# of	of
# all	all
# governmental	government
# proceedings	proceed
# into	into
# all	all
# official	offici
# languages	languag
# of	of
# the	the
# corresponding	correspond
# systems	system
# of	of
# government	govern
#
# However	howev
# most	most
# other	other
# systems	system
# depended	depend
# on	on
# corpora	corpora
# specifically	specif
# developed	develop
# for	for
# the	the
# tasks	task
# implemented	implement
# by	by
# these	these
# systems	system
# which	which
# was	wa
# and	and
# often	often
# continues	continu
# to	to
# be	be
# a	a
# major	major
# limitation	limit
# in	in
# the	the
# success	success
# of	of
# these	these
# systems	system
#
# As	As
# a	a
# result	result
# a	a
# great	great
# deal	deal
# of	of
# research	research
# has	ha
# gone	gone
# into	into
# methods	method
# of	of
# more	more
# effectively	effect
# learning	learn
# from	from
# limited	limit
# amounts	amount
# of	of
# data	data
#
# Recent	recent
# research	research
# has	ha
# increasingly	increasingli
# focused	focus
# on	on
# unsupervised	unsupervis
# and	and
# semi-supervised	semi-supervis
# learning	learn
# algorithms	algorithm
#
# Such	such
# algorithms	algorithm
# are	are
# able	abl
# to	to
# learn	learn
# from	from
# data	data
# that	that
# has	ha
# not	not
# been	been
# hand-annotated	hand-annot
# with	with
# the	the
# desired	desir
# answers	answer
# or	or
# using	use
# a	a
# combination	combin
# of	of
# annotated	annot
# and	and
# non-annotated	non-annot
# data	data
#
# Generally	gener
# this	thi
# task	task
# is	is
# much	much
# more	more
# difficult	difficult
# than	than
# supervised	supervis
# learning	learn
# and	and
# typically	typic
# produces	produc
# less	less
# accurate	accur
# results	result
# for	for
# a	a
# given	given
# amount	amount
# of	of
# input	input
# data	data
#
# However	howev
# there	there
# is	is
# an	an
# enormous	enorm
# amount	amount
# of	of
# non-annotated	non-annot
# data	data
# available	avail
# including	includ
# among	among
# other	other
# things	thing
# the	the
# entire	entir
# content	content
# of	of
# the	the
# World	world
# Wide	wide
# Web	web
# which	which
# can	can
# often	often
# make	make
# up	up
# for	for
# the	the
# inferior	inferior
# results	result
#
# NLP	nlp
# using	use
# machine	machin
# learning	learn
#
# Modern	modern
# NLP	nlp
# algorithms	algorithm
# are	are
# based	base
# on	on
# machine	machin
# learning	learn
# especially	especi
# statistical	statist
# machine	machin
# learning	learn
#
# The	the
# paradigm	paradigm
# of	of
# machine	machin
# learning	learn
# is	is
# different	differ
# from	from
# that	that
# of	of
# most	most
# prior	prior
# attempts	attempt
# at	at
# language	languag
# processing	process
#
# Prior	prior
# implementations	implement
# of	of
# language-processing	language-process
# tasks	task
# typically	typic
# involved	involv
# the	the
# direct	direct
# hand	hand
# coding	code
# of	of
# large	larg
# sets	set
# of	of
# rules	rule
#
# The	the
# machine-learning	machine-learn
# paradigm	paradigm
# calls	call
# instead	instead
# for	for
# using	use
# general	gener
# learning	learn
# algorithms	algorithm
# -	-
# often	often
# although	although
# not	not
# always	alway
# grounded	ground
# in	in
# statistical	statist
# inference	infer
# -	-
# to	to
# automatically	automat
# learn	learn
# such	such
# rules	rule
# through	through
# the	the
# analysis	analysi
# of	of
# large	larg
# corpora	corpora
# of	of
# typical	typic
# real-world	real-world
# examples	exampl
#
# A	A
# corpus	corpu
# plural	plural
# "corpora"	"corpora"
# is	is
# a	a
# set	set
# of	of
# documents	document
# or	or
# sometimes	sometim
# individual	individu
# sentences	sentenc
# that	that
# have	have
# been	been
# hand-annotated	hand-annot
# with	with
# the	the
# correct	correct
# values	valu
# to	to
# be	be
# learned	learn
#
# Many	mani
# different	differ
# classes	class
# of	of
# machine	machin
# learning	learn
# algorithms	algorithm
# have	have
# been	been
# applied	appli
# to	to
# NLP	nlp
# tasks	task
#
# These	these
# algorithms	algorithm
# take	take
# as	as
# input	input
# a	a
# large	larg
# set	set
# of	of
# "features"	"features"
# that	that
# are	are
# generated	gener
# from	from
# the	the
# input	input
# data	data
#
# Some	some
# of	of
# the	the
# earliest-used	earliest-us
# algorithms	algorithm
# such	such
# as	as
# decision	decis
# trees	tree
# produced	produc
# systems	system
# of	of
# hard	hard
# if-then	if-then
# rules	rule
# similar	similar
# to	to
# the	the
# systems	system
# of	of
# hand-written	hand-written
# rules	rule
# that	that
# were	were
# then	then
# common	common
#
# Increasingly	increasingli
# however	howev
# research	research
# has	ha
# focused	focus
# on	on
# statistical	statist
# models	model
# which	which
# make	make
# soft	soft
# probabilistic	probabilist
# decisions	decis
# based	base
# on	on
# attaching	attach
# real-valued	real-valu
# weights	weight
# to	to
# each	each
# input	input
# feature	featur
#
# Such	such
# models	model
# have	have
# the	the
# advantage	advantag
# that	that
# they	they
# can	can
# express	express
# the	the
# relative	rel
# certainty	certainti
# of	of
# many	mani
# different	differ
# possible	possibl
# answers	answer
# rather	rather
# than	than
# only	onli
# one	one
# producing	produc
# more	more
# reliable	reliabl
# results	result
# when	when
# such	such
# a	a
# model	model
# is	is
# included	includ
# as	as
# a	a
# component	compon
# of	of
# a	a
# larger	larger
# system	system
#
# Systems	system
# based	base
# on	on
# machine-learning	machine-learn
# algorithms	algorithm
# have	have
# many	mani
# advantages	advantag
# over	over
# hand-produced	hand-produc
# rules	rule
#
# The	the
# learning	learn
# procedures	procedur
# used	use
# during	dure
# machine	machin
# learning	learn
# automatically	automat
# focus	focu
# on	on
# the	the
# most	most
# common	common
# cases	case
# whereas	wherea
# when	when
# writing	write
# rules	rule
# by	by
# hand	hand
# it	it
# is	is
# often	often
# not	not
# obvious	obviou
# at	at
# all	all
# where	where
# the	the
# effort	effort
# should	should
# be	be
# directed	direct
#
# Automatic	automat
# learning	learn
# procedures	procedur
# can	can
# make	make
# use	use
# of	of
# statistical	statist
# inference	infer
# algorithms	algorithm
# to	to
# produce	produc
# models	model
# that	that
# are	are
# robust	robust
# to	to
# unfamiliar	unfamiliar
# input	input
# e.g	e.g
# containing	contain
# words	word
# or	or
# structures	structur
# that	that
# have	have
# not	not
# been	been
# seen	seen
# before	befor
# and	and
# to	to
# erroneous	erron
# input	input
# e.g	e.g
# with	with
# misspelled	misspel
# words	word
# or	or
# words	word
# accidentally	accident
# omitted	omit
#
# Generally	gener
# handling	handl
# such	such
# input	input
# gracefully	grace
# with	with
# hand-written	hand-written
# rules	rule
# --	--
# or	or
# more	more
# generally	gener
# creating	creat
# systems	system
# of	of
# hand-written	hand-written
# rules	rule
# that	that
# make	make
# soft	soft
# decisions	decis
# --	--
# extremely	extrem
# difficult	difficult
# error-prone	error-pron
# and	and
# time-consuming	time-consum
#
# Systems	system
# based	base
# on	on
# automatically	automat
# learning	learn
# the	the
# rules	rule
# can	can
# be	be
# made	made
# more	more
# accurate	accur
# simply	simpli
# by	by
# supplying	suppli
# more	more
# input	input
# data	data
#
# However	howev
# systems	system
# based	base
# on	on
# hand-written	hand-written
# rules	rule
# can	can
# only	onli
# be	be
# made	made
# more	more
# accurate	accur
# by	by
# increasing	increas
# the	the
# complexity	complex
# of	of
# the	the
# rules	rule
# which	which
# is	is
# a	a
# much	much
# more	more
# difficult	difficult
# task	task
#
# In	In
# particular	particular
# there	there
# is	is
# a	a
# limit	limit
# to	to
# the	the
# complexity	complex
# of	of
# systems	system
# based	base
# on	on
# hand-crafted	hand-craft
# rules	rule
# beyond	beyond
# which	which
# the	the
# systems	system
# become	becom
# more	more
# and	and
# more	more
# unmanageable	unmanag
#
# However	howev
# creating	creat
# more	more
# data	data
# to	to
# input	input
# to	to
# machine-learning	machine-learn
# systems	system
# simply	simpli
# requires	requir
# a	a
# corresponding	correspond
# increase	increas
# in	in
# the	the
# number	number
# of	of
# man-hours	man-hour
# worked	work
# generally	gener
# without	without
# significant	signific
# increases	increas
# in	in
# the	the
# complexity	complex
# of	of
# the	the
# annotation	annot
# process	process
#
# The	the
# subfield	subfield
# of	of
# NLP	nlp
# devoted	devot
# to	to
# learning	learn
# approaches	approach
# is	is
# known	known
# as	as
# Natural	natur
# Language	languag
# Learning	learn
# NLL	nll
# and	and
# its	it
# conference	confer
# CoNLL	conll
# and	and
# peak	peak
# body	bodi
# SIGNLL	signll
# are	are
# sponsored	sponsor
# by	by
# ACL	acl
# recognizing	recogn
# also	also
# their	their
# links	link
# with	with
# Computational	comput
# Linguistics	linguist
# and	and
# Language	languag
# Acquisition	acquisit
#
# When	when
# the	the
# aims	aim
# of	of
# computational	comput
# language	languag
# learning	learn
# research	research
# is	is
# to	to
# understand	understand
# more	more
# about	about
# human	human
# language	languag
# acquisition	acquisit
# or	or
# psycholinguistics	psycholinguist
# NLL	nll
# overlaps	overlap
# into	into
# the	the
# related	relat
# field	field
# of	of
# Computational	comput
# Psycholinguistics	psycholinguist

# %% [markdown]
# ## 53. Tokenization

# %%
from pycorenlp import StanfordCoreNLP

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
with open('data/nlp.txt', 'r') as file:
    text = file.read()

# %%
text
# Out:
# 'Natural language processing\nFrom Wikipedia, the free encyclopedia\n\nNatural language processing (NLP) is a field of computer science, artificial intelligence, and linguistics concerned with the interactions between computers and human (natural) languages. As such, NLP is related to the area of humani-computer interaction. Many challenges in NLP involve natural language understanding, that is, enabling computers to derive meaning from human or natural language input, and others involve natural language generation.\n\nHistory\n\nThe history of NLP generally starts in the 1950s, although work can be found from earlier periods. In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence.\n\nThe Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved problem. However, real progress was much slower, and after the ALPAC report in 1966, which found that ten year long research had failed to fulfill the expectations, funding for machine translation was dramatically reduced. Little further research in machine translation was conducted until the late 1980s, when the first statistical machine translation systems were developed.\n\nSome notably successful NLP systems developed in the 1960s were SHRDLU, a natural language system working in restricted "blocks worlds" with restricted vocabularies, and ELIZA, a simulation of a Rogerian psychotherapist, written by Joseph Weizenbaum between 1964 to 1966. Using almost no information about human thought or emotion, ELIZA sometimes provided a startlingly human-like interaction. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".\n\nDuring the 1970s many programmers began to write \'conceptual ontologies\', which structured real-world information into computer-understandable data. Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981). During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky.\n\nUp to the 1980s, most NLP systems were based on complex sets of hand-written rules. Starting in the late 1980s, however, there was a revolution in NLP with the introduction of machine learning algorithms for language processing. This was due to both the steady increase in computational power resulting from Moore\'s Law and the gradual lessening of the dominance of Chomskyan theories of linguistics (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing. Some of the earliest-used machine learning algorithms, such as decision trees, produced systems of hard if-then rules similar to existing hand-written rules. However, Part of speech tagging introduced the use of Hidden Markov Models to NLP, and increasingly, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to the features making up the input data. The cache language models upon which many speech recognition systems now rely are examples of such statistical models. Such models are generally more robust when given unfamiliar input, especially input that contains errors (as is very common for real-world data), and produce more reliable results when integrated into a larger system comprising multiple subtasks.\n\nMany of the notable early successes occurred in the field of machine translation, due especially to work at IBM Research, where successively more complicated statistical models were developed. These systems were a ...

# %%
output = nlp.annotate(text, properties={
    'annotators' : 'tokenize,ssplit,pos,depparse,parse,lemma,ner,dcoref',
    'outputFormat': 'xml'
})

# %%
import xml.etree.ElementTree as ET
root = ET.fromstring(output)

# %%
for word in root.iter('word'):
    print(word.text)
# Out:
# Natural
# language
# processing
# From
# Wikipedia
# ,
# the
# free
# encyclopedia
# Natural
# language
# processing
# -LRB-
# NLP
# -RRB-
# is
# a
# field
# of
# computer
# science
# ,
# artificial
# intelligence
# ,
# and
# linguistics
# concerned
# with
# the
# interactions
# between
# computers
# and
# human
# -LRB-
# natural
# -RRB-
# languages
# .
# As
# such
# ,
# NLP
# is
# related
# to
# the
# area
# of
# humani-computer
# interaction
# .
# Many
# challenges
# in
# NLP
# involve
# natural
# language
# understanding
# ,
# that
# is
# ,
# enabling
# computers
# to
# derive
# meaning
# from
# human
# or
# natural
# language
# input
# ,
# and
# others
# involve
# natural
# language
# generation
# .
# History
# The
# history
# of
# NLP
# generally
# starts
# in
# the
# 1950s
# ,
# although
# work
# can
# be
# found
# from
# earlier
# periods
# .
# In
# 1950
# ,
# Alan
# Turing
# published
# an
# article
# titled
# ``
# Computing
# Machinery
# and
# Intelligence
# ''
# which
# proposed
# what
# is
# now
# called
# the
# Turing
# test
# as
# a
# criterion
# of
# intelligence
# .
# The
# Georgetown
# experiment
# in
# 1954
# involved
# fully
# automatic
# translation
# of
# more
# than
# sixty
# Russian
# sentences
# into
# English
# .
# The
# authors
# claimed
# that
# within
# three
# or
# five
# years
# ,
# machine
# translation
# would
# be
# a
# solved
# problem
# .
# However
# ,
# real
# progress
# was
# much
# slower
# ,
# and
# after
# the
# ALPAC
# report
# in
# 1966
# ,
# which
# found
# that
# ten
# year
# long
# research
# had
# failed
# to
# fulfill
# the
# expectations
# ,
# funding
# for
# machine
# translation
# was
# dramatically
# reduced
# .
# Little
# further
# research
# in
# machine
# translation
# was
# conducted
# until
# the
# late
# 1980s
# ,
# when
# the
# first
# statistical
# machine
# translation
# systems
# were
# developed
# .
# Some
# notably
# successful
# NLP
# systems
# developed
# in
# the
# 1960s
# were
# SHRDLU
# ,
# a
# natural
# language
# system
# working
# in
# restricted
# ``
# blocks
# worlds
# ''
# with
# restricted
# vocabularies
# ,
# and
# ELIZA
# ,
# a
# simulation
# of
# a
# Rogerian
# psychotherapist
# ,
# written
# by
# Joseph
# Weizenbaum
# between
# 1964
# to
# 1966
# .
# Using
# almost
# no
# information
# about
# human
# thought
# or
# emotion
# ,
# ELIZA
# sometimes
# provided
# a
# startlingly
# human-like
# interaction
# .
# When
# the
# ``
# patient
# ''
# exceeded
# the
# very
# small
# knowledge
# base
# ,
# ELIZA
# might
# provide
# a
# generic
# response
# ,
# for
# example
# ,
# responding
# to
# ``
# My
# head
# hurts
# ''
# with
# ``
# Why
# do
# you
# say
# your
# head
# hurts
# ?
# ''
# .
# During
# the
# 1970s
# many
# programmers
# began
# to
# write
# `
# conceptual
# ontologies
# '
# ,
# which
# structured
# real-world
# information
# into
# computer-understandable
# data
# .
# Examples
# are
# MARGIE
# -LRB-
# Schank
# ,
# 1975
# -RRB-
# ,
# SAM
# -LRB-
# Cullingford
# ,
# 1978
# -RRB-
# ,
# PAM
# -LRB-
# Wilensky
# ,
# 1978
# -RRB-
# ,
# TaleSpin
# -LRB-
# Meehan
# ,
# 1976
# -RRB-
# ,
# QUALM
# -LRB-
# Lehnert
# ,
# 1977
# -RRB-
# ,
# Politics
# -LRB-
# Carbonell
# ,
# 1979
# -RRB-
# ,
# and
# Plot
# Units
# -LRB-
# Lehnert
# 1981
# -RRB-
# .
# During
# this
# time
# ,
# many
# chatterbots
# were
# written
# including
# PARRY
# ,
# Racter
# ,
# and
# Jabberwacky
# .
# Up
# to
# the
# 1980s
# ,
# most
# NLP
# systems
# were
# based
# on
# complex
# sets
# of
# hand-written
# rules
# .
# Starting
# in
# the
# late
# 1980s
# ,
# however
# ,
# there
# was
# a
# revolution
# in
# NLP
# with
# the
# introduction
# of
# machine
# learning
# algorithms
# for
# language
# processing
# .
# This
# was
# due
# to
# both
# the
# steady
# increase
# in
# computational
# power
# resulting
# from
# Moore
# 's
# Law
# and
# the
# gradual
# lessening
# of
# the
# dominance
# of
# Chomskyan
# theories
# of
# linguistics
# -LRB-
# e.g.
# transformational
# grammar
# -RRB-
# ,
# whose
# theoretical
# underpinnings
# discouraged
# the
# sort
# of
# corpus
# linguistics
# that
# underlies
# the
# machine-learning
# approach
# to
# language
# processing
# .
# Some
# of
# the
# earliest-used
# machine
# learning
# algorithms
# ,
# such
# as
# decision
# trees
# ,
# produced
# systems
# of
# hard
# if-then
# rules
# similar
# to
# existing
# hand-written
# rules
# .
# However
# ,
# Part
# of
# speech
# tagging
# introduced
# the
# use
# of
# Hidden
# Markov
# Models
# to
# NLP
# ,
# and
# increasingly
# ,
# research
# has
# focused
# on
# statistical
# models
# ,
# which
# make
# soft
# ,
# probabilistic
# decisions
# based
# on
# attaching
# real-valued
# weights
# to
# the
# features
# making
# up
# the
# input
# data
# .
# The
# cache
# language
# models
# upon
# which
# many
# speech
# recognition
# systems
# now
# rely
# are
# examples
# of
# such
# statistical
# models
# .
# Such
# models
# are
# generally
# more
# robust
# when
# given
# unfamiliar
# input
# ,
# especially
# input
# that
# contains
# errors
# -LRB-
# as
# is
# very
# common
# for
# real-world
# data
# -RRB-
# ,
# and
# produce
# more
# reliable
# results
# when
# integrated
# into
# a
# larger
# system
# comprising
# multiple
# subtasks
# .
# Many
# of
# the
# notable
# early
# successes
# occurred
# in
# the
# field
# of
# machine
# translation
# ,
# due
# especially
# to
# work
# at
# IBM
# Research
# ,
# where
# successively
# more
# complicated
# statistical
# models
# were
# developed
# .
# These
# systems
# were
# able
# to
# take
# advantage
# of
# existing
# multilingual
# textual
# corpora
# that
# had
# been
# produced
# by
# the
# Parliament
# of
# Canada
# and
# the
# European
# Union
# as
# a
# result
# of
# laws
# calling
# for
# the
# translation
# of
# all
# governmental
# proceedings
# into
# all
# official
# languages
# of
# the
# corresponding
# systems
# of
# government
# .
# However
# ,
# most
# other
# systems
# depended
# on
# corpora
# specifically
# developed
# for
# the
# tasks
# implemented
# by
# these
# systems
# ,
# which
# was
# -LRB-
# and
# often
# continues
# to
# be
# -RRB-
# a
# major
# limitation
# in
# the
# success
# of
# these
# systems
# .
# As
# a
# result
# ,
# a
# great
# deal
# of
# research
# has
# gone
# into
# methods
# of
# more
# effectively
# learning
# from
# limited
# amounts
# of
# data
# .
# Recent
# research
# has
# increasingly
# focused
# on
# unsupervised
# and
# semi-supervised
# learning
# algorithms
# .
# Such
# algorithms
# are
# able
# to
# learn
# from
# data
# that
# has
# not
# been
# hand-annotated
# with
# the
# desired
# answers
# ,
# or
# using
# a
# combination
# of
# annotated
# and
# non-annotated
# data
# .
# Generally
# ,
# this
# task
# is
# much
# more
# difficult
# than
# supervised
# learning
# ,
# and
# typically
# produces
# less
# accurate
# results
# for
# a
# given
# amount
# of
# input
# data
# .
# However
# ,
# there
# is
# an
# enormous
# amount
# of
# non-annotated
# data
# available
# -LRB-
# including
# ,
# among
# other
# things
# ,
# the
# entire
# content
# of
# the
# World
# Wide
# Web
# -RRB-
# ,
# which
# can
# often
# make
# up
# for
# the
# inferior
# results
# .
# NLP
# using
# machine
# learning
# Modern
# NLP
# algorithms
# are
# based
# on
# machine
# learning
# ,
# especially
# statistical
# machine
# learning
# .
# The
# paradigm
# of
# machine
# learning
# is
# different
# from
# that
# of
# most
# prior
# attempts
# at
# language
# processing
# .
# Prior
# implementations
# of
# language-processing
# tasks
# typically
# involved
# the
# direct
# hand
# coding
# of
# large
# sets
# of
# rules
# .
# The
# machine-learning
# paradigm
# calls
# instead
# for
# using
# general
# learning
# algorithms
# -
# often
# ,
# although
# not
# always
# ,
# grounded
# in
# statistical
# inference
# -
# to
# automatically
# learn
# such
# rules
# through
# the
# analysis
# of
# large
# corpora
# of
# typical
# real-world
# examples
# .
# A
# corpus
# -LRB-
# plural
# ,
# ``
# corpora
# ''
# -RRB-
# is
# a
# set
# of
# documents
# -LRB-
# or
# sometimes
# ,
# individual
# sentences
# -RRB-
# that
# have
# been
# hand-annotated
# with
# the
# correct
# values
# to
# be
# learned
# .
# Many
# different
# classes
# of
# machine
# learning
# algorithms
# have
# been
# applied
# to
# NLP
# tasks
# .
# These
# algorithms
# take
# as
# input
# a
# large
# set
# of
# ``
# features
# ''
# that
# are
# generated
# from
# the
# input
# data
# .
# Some
# of
# the
# earliest-used
# algorithms
# ,
# such
# as
# decision
# trees
# ,
# produced
# systems
# of
# hard
# if-then
# rules
# similar
# to
# the
# systems
# of
# hand-written
# rules
# that
# were
# then
# common
# .
# Increasingly
# ,
# however
# ,
# research
# has
# focused
# on
# statistical
# models
# ,
# which
# make
# soft
# ,
# probabilistic
# decisions
# based
# on
# attaching
# real-valued
# weights
# to
# each
# input
# feature
# .
# Such
# models
# have
# the
# advantage
# that
# they
# can
# express
# the
# relative
# certainty
# of
# many
# different
# possible
# answers
# rather
# than
# only
# one
# ,
# producing
# more
# reliable
# results
# when
# such
# a
# model
# is
# included
# as
# a
# component
# of
# a
# larger
# system
# .
# Systems
# based
# on
# machine-learning
# algorithms
# have
# many
# advantages
# over
# hand-produced
# rules
# :
# The
# learning
# procedures
# used
# during
# machine
# learning
# automatically
# focus
# on
# the
# most
# common
# cases
# ,
# whereas
# when
# writing
# rules
# by
# hand
# it
# is
# often
# not
# obvious
# at
# all
# where
# the
# effort
# should
# be
# directed
# .
# Automatic
# learning
# procedures
# can
# make
# use
# of
# statistical
# inference
# algorithms
# to
# produce
# models
# that
# are
# robust
# to
# unfamiliar
# input
# -LRB-
# e.g.
# containing
# words
# or
# structures
# that
# have
# not
# been
# seen
# before
# -RRB-
# and
# to
# erroneous
# input
# -LRB-
# e.g.
# with
# misspelled
# words
# or
# words
# accidentally
# omitted
# -RRB-
# .
# Generally
# ,
# handling
# such
# input
# gracefully
# with
# hand-written
# rules
# --
# or
# more
# generally
# ,
# creating
# systems
# of
# hand-written
# rules
# that
# make
# soft
# decisions
# --
# extremely
# difficult
# ,
# error-prone
# and
# time-consuming
# .
# Systems
# based
# on
# automatically
# learning
# the
# rules
# can
# be
# made
# more
# accurate
# simply
# by
# supplying
# more
# input
# data
# .
# However
# ,
# systems
# based
# on
# hand-written
# rules
# can
# only
# be
# made
# more
# accurate
# by
# increasing
# the
# complexity
# of
# the
# rules
# ,
# which
# is
# a
# much
# more
# difficult
# task
# .
# In
# particular
# ,
# there
# is
# a
# limit
# to
# the
# complexity
# of
# systems
# based
# on
# hand-crafted
# rules
# ,
# beyond
# which
# the
# systems
# become
# more
# and
# more
# unmanageable
# .
# However
# ,
# creating
# more
# data
# to
# input
# to
# machine-learning
# systems
# simply
# requires
# a
# corresponding
# increase
# in
# the
# number
# of
# man-hours
# worked
# ,
# generally
# without
# significant
# increases
# in
# the
# complexity
# of
# the
# annotation
# process
# .
# The
# subfield
# of
# NLP
# devoted
# to
# learning
# approaches
# is
# known
# as
# Natural
# Language
# Learning
# -LRB-
# NLL
# -RRB-
# and
# its
# conference
# CoNLL
# and
# peak
# body
# SIGNLL
# are
# sponsored
# by
# ACL
# ,
# recognizing
# also
# their
# links
# with
# Computational
# Linguistics
# and
# Language
# Acquisition
# .
# When
# the
# aims
# of
# computational
# language
# learning
# research
# is
# to
# understand
# more
# about
# human
# language
# acquisition
# ,
# or
# psycholinguistics
# ,
# NLL
# overlaps
# into
# the
# related
# field
# of
# Computational
# Psycholinguistics
# .

# %% [markdown]
# ## 54. 品詞タグ付け

# %%
def indent(elem, level=0):
    i = "\n" + level*"  "
    j = "\n" + (level-1)*"  "
    if len(elem):
        if not elem.text or not elem.text.strip():
            elem.text = i + "  "
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
        for subelem in elem:
            indent(subelem, level+1)
        if not elem.tail or not elem.tail.strip():
            elem.tail = j
    else:
        if level and (not elem.tail or not elem.tail.strip()):
            elem.tail = j
    return elem

# %%
indent(root)
ET.dump(root)
# Out:
# <root>
#   <document>
#     <sentences>
#       <sentence id="1">
#         <tokens>
#           <token id="1">
#             <word>Natural</word>
#           <lemma>natural</lemma>
#           <CharacterOffsetBegin>0</CharacterOffsetBegin>
#           <CharacterOffsetEnd>7</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="2">
#             <word>language</word>
#           <lemma>language</lemma>
#           <CharacterOffsetBegin>8</CharacterOffsetBegin>
#           <CharacterOffsetEnd>16</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="3">
#             <word>processing</word>
#           <lemma>processing</lemma>
#           <CharacterOffsetBegin>17</CharacterOffsetBegin>
#           <CharacterOffsetEnd>27</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="4">
#             <word>From</word>
#           <lemma>from</lemma>
#           <CharacterOffsetBegin>28</CharacterOffsetBegin>
#           <CharacterOffsetEnd>32</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="5">
#             <word>Wikipedia</word>
#           <lemma>Wikipedia</lemma>
#           <CharacterOffsetBegin>33</CharacterOffsetBegin>
#           <CharacterOffsetEnd>42</CharacterOffsetEnd>
#           <POS>NNP</POS>
#           <NER>ORGANIZATION</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="6">
#             <word>,</word>
#           <lemma>,</lemma>
#           <CharacterOffsetBegin>42</CharacterOffsetBegin>
#           <CharacterOffsetEnd>43</CharacterOffsetEnd>
#           <POS>,</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="7">
#             <word>the</word>
#           <lemma>the</lemma>
#           <CharacterOffsetBegin>44</CharacterOffsetBegin>
#           <CharacterOffsetEnd>47</CharacterOffsetEnd>
#           <POS>DT</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="8">
#             <word>free</word>
#           <lemma>free</lemma>
#           <CharacterOffsetBegin>48</CharacterOffsetBegin>
#           <CharacterOffsetEnd>52</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="9">
#             <word>encyclopedia</word>
#           <lemma>encyclopedia</lemma>
#           <CharacterOffsetBegin>53</CharacterOffsetBegin>
#           <CharacterOffsetEnd>65</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="10">
#             <word>Natural</word>
#           <lemma>natural</lemma>
#           <CharacterOffsetBegin>67</CharacterOffsetBegin>
#           <CharacterOffsetEnd>74</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>MISC</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="11">
#             <word>language</word>
#           <lemma>language</lemma>
#           <CharacterOffsetBegin>75</CharacterOffsetBegin>
#           <CharacterOffsetEnd>83</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="12">
#             <word>processing</word>
#           <lemma>processing</lemma>
#           <CharacterOffsetBegin>84</CharacterOffsetBegin>
#           <CharacterOffsetEnd>94</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="13">
#             <word>-LRB-</word>
#           <lemma>-lrb-</lemma>
#           <CharacterOffsetBegin>95</CharacterOffsetBegin>
#           <CharacterOffsetEnd>96</CharacterOffsetEnd>
#           <POS>-LRB-</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="14">
#             <word>NLP</word>
#           <lemma>nlp</lemma>
#           <CharacterOffsetBegin>96</CharacterOffsetBegin>
#           <CharacterOffsetEnd>99</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>ORGANIZATION</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="15">
#             <word>-RRB-</word>
#           <lemma>-rrb-</lemma>
#           <CharacterOffsetBegin>99</CharacterOffsetBegin>
#           <CharacterOffsetEnd>100</CharacterOffsetEnd>
#           <POS>-RRB-</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="16">
#             <word>is</word>
#           <lemma>be</lemma>
#           <CharacterOffsetBegin>101</CharacterOffsetBegin>
#           <CharacterOffsetEnd>103</CharacterOffsetEnd>
#           <POS>VBZ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="17">
#             <word>a</word>
#           <lemma>a</lemma>
#           <CharacterOffsetBegin>104</CharacterOffsetBegin>
#           <CharacterOffsetEnd>105</CharacterOffsetEnd>
#           <POS>DT</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="18">
#             <word>field</word>
#           <lemma>field</lemma>
#           <CharacterOffsetBegin>106</CharacterOffsetBegin>
#           <CharacterOffsetEnd>111</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="19">
#             <word>of</word>
#           <lemma>of</lemma>
#           <CharacterOffsetBegin>112</CharacterOffsetBegin>
#           <CharacterOffsetEnd>114</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="20">
#             <word>computer</word>
#           <lemma>computer</lemma>
#           <CharacterOffsetBegin>115</CharacterOffsetBegin>
#           <CharacterOffsetEnd>123</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="21">
#             <word>science</word>
#           <lemma>science</lemma>
#           <CharacterOffsetBegin>124</CharacterOffsetBegin>
#           <CharacterOffsetEnd>131</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="22">
#             <word>,</word>
#           <lemma>,</lemma>
#           <CharacterOffsetBegin>131</CharacterOffsetBegin>
#           <CharacterOffsetEnd>132</CharacterOffsetEnd>
#           <POS>,</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="23">
#             <word>artificial</word>
#           <lemma>artificial</lemma>
#           <CharacterOffsetBegin>133</CharacterOffsetBegin>
#           <CharacterOffsetEnd>143</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="24">
#             <word>intelligence</word>
#           <lemma>intelligence</lemma>
#           <CharacterOffsetBegin>144</CharacterOffsetBegin>
#           <CharacterOffsetEnd>156</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="25">
#             <word>,</word>
#           <lemma>,</lemma>
#           <CharacterOffsetBegin>156</CharacterOffsetBegin>
#           <CharacterOffsetEnd>157</CharacterOffsetEnd>
#           <POS>,</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="26">
#             <word>and</word>
#           <lemma>and</lemma>
#           <CharacterOffsetBegin>158</CharacterOffsetBegin>
#           <CharacterOffsetEnd>161</CharacterOffsetEnd>
#           <POS>CC</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="27">
#             <word>linguistics</word>
#           <lemma>linguistics</lemma>
#           <CharacterOffsetBegin>162</CharacterOffsetBegin>
#           <CharacterOffsetEnd>173</CharacterOffsetEnd>
#           <POS>NNS</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="28">
#             <word>concerned</word>
#           <lemma>concern</lemma>
#           <CharacterOffsetBegin>174</CharacterOffsetBegin>
#           <CharacterOffsetEnd>183</CharacterOffsetEnd>
#           <POS>VBN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="29">
#             <word>with</word>
#           <lemma>with</lemma>
#           <CharacterOffsetBegin>184</CharacterOffsetBegin>
#           <CharacterOffsetEnd>188</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="30">
#             <word>the</word>
#           <lemma>the</lemma>
#           <CharacterOffsetBegin>189</CharacterOffsetBegin>
#           <CharacterOffsetEnd>192</CharacterOffsetEnd>
#           <POS>DT</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="31">
#             <word>interactions</word>
#           <lemma>interaction</lemma>
#           <CharacterOffsetBegin>193</CharacterOffsetBegin>
#           <CharacterOffsetEnd>205</CharacterOffsetEnd>
#           <POS>NNS</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="32">
#             <word>between</word>
#           <lemma>between</lemma>
#           <CharacterOffsetBegin>206</CharacterOffsetBegin>
#           <CharacterOffsetEnd>213</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="33">
#             <word>computers</word>
#           <lemma>computer</lemma>
#           <CharacterOffsetBegin>214</CharacterOffsetBegin>
#           <CharacterOffsetEnd>223</CharacterOffsetEnd>
#           <POS>NNS</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="34">
#             <word>and</word>
#           <lemma>and</lemma>
#           <CharacterOffsetBegin>224</CharacterOffsetBegin>
#           <CharacterOffsetEnd>227</CharacterOffsetEnd>
#           <POS>CC</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="35">
#             <word>human</word>
#           <lemma>human</lemma>
#           <CharacterOffsetBegin>228</CharacterOffsetBegin>
#           <CharacterOffsetEnd>233</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="36">
#             <word>-LRB-</word>
#           <lemma>-lrb-</lemma>
#           <CharacterOffsetBegin>234</CharacterOffsetBegin>
#           <CharacterOffsetEnd>235</CharacterOffsetEnd>
#           <POS>-LRB-</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="37">
#             <word>natural</word>
#           <lemma>natural</lemma>
#           <CharacterOffsetBegin>235</CharacterOffsetBegin>
#           <CharacterOffsetEnd>242</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="38">
#             <word>-RRB-</word>
#           <lemma>-rrb-</lemma>
#           <CharacterOffsetBegin>242</CharacterOffsetBegin>
#           <CharacterOffsetEnd>243</CharacterOffsetEnd>
#           <POS>-RRB-</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="39">
#             <word>languages</word>
#           <lemma>language</lemma>
#           <CharacterOffsetBegin>244</CharacterOffsetBegin>
#           <CharacterOffsetEnd>253</CharacterOffsetEnd>
#           <POS>NNS</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="40">
#             <word>.</word>
#           <lemma>.</lemma>
#           <CharacterOffsetBegin>253</CharacterOffsetBegin>
#           <CharacterOffsetEnd>254</CharacterOffsetEnd>
#           <POS>.</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         </tokens>
#       <parse>(ROOT
#   (S
#     (PP
#       (NP (JJ Natural) (NN language) (NN processing))
#       (IN From)
#       (NP (NNP Wikipedia)))
#     (, ,)
#     (NP
#       (NP (DT the) (JJ free) (NN encyclopedia) (JJ Natural) (NN language) (NN processing))
#       (PRN (-LRB- -LRB-)
#         (NP (NN NLP))
#         (-RRB- -RRB-)))
#     (VP (VBZ is)
#       (NP
#         (NP
#           (NP (DT a) (NN field))
#           (PP (IN of)
#             (NP (NN computer) (NN science))))
#         (, ,)
#         (NP (JJ artificial) (NN intelligence))
#         (, ,)
#         (CC and)
#         (NP
#           (NP (NNS linguistics))
#           (VP (VBN concerned)
#             (PP (IN with)
#               (NP
#                 (NP (DT the) (NNS interactions))
#                 (PP (IN between)
#                   (NP
#                     (NP (NNS computers))
#                     (CC and)
#                     (NP (JJ human) (-LRB- -LRB-) (JJ natural) (-RRB- -RRB-) (NNS languages))))))))))
#     (. .)))
#
# </parse>
#       <dependencies type="basic-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="18">field</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="3">processing</governor>
#           <dependent idx="1">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="3">processing</governor>
#           <dependent idx="2">language</dependent>
#           </dep>
#         <dep type="nmod">
#             <governor idx="18">field</governor>
#           <dependent idx="3">processing</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="3">processing</governor>
#           <dependent idx="4">From</dependent>
#           </dep>
#         <dep type="dep">
#             <governor idx="3">processing</governor>
#           <dependent idx="5">Wikipedia</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="6">,</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="12">processing</governor>
#           <dependent idx="7">the</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="8">free</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="9">encyclopedia</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="10">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="11">language</dependent>
#           </dep>
#         <dep type="nsubj">
#             <governor idx="18">field</governor>
#           <dependent idx="12">processing</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="13">-LRB-</dependent>
#           </dep>
#         <dep type="appos">
#             <governor idx="12">processing</governor>
#           <dependent idx="14">NLP</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="15">-RRB-</dependent>
#           </dep>
#         <dep type="cop">
#             <governor idx="18">field</governor>
#           <dependent idx="16">is</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="18">field</governor>
#           <dependent idx="17">a</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="21">science</governor>
#           <dependent idx="19">of</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="21">science</governor>
#           <dependent idx="20">computer</dependent>
#           </dep>
#         <dep type="nmod">
#             <governor idx="18">field</governor>
#           <dependent idx="21">science</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="22">,</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="24">intelligence</governor>
#           <dependent idx="23">artificial</dependent>
#           </dep>
#         <dep type="conj">
#             <governor idx="18">field</governor>
#           <dependent idx="24">intelligence</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="25">,</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="18">field</governor>
#           <dependent idx="26">and</dependent>
#           </dep>
#         <dep type="conj">
#             <governor idx="18">field</governor>
#           <dependent idx="27">linguistics</dependent>
#           </dep>
#         <dep type="acl">
#             <governor idx="27">linguistics</governor>
#           <dependent idx="28">concerned</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="31">interactions</governor>
#           <dependent idx="29">with</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="31">interactions</governor>
#           <dependent idx="30">the</dependent>
#           </dep>
#         <dep type="nmod">
#             <governor idx="28">concerned</governor>
#           <dependent idx="31">interactions</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="33">computers</governor>
#           <dependent idx="32">between</dependent>
#           </dep>
#         <dep type="nmod">
#             <governor idx="31">interactions</governor>
#           <dependent idx="33">computers</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="33">computers</governor>
#           <dependent idx="34">and</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="35">human</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="36">-LRB-</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="37">natural</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="38">-RRB-</dependent>
#           </dep>
#         <dep type="conj">
#             <governor idx="33">computers</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="40">.</dependent>
#           </dep>
#         </dependencies>
#       <dependencies type="collapsed-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="18">field</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="3">processing</governor>
#           <dependent idx="1">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="3">processing</governor>
#           <dependent idx="2">language</dependent>
#           </dep>
#         <dep type="nmod:from">
#             <governor idx="18">field</governor>
#           <dependent idx="3">processing</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="3">processing</governor>
#           <dependent idx="4">From</dependent>
#           </dep>
#         <dep type="dep">
#             <governor idx="3">processing</governor>
#           <dependent idx="5">Wikipedia</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="6">,</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="12">processing</governor>
#           <dependent idx="7">the</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="8">free</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="9">encyclopedia</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="10">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="11">language</dependent>
#           </dep>
#         <dep type="nsubj">
#             <governor idx="18">field</governor>
#           <dependent idx="12">processing</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="13">-LRB-</dependent>
#           </dep>
#         <dep type="appos">
#             <governor idx="12">processing</governor>
#           <dependent idx="14">NLP</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="15">-RRB-</dependent>
#           </dep>
#         <dep type="cop">
#             <governor idx="18">field</governor>
#           <dependent idx="16">is</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="18">field</governor>
#           <dependent idx="17">a</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="21">science</governor>
#           <dependent idx="19">of</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="21">science</governor>
#           <dependent idx="20">computer</dependent>
#           </dep>
#         <dep type="nmod:of">
#             <governor idx="18">field</governor>
#           <dependent idx="21">science</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="22">,</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="24">intelligence</governor>
#           <dependent idx="23">artificial</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="24">intelligence</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="25">,</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="18">field</governor>
#           <dependent idx="26">and</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="27">linguistics</dependent>
#           </dep>
#         <dep type="acl">
#             <governor idx="27">linguistics</governor>
#           <dependent idx="28">concerned</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="31">interactions</governor>
#           <dependent idx="29">with</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="31">interactions</governor>
#           <dependent idx="30">the</dependent>
#           </dep>
#         <dep type="nmod:with">
#             <governor idx="28">concerned</governor>
#           <dependent idx="31">interactions</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="33">computers</governor>
#           <dependent idx="32">between</dependent>
#           </dep>
#         <dep type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="33">computers</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="33">computers</governor>
#           <dependent idx="34">and</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="35">human</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="36">-LRB-</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="37">natural</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="38">-RRB-</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="33">computers</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="40">.</dependent>
#           </dep>
#         </dependencies>
#       <dependencies type="collapsed-ccprocessed-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="18">field</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="3">processing</governor>
#           <dependent idx="1">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="3">processing</governor>
#           <dependent idx="2">language</dependent>
#           </dep>
#         <dep type="nmod:from">
#             <governor idx="18">field</governor>
#           <dependent idx="3">processing</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="3">processing</governor>
#           <dependent idx="4">From</dependent>
#           </dep>
#         <dep type="dep">
#             <governor idx="3">processing</governor>
#           <dependent idx="5">Wikipedia</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="6">,</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="12">processing</governor>
#           <dependent idx="7">the</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="8">free</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="9">encyclopedia</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="10">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="11">language</dependent>
#           </dep>
#         <dep type="nsubj">
#             <governor idx="18">field</governor>
#           <dependent idx="12">processing</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="13">-LRB-</dependent>
#           </dep>
#         <dep type="appos">
#             <governor idx="12">processing</governor>
#           <dependent idx="14">NLP</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="15">-RRB-</dependent>
#           </dep>
#         <dep type="cop">
#             <governor idx="18">field</governor>
#           <dependent idx="16">is</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="18">field</governor>
#           <dependent idx="17">a</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="21">science</governor>
#           <dependent idx="19">of</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="21">science</governor>
#           <dependent idx="20">computer</dependent>
#           </dep>
#         <dep type="nmod:of">
#             <governor idx="18">field</governor>
#           <dependent idx="21">science</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="22">,</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="24">intelligence</governor>
#           <dependent idx="23">artificial</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="24">intelligence</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="25">,</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="18">field</governor>
#           <dependent idx="26">and</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="27">linguistics</dependent>
#           </dep>
#         <dep type="acl">
#             <governor idx="27">linguistics</governor>
#           <dependent idx="28">concerned</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="31">interactions</governor>
#           <dependent idx="29">with</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="31">interactions</governor>
#           <dependent idx="30">the</dependent>
#           </dep>
#         <dep type="nmod:with">
#             <governor idx="28">concerned</governor>
#           <dependent idx="31">interactions</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="33">computers</governor>
#           <dependent idx="32">between</dependent>
#           </dep>
#         <dep type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="33">computers</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="33">computers</governor>
#           <dependent idx="34">and</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="35">human</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="36">-LRB-</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="37">natural</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="38">-RRB-</dependent>
#           </dep>
#         <dep extra="true" type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="33">computers</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="40">.</dependent>
#           </dep>
#         </dependencies>
#       <dependencies type="enhanced-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="18">field</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="3">processing</governor>
#           <dependent idx="1">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="3">processing</governor>
#           <dependent idx="2">language</dependent>
#           </dep>
#         <dep type="nmod:from">
#             <governor idx="18">field</governor>
#           <dependent idx="3">processing</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="3">processing</governor>
#           <dependent idx="4">From</dependent>
#           </dep>
#         <dep type="dep">
#             <governor idx="3">processing</governor>
#           <dependent idx="5">Wikipedia</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="6">,</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="12">processing</governor>
#           <dependent idx="7">the</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="8">free</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="9">encyclopedia</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="10">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="11">language</dependent>
#           </dep>
#         <dep type="nsubj">
#             <governor idx="18">field</governor>
#           <dependent idx="12">processing</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="13">-LRB-</dependent>
#           </dep>
#         <dep type="appos">
#             <governor idx="12">processing</governor>
#           <dependent idx="14">NLP</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="15">-RRB-</dependent>
#           </dep>
#         <dep type="cop">
#             <governor idx="18">field</governor>
#           <dependent idx="16">is</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="18">field</governor>
#           <dependent idx="17">a</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="21">science</governor>
#           <dependent idx="19">of</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="21">science</governor>
#           <dependent idx="20">computer</dependent>
#           </dep>
#         <dep type="nmod:of">
#             <governor idx="18">field</governor>
#           <dependent idx="21">science</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="22">,</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="24">intelligence</governor>
#           <dependent idx="23">artificial</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="24">intelligence</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="25">,</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="18">field</governor>
#           <dependent idx="26">and</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="27">linguistics</dependent>
#           </dep>
#         <dep type="acl">
#             <governor idx="27">linguistics</governor>
#           <dependent idx="28">concerned</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="31">interactions</governor>
#           <dependent idx="29">with</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="31">interactions</governor>
#           <dependent idx="30">the</dependent>
#           </dep>
#         <dep type="nmod:with">
#             <governor idx="28">concerned</governor>
#           <dependent idx="31">interactions</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="33">computers</governor>
#           <dependent idx="32">between</dependent>
#           </dep>
#         <dep type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="33">computers</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="33">computers</governor>
#           <dependent idx="34">and</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="35">human</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="36">-LRB-</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="37">natural</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="38">-RRB-</dependent>
#           </dep>
#         <dep extra="true" type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="33">computers</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="40">.</dependent>
#           </dep>
#         </dependencies>
#       <dependencies type="enhanced-plus-plus-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="18">field</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="3">processing</governor>
#           <dependent idx="1">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="3">processing</governor>
#           <dependent idx="2">language</dependent>
#           </dep>
#         <dep type="nmod:from">
#             <governor idx="18">field</governor>
#           <dependent idx="3">processing</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="3">processing</governor>
#           <dependent idx="4">From</dependent>
#           </dep>
#         <dep type="dep">
#             <governor idx="3">processing</governor>
#           <dependent idx="5">Wikipedia</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="6">,</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="12">processing</governor>
#           <dependent idx="7">the</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="8">free</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="9">encyclopedia</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="12">processing</governor>
#           <dependent idx="10">Natural</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="12">processing</governor>
#           <dependent idx="11">language</dependent>
#           </dep>
#         <dep type="nsubj">
#             <governor idx="18">field</governor>
#           <dependent idx="12">processing</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="13">-LRB-</dependent>
#           </dep>
#         <dep type="appos">
#             <governor idx="12">processing</governor>
#           <dependent idx="14">NLP</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="14">NLP</governor>
#           <dependent idx="15">-RRB-</dependent>
#           </dep>
#         <dep type="cop">
#             <governor idx="18">field</governor>
#           <dependent idx="16">is</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="18">field</governor>
#           <dependent idx="17">a</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="21">science</governor>
#           <dependent idx="19">of</dependent>
#           </dep>
#         <dep type="compound">
#             <governor idx="21">science</governor>
#           <dependent idx="20">computer</dependent>
#           </dep>
#         <dep type="nmod:of">
#             <governor idx="18">field</governor>
#           <dependent idx="21">science</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="22">,</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="24">intelligence</governor>
#           <dependent idx="23">artificial</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="24">intelligence</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="25">,</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="18">field</governor>
#           <dependent idx="26">and</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="18">field</governor>
#           <dependent idx="27">linguistics</dependent>
#           </dep>
#         <dep type="acl">
#             <governor idx="27">linguistics</governor>
#           <dependent idx="28">concerned</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="31">interactions</governor>
#           <dependent idx="29">with</dependent>
#           </dep>
#         <dep type="det">
#             <governor idx="31">interactions</governor>
#           <dependent idx="30">the</dependent>
#           </dep>
#         <dep type="nmod:with">
#             <governor idx="28">concerned</governor>
#           <dependent idx="31">interactions</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="33">computers</governor>
#           <dependent idx="32">between</dependent>
#           </dep>
#         <dep type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="33">computers</dependent>
#           </dep>
#         <dep type="cc">
#             <governor idx="33">computers</governor>
#           <dependent idx="34">and</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="35">human</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="36">-LRB-</dependent>
#           </dep>
#         <dep type="amod">
#             <governor idx="39">languages</governor>
#           <dependent idx="37">natural</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="39">languages</governor>
#           <dependent idx="38">-RRB-</dependent>
#           </dep>
#         <dep extra="true" type="nmod:between">
#             <governor idx="31">interactions</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="conj:and">
#             <governor idx="33">computers</governor>
#           <dependent idx="39">languages</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="18">field</governor>
#           <dependent idx="40">.</dependent>
#           </dep>
#         </dependencies>
#       </sentence>
#     <sentence id="2">
#         <tokens>
#           <token id="1">
#             <word>As</word>
#           <lemma>as</lemma>
#           <CharacterOffsetBegin>255</CharacterOffsetBegin>
#           <CharacterOffsetEnd>257</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="2">
#             <word>such</word>
#           <lemma>such</lemma>
#           <CharacterOffsetBegin>258</CharacterOffsetBegin>
#           <CharacterOffsetEnd>262</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="3">
#             <word>,</word>
#           <lemma>,</lemma>
#           <CharacterOffsetBegin>262</CharacterOffsetBegin>
#           <CharacterOffsetEnd>263</CharacterOffsetEnd>
#           <POS>,</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="4">
#             <word>NLP</word>
#           <lemma>nlp</lemma>
#           <CharacterOffsetBegin>264</CharacterOffsetBegin>
#           <CharacterOffsetEnd>267</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>ORGANIZATION</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="5">
#             <word>is</word>
#           <lemma>be</lemma>
#           <CharacterOffsetBegin>268</CharacterOffsetBegin>
#           <CharacterOffsetEnd>270</CharacterOffsetEnd>
#           <POS>VBZ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="6">
#             <word>related</word>
#           <lemma>relate</lemma>
#           <CharacterOffsetBegin>271</CharacterOffsetBegin>
#           <CharacterOffsetEnd>278</CharacterOffsetEnd>
#           <POS>VBN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="7">
#             <word>to</word>
#           <lemma>to</lemma>
#           <CharacterOffsetBegin>279</CharacterOffsetBegin>
#           <CharacterOffsetEnd>281</CharacterOffsetEnd>
#           <POS>TO</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="8">
#             <word>the</word>
#           <lemma>the</lemma>
#           <CharacterOffsetBegin>282</CharacterOffsetBegin>
#           <CharacterOffsetEnd>285</CharacterOffsetEnd>
#           <POS>DT</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="9">
#             <word>area</word>
#           <lemma>area</lemma>
#           <CharacterOffsetBegin>286</CharacterOffsetBegin>
#           <CharacterOffsetEnd>290</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="10">
#             <word>of</word>
#           <lemma>of</lemma>
#           <CharacterOffsetBegin>291</CharacterOffsetBegin>
#           <CharacterOffsetEnd>293</CharacterOffsetEnd>
#           <POS>IN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="11">
#             <word>humani-computer</word>
#           <lemma>humani-computer</lemma>
#           <CharacterOffsetBegin>294</CharacterOffsetBegin>
#           <CharacterOffsetEnd>309</CharacterOffsetEnd>
#           <POS>JJ</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="12">
#             <word>interaction</word>
#           <lemma>interaction</lemma>
#           <CharacterOffsetBegin>310</CharacterOffsetBegin>
#           <CharacterOffsetEnd>321</CharacterOffsetEnd>
#           <POS>NN</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         <token id="13">
#             <word>.</word>
#           <lemma>.</lemma>
#           <CharacterOffsetBegin>321</CharacterOffsetBegin>
#           <CharacterOffsetEnd>322</CharacterOffsetEnd>
#           <POS>.</POS>
#           <NER>O</NER>
#           <Speaker>PER0</Speaker>
#           </token>
#         </tokens>
#       <parse>(ROOT
#   (S
#     (PP (IN As)
#       (NP (JJ such)))
#     (, ,)
#     (NP (NN NLP))
#     (VP (VBZ is)
#       (ADJP (VBN related)
#         (PP (TO to)
#           (NP
#             (NP (DT the) (NN area))
#             (PP (IN of)
#               (NP (JJ humani-computer) (NN interaction)))))))
#     (. .)))
#
# </parse>
#       <dependencies type="basic-dependencies">
#           <dep type="root">
#             <governor idx="0">ROOT</governor>
#           <dependent idx="6">related</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="2">such</governor>
#           <dependent idx="1">As</dependent>
#           </dep>
#         <dep type="nmod">
#             <governor idx="6">related</governor>
#           <dependent idx="2">such</dependent>
#           </dep>
#         <dep type="punct">
#             <governor idx="6">related</governor>
#           <dependent idx="3">,</dependent>
#           </dep>
#         <dep type="nsubjpass">
#             <governor idx="6">related</governor>
#           <dependent idx="4">NLP</dependent>
#           </dep>
#         <dep type="auxpass">
#             <governor idx="6">related</governor>
#           <dependent idx="5">is</dependent>
#           </dep>
#         <dep type="case">
#             <governor idx="9">area</governor>
# ...
#         <start>29</start>
#         <end>30</end>
#         <head>29</head>
#         <text>ELIZA</text>
#         </mention>
#       <mention>
#           <sentence>12</sentence>
#         <start>13</start>
#         <end>14</end>
#         <head>13</head>
#         <text>ELIZA</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>10</sentence>
#         <start>11</start>
#         <end>12</end>
#         <head>11</head>
#         <text>SHRDLU</text>
#         </mention>
#       <mention>
#           <sentence>10</sentence>
#         <start>13</start>
#         <end>27</end>
#         <head>16</head>
#         <text>a natural language system working in restricted `` blocks worlds '' with restricted vocabularies</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>12</sentence>
#         <start>2</start>
#         <end>6</end>
#         <head>4</head>
#         <text>the `` patient ''</text>
#         </mention>
#       <mention>
#           <sentence>12</sentence>
#         <start>26</start>
#         <end>27</end>
#         <head>26</head>
#         <text>My</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>12</sentence>
#         <start>26</start>
#         <end>28</end>
#         <head>27</head>
#         <text>My head</text>
#         </mention>
#       <mention>
#           <sentence>12</sentence>
#         <start>36</start>
#         <end>38</end>
#         <head>37</head>
#         <text>your head</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>12</sentence>
#         <start>34</start>
#         <end>35</end>
#         <head>34</head>
#         <text>you</text>
#         </mention>
#       <mention>
#           <sentence>12</sentence>
#         <start>36</start>
#         <end>37</end>
#         <head>36</head>
#         <text>your</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>15</sentence>
#         <start>33</start>
#         <end>34</end>
#         <head>33</head>
#         <text>Lehnert</text>
#         </mention>
#       <mention>
#           <sentence>15</sentence>
#         <start>49</start>
#         <end>51</end>
#         <head>49</head>
#         <text>Lehnert 1981</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>15</sentence>
#         <start>14</start>
#         <end>15</end>
#         <head>14</head>
#         <text>1978</text>
#         </mention>
#       <mention>
#           <sentence>15</sentence>
#         <start>21</start>
#         <end>22</end>
#         <head>21</head>
#         <text>1978</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>17</sentence>
#         <start>15</start>
#         <end>17</end>
#         <head>16</head>
#         <text>hand-written rules</text>
#         </mention>
#       <mention>
#           <sentence>39</sentence>
#         <start>23</start>
#         <end>25</end>
#         <head>24</head>
#         <text>hand-written rules</text>
#         </mention>
#       <mention>
#           <sentence>44</sentence>
#         <start>8</start>
#         <end>10</end>
#         <head>9</head>
#         <text>hand-written rules</text>
#         </mention>
#       <mention>
#           <sentence>44</sentence>
#         <start>18</start>
#         <end>20</end>
#         <head>19</head>
#         <text>hand-written rules</text>
#         </mention>
#       <mention>
#           <sentence>46</sentence>
#         <start>6</start>
#         <end>8</end>
#         <head>7</head>
#         <text>hand-written rules</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>18</sentence>
#         <start>19</start>
#         <end>25</end>
#         <head>21</head>
#         <text>machine learning algorithms for language processing</text>
#         </mention>
#       <mention>
#           <sentence>20</sentence>
#         <start>7</start>
#         <end>8</end>
#         <head>7</head>
#         <text>algorithms</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>20</sentence>
#         <start>11</start>
#         <end>13</end>
#         <head>12</head>
#         <text>decision trees</text>
#         </mention>
#       <mention>
#           <sentence>39</sentence>
#         <start>9</start>
#         <end>11</end>
#         <head>10</head>
#         <text>decision trees</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>20</sentence>
#         <start>17</start>
#         <end>25</end>
#         <head>19</head>
#         <text>hard if-then rules similar to existing hand-written rules</text>
#         </mention>
#       <mention>
#           <sentence>34</sentence>
#         <start>16</start>
#         <end>17</end>
#         <head>16</head>
#         <text>rules</text>
#         </mention>
#       <mention>
#           <sentence>42</sentence>
#         <start>31</start>
#         <end>32</end>
#         <head>31</head>
#         <text>rules</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>21</sentence>
#         <start>24</start>
#         <end>26</end>
#         <head>25</head>
#         <text>statistical models</text>
#         </mention>
#       <mention>
#           <sentence>21</sentence>
#         <start>24</start>
#         <end>46</end>
#         <head>25</head>
#         <text>statistical models , which make soft , probabilistic decisions based on attaching real-valued weights to the features making up the input data</text>
#         </mention>
#       <mention>
#           <sentence>40</sentence>
#         <start>9</start>
#         <end>27</end>
#         <head>10</head>
#         <text>statistical models , which make soft , probabilistic decisions based on attaching real-valued weights to each input feature</text>
#         </mention>
#       <mention>
#           <sentence>40</sentence>
#         <start>9</start>
#         <end>11</end>
#         <head>10</head>
#         <text>statistical models</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>21</sentence>
#         <start>29</start>
#         <end>33</end>
#         <head>32</head>
#         <text>soft , probabilistic decisions</text>
#         </mention>
#       <mention>
#           <sentence>40</sentence>
#         <start>14</start>
#         <end>18</end>
#         <head>17</head>
#         <text>soft , probabilistic decisions</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>21</sentence>
#         <start>36</start>
#         <end>38</end>
#         <head>37</head>
#         <text>real-valued weights</text>
#         </mention>
#       <mention>
#           <sentence>40</sentence>
#         <start>21</start>
#         <end>23</end>
#         <head>22</head>
#         <text>real-valued weights</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>21</sentence>
#         <start>43</start>
#         <end>46</end>
#         <head>45</head>
#         <text>the input data</text>
#         </mention>
#       <mention>
#           <sentence>38</sentence>
#         <start>17</start>
#         <end>20</end>
#         <head>19</head>
#         <text>the input data</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>22</sentence>
#         <start>1</start>
#         <end>13</end>
#         <head>4</head>
#         <text>The cache language models upon which many speech recognition systems now rely</text>
#         </mention>
#       <mention>
#           <sentence>22</sentence>
#         <start>14</start>
#         <end>19</end>
#         <head>14</head>
#         <text>examples of such statistical models</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>22</sentence>
#         <start>7</start>
#         <end>11</end>
#         <head>10</head>
#         <text>many speech recognition systems</text>
#         </mention>
#       <mention>
#           <sentence>25</sentence>
#         <start>1</start>
#         <end>3</end>
#         <head>2</head>
#         <text>These systems</text>
#         </mention>
#       <mention>
#           <sentence>26</sentence>
#         <start>16</start>
#         <end>18</end>
#         <head>17</head>
#         <text>these systems</text>
#         </mention>
#       <mention>
#           <sentence>26</sentence>
#         <start>35</start>
#         <end>37</end>
#         <head>36</head>
#         <text>these systems</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>38</sentence>
#         <start>4</start>
#         <end>6</end>
#         <head>5</head>
#         <text>as input</text>
#         </mention>
#       <mention>
#           <sentence>23</sentence>
#         <start>13</start>
#         <end>26</end>
#         <head>13</head>
#         <text>input that contains errors -LRB- as is very common for real-world data -RRB-</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>41</sentence>
#         <start>4</start>
#         <end>6</end>
#         <head>5</head>
#         <text>the advantage</text>
#         </mention>
#       <mention>
#           <sentence>25</sentence>
#         <start>7</start>
#         <end>49</end>
#         <head>7</head>
#         <text>advantage of existing multilingual textual corpora that had been produced by the Parliament of Canada and the European Union as a result of laws calling for the translation of all governmental proceedings into all official languages of the corresponding systems of government</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>25</sentence>
#         <start>9</start>
#         <end>49</end>
#         <head>12</head>
#         <text>existing multilingual textual corpora that had been produced by the Parliament of Canada and the European Union as a result of laws calling for the translation of all governmental proceedings into all official languages of the corresponding systems of government</text>
#         </mention>
#       <mention>
#           <sentence>36</sentence>
#         <start>6</start>
#         <end>9</end>
#         <head>7</head>
#         <text>`` corpora ''</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>27</sentence>
#         <start>22</start>
#         <end>23</end>
#         <head>22</head>
#         <text>data</text>
#         </mention>
#       <mention>
#           <sentence>29</sentence>
#         <start>8</start>
#         <end>18</end>
#         <head>8</head>
#         <text>data that has not been hand-annotated with the desired answers</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>32</sentence>
#         <start>3</start>
#         <end>8</end>
#         <head>7</head>
#         <text>machine learning Modern NLP algorithms</text>
#         </mention>
#       <mention>
#           <sentence>37</sentence>
#         <start>5</start>
#         <end>8</end>
#         <head>7</head>
#         <text>machine learning algorithms</text>
#         </mention>
#       <mention>
#           <sentence>38</sentence>
#         <start>1</start>
#         <end>3</end>
#         <head>2</head>
#         <text>These algorithms</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>32</sentence>
#         <start>11</start>
#         <end>18</end>
#         <head>12</head>
#         <text>machine learning , especially statistical machine learning</text>
#         </mention>
#       <mention>
#           <sentence>32</sentence>
#         <start>11</start>
#         <end>13</end>
#         <head>12</head>
#         <text>machine learning</text>
#         </mention>
#       <mention>
#           <sentence>33</sentence>
#         <start>4</start>
#         <end>6</end>
#         <head>5</head>
#         <text>machine learning</text>
#         </mention>
#       <mention>
#           <sentence>42</sentence>
#         <start>18</start>
#         <end>20</end>
#         <head>19</head>
#         <text>machine learning</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>36</sentence>
#         <start>1</start>
#         <end>10</end>
#         <head>2</head>
#         <text>A corpus -LRB- plural , `` corpora '' -RRB-</text>
#         </mention>
#       <mention>
#           <sentence>36</sentence>
#         <start>11</start>
#         <end>33</end>
#         <head>12</head>
#         <text>a set of documents -LRB- or sometimes , individual sentences -RRB- that have been hand-annotated with the correct values to be learned</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>39</sentence>
#         <start>1</start>
#         <end>11</end>
#         <head>1</head>
#         <text>Some of the earliest-used algorithms , such as decision trees</text>
#         </mention>
#       <mention>
#           <sentence>41</sentence>
#         <start>7</start>
#         <end>8</end>
#         <head>7</head>
#         <text>they</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>42</sentence>
#         <start>1</start>
#         <end>6</end>
#         <head>1</head>
#         <text>Systems based on machine-learning algorithms</text>
#         </mention>
#       <mention>
#           <sentence>48</sentence>
#         <start>9</start>
#         <end>11</end>
#         <head>10</head>
#         <text>machine-learning systems</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>42</sentence>
#         <start>13</start>
#         <end>20</end>
#         <head>15</head>
#         <text>The learning procedures used during machine learning</text>
#         </mention>
#       <mention>
#           <sentence>43</sentence>
#         <start>3</start>
#         <end>4</end>
#         <head>3</head>
#         <text>procedures</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>45</sentence>
#         <start>6</start>
#         <end>8</end>
#         <head>7</head>
#         <text>the rules</text>
#         </mention>
#       <mention>
#           <sentence>46</sentence>
#         <start>19</start>
#         <end>29</end>
#         <head>20</head>
#         <text>the rules , which is a much more difficult task</text>
#         </mention>
#       <mention>
#           <sentence>46</sentence>
#         <start>19</start>
#         <end>21</end>
#         <head>20</head>
#         <text>the rules</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>47</sentence>
#         <start>20</start>
#         <end>22</end>
#         <head>21</head>
#         <text>the systems</text>
#         </mention>
#       <mention>
#           <sentence>46</sentence>
#         <start>3</start>
#         <end>8</end>
#         <head>3</head>
#         <text>systems based on hand-written rules</text>
#         </mention>
#       </coreference>
#     <coreference>
#         <mention representative="true">
#           <sentence>49</sentence>
#         <start>12</start>
#         <end>18</end>
#         <head>14</head>
#         <text>Natural Language Learning -LRB- NLL -RRB-</text>
#         </mention>
#       <mention>
#           <sentence>49</sentence>
#         <start>19</start>
#         <end>20</end>
#         <head>19</head>
#         <text>its</text>
#         </mention>
#       </coreference>
#     </coreference>
#   </document>
# </root>

# %%
for token in root.iter('token'):
    word = token[0].text
    lemma = token[1].text
    pos = token[4].text
    
    print('{}\t{}\t{}'.format(word, lemma, pos))
# Out:
# Natural	natural	JJ
# language	language	NN
# processing	processing	NN
# From	from	IN
# Wikipedia	Wikipedia	NNP
# ,	,	,
# the	the	DT
# free	free	JJ
# encyclopedia	encyclopedia	NN
# Natural	natural	JJ
# language	language	NN
# processing	processing	NN
# -LRB-	-lrb-	-LRB-
# NLP	nlp	NN
# -RRB-	-rrb-	-RRB-
# is	be	VBZ
# a	a	DT
# field	field	NN
# of	of	IN
# computer	computer	NN
# science	science	NN
# ,	,	,
# artificial	artificial	JJ
# intelligence	intelligence	NN
# ,	,	,
# and	and	CC
# linguistics	linguistics	NNS
# concerned	concern	VBN
# with	with	IN
# the	the	DT
# interactions	interaction	NNS
# between	between	IN
# computers	computer	NNS
# and	and	CC
# human	human	JJ
# -LRB-	-lrb-	-LRB-
# natural	natural	JJ
# -RRB-	-rrb-	-RRB-
# languages	language	NNS
# .	.	.
# As	as	IN
# such	such	JJ
# ,	,	,
# NLP	nlp	NN
# is	be	VBZ
# related	relate	VBN
# to	to	TO
# the	the	DT
# area	area	NN
# of	of	IN
# humani-computer	humani-computer	JJ
# interaction	interaction	NN
# .	.	.
# Many	many	JJ
# challenges	challenge	NNS
# in	in	IN
# NLP	nlp	NN
# involve	involve	VBP
# natural	natural	JJ
# language	language	NN
# understanding	understanding	NN
# ,	,	,
# that	that	WDT
# is	be	VBZ
# ,	,	,
# enabling	enable	VBG
# computers	computer	NNS
# to	to	TO
# derive	derive	VB
# meaning	meaning	NN
# from	from	IN
# human	human	JJ
# or	or	CC
# natural	natural	JJ
# language	language	NN
# input	input	NN
# ,	,	,
# and	and	CC
# others	other	NNS
# involve	involve	VBP
# natural	natural	JJ
# language	language	NN
# generation	generation	NN
# .	.	.
# History	history	NN
# The	the	DT
# history	history	NN
# of	of	IN
# NLP	NLP	NNP
# generally	generally	RB
# starts	start	VBZ
# in	in	IN
# the	the	DT
# 1950s	1950s	CD
# ,	,	,
# although	although	IN
# work	work	NN
# can	can	MD
# be	be	VB
# found	find	VBN
# from	from	IN
# earlier	earlier	JJR
# periods	period	NNS
# .	.	.
# In	in	IN
# 1950	1950	CD
# ,	,	,
# Alan	Alan	NNP
# Turing	Turing	NNP
# published	publish	VBD
# an	a	DT
# article	article	NN
# titled	title	VBN
# ``	``	``
# Computing	Computing	NNP
# Machinery	Machinery	NNP
# and	and	CC
# Intelligence	Intelligence	NNP
# ''	''	''
# which	which	WDT
# proposed	propose	VBD
# what	what	WP
# is	be	VBZ
# now	now	RB
# called	call	VBN
# the	the	DT
# Turing	turing	JJ
# test	test	NN
# as	as	IN
# a	a	DT
# criterion	criterion	NN
# of	of	IN
# intelligence	intelligence	NN
# .	.	.
# The	the	DT
# Georgetown	Georgetown	NNP
# experiment	experiment	NN
# in	in	IN
# 1954	1954	CD
# involved	involve	VBN
# fully	fully	RB
# automatic	automatic	JJ
# translation	translation	NN
# of	of	IN
# more	more	JJR
# than	than	IN
# sixty	sixty	CD
# Russian	russian	JJ
# sentences	sentence	NNS
# into	into	IN
# English	English	NNP
# .	.	.
# The	the	DT
# authors	author	NNS
# claimed	claim	VBD
# that	that	IN
# within	within	IN
# three	three	CD
# or	or	CC
# five	five	CD
# years	year	NNS
# ,	,	,
# machine	machine	NN
# translation	translation	NN
# would	would	MD
# be	be	VB
# a	a	DT
# solved	solve	VBN
# problem	problem	NN
# .	.	.
# However	however	RB
# ,	,	,
# real	real	JJ
# progress	progress	NN
# was	be	VBD
# much	much	RB
# slower	slower	JJR
# ,	,	,
# and	and	CC
# after	after	IN
# the	the	DT
# ALPAC	ALPAC	NNP
# report	report	NN
# in	in	IN
# 1966	1966	CD
# ,	,	,
# which	which	WDT
# found	find	VBD
# that	that	IN
# ten	ten	CD
# year	year	NN
# long	long	RB
# research	research	NN
# had	have	VBD
# failed	fail	VBN
# to	to	TO
# fulfill	fulfill	VB
# the	the	DT
# expectations	expectation	NNS
# ,	,	,
# funding	fund	VBG
# for	for	IN
# machine	machine	NN
# translation	translation	NN
# was	be	VBD
# dramatically	dramatically	RB
# reduced	reduce	VBN
# .	.	.
# Little	little	JJ
# further	further	JJ
# research	research	NN
# in	in	IN
# machine	machine	NN
# translation	translation	NN
# was	be	VBD
# conducted	conduct	VBN
# until	until	IN
# the	the	DT
# late	late	JJ
# 1980s	1980	NNS
# ,	,	,
# when	when	WRB
# the	the	DT
# first	first	JJ
# statistical	statistical	JJ
# machine	machine	NN
# translation	translation	NN
# systems	system	NNS
# were	be	VBD
# developed	develop	VBN
# .	.	.
# Some	some	DT
# notably	notably	RB
# successful	successful	JJ
# NLP	nlp	NN
# systems	system	NNS
# developed	develop	VBN
# in	in	IN
# the	the	DT
# 1960s	1960	NNS
# were	be	VBD
# SHRDLU	SHRDLU	NNP
# ,	,	,
# a	a	DT
# natural	natural	JJ
# language	language	NN
# system	system	NN
# working	work	VBG
# in	in	IN
# restricted	restricted	JJ
# ``	``	``
# blocks	block	NNS
# worlds	world	NNS
# ''	''	''
# with	with	IN
# restricted	restricted	JJ
# vocabularies	vocabulary	NNS
# ,	,	,
# and	and	CC
# ELIZA	ELIZA	NNP
# ,	,	,
# a	a	DT
# simulation	simulation	NN
# of	of	IN
# a	a	DT
# Rogerian	rogerian	JJ
# psychotherapist	psychotherapist	NN
# ,	,	,
# written	write	VBN
# by	by	IN
# Joseph	Joseph	NNP
# Weizenbaum	Weizenbaum	NNP
# between	between	IN
# 1964	1964	CD
# to	to	TO
# 1966	1966	CD
# .	.	.
# Using	use	VBG
# almost	almost	RB
# no	no	DT
# information	information	NN
# about	about	IN
# human	human	JJ
# thought	thought	NN
# or	or	CC
# emotion	emotion	NN
# ,	,	,
# ELIZA	eliza	NN
# sometimes	sometimes	RB
# provided	provide	VBD
# a	a	DT
# startlingly	startlingly	RB
# human-like	human-like	JJ
# interaction	interaction	NN
# .	.	.
# When	when	WRB
# the	the	DT
# ``	``	``
# patient	patient	NN
# ''	''	''
# exceeded	exceed	VBD
# the	the	DT
# very	very	RB
# small	small	JJ
# knowledge	knowledge	NN
# base	base	NN
# ,	,	,
# ELIZA	ELIZA	NNP
# might	might	MD
# provide	provide	VB
# a	a	DT
# generic	generic	JJ
# response	response	NN
# ,	,	,
# for	for	IN
# example	example	NN
# ,	,	,
# responding	respond	VBG
# to	to	TO
# ``	``	``
# My	my	PRP$
# head	head	NN
# hurts	hurt	VBZ
# ''	''	''
# with	with	IN
# ``	``	``
# Why	why	WRB
# do	do	VBP
# you	you	PRP
# say	say	VB
# your	you	PRP$
# head	head	NN
# hurts	hurt	VBZ
# ?	?	.
# ''	''	''
# .	.	.
# During	during	IN
# the	the	DT
# 1970s	1970s	CD
# many	many	JJ
# programmers	programmer	NNS
# began	begin	VBD
# to	to	TO
# write	write	VB
# `	`	``
# conceptual	conceptual	JJ
# ontologies	ontology	NNS
# '	'	POS
# ,	,	,
# which	which	WDT
# structured	structure	VBD
# real-world	real-world	JJ
# information	information	NN
# into	into	IN
# computer-understandable	computer-understandable	JJ
# data	datum	NNS
# .	.	.
# Examples	example	NNS
# are	be	VBP
# MARGIE	MARGIE	NNP
# -LRB-	-lrb-	-LRB-
# Schank	Schank	NNP
# ,	,	,
# 1975	1975	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# SAM	SAM	NNP
# -LRB-	-lrb-	-LRB-
# Cullingford	Cullingford	NNP
# ,	,	,
# 1978	1978	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# PAM	pam	NNS
# -LRB-	-lrb-	-LRB-
# Wilensky	Wilensky	NNP
# ,	,	,
# 1978	1978	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# TaleSpin	TaleSpin	NNP
# -LRB-	-lrb-	-LRB-
# Meehan	Meehan	NNP
# ,	,	,
# 1976	1976	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# QUALM	qualm	NN
# -LRB-	-lrb-	-LRB-
# Lehnert	Lehnert	NNP
# ,	,	,
# 1977	1977	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# Politics	politics	NN
# -LRB-	-lrb-	-LRB-
# Carbonell	Carbonell	NNP
# ,	,	,
# 1979	1979	CD
# -RRB-	-rrb-	-RRB-
# ,	,	,
# and	and	CC
# Plot	plot	NN
# Units	unit	NNS
# -LRB-	-lrb-	-LRB-
# Lehnert	Lehnert	NNP
# 1981	1981	CD
# -RRB-	-rrb-	-RRB-
# .	.	.
# During	during	IN
# this	this	DT
# time	time	NN
# ,	,	,
# many	many	JJ
# chatterbots	chatterbot	NNS
# were	be	VBD
# written	write	VBN
# including	include	VBG
# PARRY	PARRY	NNP
# ,	,	,
# Racter	Racter	NNP
# ,	,	,
# and	and	CC
# Jabberwacky	Jabberwacky	NNP
# .	.	.
# Up	up	IN
# to	to	TO
# the	the	DT
# 1980s	1980	NNS
# ,	,	,
# most	most	JJS
# NLP	nlp	NNS
# systems	system	NNS
# were	be	VBD
# based	base	VBN
# on	on	IN
# complex	complex	JJ
# sets	set	NNS
# of	of	IN
# hand-written	hand-written	JJ
# rules	rule	NNS
# .	.	.
# Starting	start	VBG
# in	in	IN
# the	the	DT
# late	late	JJ
# 1980s	1980	NNS
# ,	,	,
# however	however	RB
# ,	,	,
# there	there	EX
# was	be	VBD
# a	a	DT
# revolution	revolution	NN
# in	in	IN
# NLP	nlp	NN
# with	with	IN
# the	the	DT
# introduction	introduction	NN
# of	of	IN
# machine	machine	NN
# learning	learning	NN
# algorithms	algorithm	NNS
# for	for	IN
# language	language	NN
# processing	processing	NN
# .	.	.
# This	this	DT
# was	be	VBD
# due	due	JJ
# to	to	TO
# both	both	CC
# the	the	DT
# steady	steady	JJ
# increase	increase	NN
# in	in	IN
# computational	computational	JJ
# power	power	NN
# resulting	result	VBG
# from	from	IN
# Moore	Moore	NNP
# 's	's	POS
# Law	law	NN
# and	and	CC
# the	the	DT
# gradual	gradual	JJ
# lessening	lessen	VBG
# of	of	IN
# the	the	DT
# dominance	dominance	NN
# of	of	IN
# Chomskyan	Chomskyan	NNP
# theories	theory	NNS
# of	of	IN
# linguistics	linguistics	NNS
# -LRB-	-lrb-	-LRB-
# e.g.	e.g.	FW
# transformational	transformational	JJ
# grammar	grammar	NN
# -RRB-	-rrb-	-RRB-
# ,	,	,
# whose	whose	WP$
# theoretical	theoretical	JJ
# underpinnings	underpinning	NNS
# discouraged	discourage	VBD
# the	the	DT
# sort	sort	NN
# of	of	IN
# corpus	corpus	NN
# linguistics	linguistics	NNS
# that	that	WDT
# underlies	underlie	VBZ
# the	the	DT
# machine-learning	machine-learning	JJ
# approach	approach	NN
# to	to	TO
# language	language	NN
# processing	processing	NN
# .	.	.
# Some	some	DT
# of	of	IN
# the	the	DT
# earliest-used	earliest-used	JJ
# machine	machine	NN
# learning	learn	VBG
# algorithms	algorithm	NNS
# ,	,	,
# such	such	JJ
# as	as	IN
# decision	decision	NN
# trees	tree	NNS
# ,	,	,
# produced	produce	VBD
# systems	system	NNS
# of	of	IN
# hard	hard	JJ
# if-then	if-then	JJ
# rules	rule	NNS
# similar	similar	JJ
# to	to	TO
# existing	exist	VBG
# hand-written	hand-written	JJ
# rules	rule	NNS
# .	.	.
# However	however	RB
# ,	,	,
# Part	part	NN
# of	of	IN
# speech	speech	NN
# tagging	tag	VBG
# introduced	introduce	VBN
# the	the	DT
# use	use	NN
# of	of	IN
# Hidden	Hidden	NNP
# Markov	Markov	NNP
# Models	model	NNS
# to	to	TO
# NLP	NLP	NNP
# ,	,	,
# and	and	CC
# increasingly	increasingly	RB
# ,	,	,
# research	research	NN
# has	have	VBZ
# focused	focus	VBN
# on	on	IN
# statistical	statistical	JJ
# models	model	NNS
# ,	,	,
# which	which	WDT
# make	make	VBP
# soft	soft	JJ
# ,	,	,
# probabilistic	probabilistic	JJ
# decisions	decision	NNS
# based	base	VBN
# on	on	IN
# attaching	attach	VBG
# real-valued	real-valued	JJ
# weights	weight	NNS
# to	to	TO
# the	the	DT
# features	feature	NNS
# making	make	VBG
# up	up	RP
# the	the	DT
# input	input	NN
# data	datum	NNS
# .	.	.
# The	the	DT
# cache	cache	NN
# language	language	NN
# models	model	NNS
# upon	upon	IN
# which	which	WDT
# many	many	JJ
# speech	speech	NN
# recognition	recognition	NN
# systems	system	NNS
# now	now	RB
# rely	rely	VBP
# are	be	VBP
# examples	example	NNS
# of	of	IN
# such	such	JJ
# statistical	statistical	JJ
# models	model	NNS
# .	.	.
# Such	such	JJ
# models	model	NNS
# are	be	VBP
# generally	generally	RB
# more	more	RBR
# robust	robust	JJ
# when	when	WRB
# given	give	VBN
# unfamiliar	unfamiliar	JJ
# input	input	NN
# ,	,	,
# especially	especially	RB
# input	input	NN
# that	that	WDT
# contains	contain	VBZ
# errors	error	NNS
# -LRB-	-lrb-	-LRB-
# as	as	RB
# is	be	VBZ
# very	very	RB
# common	common	JJ
# for	for	IN
# real-world	real-world	JJ
# data	datum	NNS
# -RRB-	-rrb-	-RRB-
# ,	,	,
# and	and	CC
# produce	produce	VB
# more	more	JJR
# reliable	reliable	JJ
# results	result	NNS
# when	when	WRB
# integrated	integrate	VBN
# into	into	IN
# a	a	DT
# larger	larger	JJR
# system	system	NN
# comprising	comprise	VBG
# multiple	multiple	JJ
# subtasks	subtask	NNS
# .	.	.
# Many	many	JJ
# of	of	IN
# the	the	DT
# notable	notable	JJ
# early	early	JJ
# successes	success	NNS
# occurred	occur	VBD
# in	in	IN
# the	the	DT
# field	field	NN
# of	of	IN
# machine	machine	NN
# translation	translation	NN
# ,	,	,
# due	due	JJ
# especially	especially	RB
# to	to	TO
# work	work	VB
# at	at	IN
# IBM	IBM	NNP
# Research	Research	NNP
# ,	,	,
# where	where	WRB
# successively	successively	RB
# more	more	RBR
# complicated	complicated	JJ
# statistical	statistical	JJ
# models	model	NNS
# were	be	VBD
# developed	develop	VBN
# .	.	.
# These	these	DT
# systems	system	NNS
# were	be	VBD
# able	able	JJ
# to	to	TO
# take	take	VB
# advantage	advantage	NN
# of	of	IN
# existing	exist	VBG
# multilingual	multilingual	JJ
# textual	textual	JJ
# corpora	corpora	NN
# that	that	WDT
# had	have	VBD
# been	be	VBN
# produced	produce	VBN
# by	by	IN
# the	the	DT
# Parliament	Parliament	NNP
# of	of	IN
# Canada	Canada	NNP
# and	and	CC
# the	the	DT
# European	European	NNP
# Union	Union	NNP
# as	as	IN
# a	a	DT
# result	result	NN
# of	of	IN
# laws	law	NNS
# calling	call	VBG
# for	for	IN
# the	the	DT
# translation	translation	NN
# of	of	IN
# all	all	DT
# governmental	governmental	JJ
# proceedings	proceedings	NNS
# into	into	IN
# all	all	DT
# official	official	JJ
# languages	language	NNS
# of	of	IN
# the	the	DT
# corresponding	corresponding	JJ
# systems	system	NNS
# of	of	IN
# government	government	NN
# .	.	.
# However	however	RB
# ,	,	,
# most	most	RBS
# other	other	JJ
# systems	system	NNS
# depended	depend	VBD
# on	on	IN
# corpora	corpora	NN
# specifically	specifically	RB
# developed	develop	VBD
# for	for	IN
# the	the	DT
# tasks	task	NNS
# implemented	implement	VBN
# by	by	IN
# these	these	DT
# systems	system	NNS
# ,	,	,
# which	which	WDT
# was	be	VBD
# -LRB-	-lrb-	-LRB-
# and	and	CC
# often	often	RB
# continues	continue	VBZ
# to	to	TO
# be	be	VB
# -RRB-	-rrb-	-RRB-
# a	a	DT
# major	major	JJ
# limitation	limitation	NN
# in	in	IN
# the	the	DT
# success	success	NN
# of	of	IN
# these	these	DT
# systems	system	NNS
# .	.	.
# As	as	IN
# a	a	DT
# result	result	NN
# ,	,	,
# a	a	DT
# great	great	JJ
# deal	deal	NN
# of	of	IN
# research	research	NN
# has	have	VBZ
# gone	go	VBN
# into	into	IN
# methods	method	NNS
# of	of	IN
# more	more	JJR
# effectively	effectively	RB
# learning	learn	VBG
# from	from	IN
# limited	limited	JJ
# amounts	amount	NNS
# of	of	IN
# data	datum	NNS
# .	.	.
# Recent	recent	JJ
# research	research	NN
# has	have	VBZ
# increasingly	increasingly	RB
# focused	focus	VBN
# on	on	IN
# unsupervised	unsupervised	JJ
# and	and	CC
# semi-supervised	semi-supervised	JJ
# learning	learning	NN
# algorithms	algorithm	NNS
# .	.	.
# Such	such	JJ
# algorithms	algorithm	NNS
# are	be	VBP
# able	able	JJ
# to	to	TO
# learn	learn	VB
# from	from	IN
# data	datum	NNS
# that	that	WDT
# has	have	VBZ
# not	not	RB
# been	be	VBN
# hand-annotated	hand-annotate	VBN
# with	with	IN
# the	the	DT
# desired	desire	VBN
# answers	answer	NNS
# ,	,	,
# or	or	CC
# using	use	VBG
# a	a	DT
# combination	combination	NN
# of	of	IN
# annotated	annotated	JJ
# and	and	CC
# non-annotated	non-annotated	JJ
# data	datum	NNS
# .	.	.
# Generally	generally	RB
# ,	,	,
# this	this	DT
# task	task	NN
# is	be	VBZ
# much	much	RB
# more	more	RBR
# difficult	difficult	JJ
# than	than	IN
# supervised	supervised	JJ
# learning	learning	NN
# ,	,	,
# and	and	CC
# typically	typically	RB
# produces	produce	VBZ
# less	less	JJR
# accurate	accurate	JJ
# results	result	NNS
# for	for	IN
# a	a	DT
# given	give	VBN
# amount	amount	NN
# of	of	IN
# input	input	NN
# data	datum	NNS
# .	.	.
# However	however	RB
# ,	,	,
# there	there	EX
# is	be	VBZ
# an	a	DT
# enormous	enormous	JJ
# amount	amount	NN
# of	of	IN
# non-annotated	non-annotated	JJ
# data	datum	NNS
# available	available	JJ
# -LRB-	-lrb-	-LRB-
# including	include	VBG
# ,	,	,
# among	among	IN
# other	other	JJ
# things	thing	NNS
# ,	,	,
# the	the	DT
# entire	entire	JJ
# content	content	NN
# of	of	IN
# the	the	DT
# World	World	NNP
# Wide	wide	NN
# Web	web	NN
# -RRB-	-rrb-	-RRB-
# ,	,	,
# which	which	WDT
# can	can	MD
# often	often	RB
# make	make	VB
# up	up	RP
# for	for	IN
# the	the	DT
# inferior	inferior	JJ
# results	result	NNS
# .	.	.
# NLP	nlp	NN
# using	use	VBG
# machine	machine	NN
# learning	learning	NN
# Modern	Modern	NNP
# NLP	NLP	NNP
# algorithms	algorithm	NNS
# are	be	VBP
# based	base	VBN
# on	on	IN
# machine	machine	NN
# learning	learning	NN
# ,	,	,
# especially	especially	RB
# statistical	statistical	JJ
# machine	machine	NN
# learning	learning	NN
# .	.	.
# The	the	DT
# paradigm	paradigm	NN
# of	of	IN
# machine	machine	NN
# learning	learning	NN
# is	be	VBZ
# different	different	JJ
# from	from	IN
# that	that	DT
# of	of	IN
# most	most	RBS
# prior	prior	JJ
# attempts	attempt	NNS
# at	at	IN
# language	language	NN
# processing	processing	NN
# .	.	.
# Prior	prior	RB
# implementations	implementation	NNS
# of	of	IN
# language-processing	language-processing	JJ
# tasks	task	NNS
# typically	typically	RB
# involved	involve	VBD
# the	the	DT
# direct	direct	JJ
# hand	hand	NN
# coding	coding	NN
# of	of	IN
# large	large	JJ
# sets	set	NNS
# of	of	IN
# rules	rule	NNS
# .	.	.
# The	the	DT
# machine-learning	machine-learning	JJ
# paradigm	paradigm	NN
# calls	call	VBZ
# instead	instead	RB
# for	for	IN
# using	use	VBG
# general	general	JJ
# learning	learning	NN
# algorithms	algorithm	NNS
# -	-	:
# often	often	RB
# ,	,	,
# although	although	IN
# not	not	RB
# always	always	RB
# ,	,	,
# grounded	ground	VBN
# in	in	IN
# statistical	statistical	JJ
# inference	inference	NN
# -	-	:
# to	to	TO
# automatically	automatically	RB
# learn	learn	VB
# such	such	JJ
# rules	rule	NNS
# through	through	IN
# the	the	DT
# analysis	analysis	NN
# of	of	IN
# large	large	JJ
# corpora	corpora	NN
# of	of	IN
# typical	typical	JJ
# real-world	real-world	JJ
# examples	example	NNS
# .	.	.
# A	a	DT
# corpus	corpus	NN
# -LRB-	-lrb-	-LRB-
# plural	plural	NN
# ,	,	,
# ``	``	``
# corpora	corpora	NN
# ''	''	''
# -RRB-	-rrb-	-RRB-
# is	be	VBZ
# a	a	DT
# set	set	NN
# of	of	IN
# documents	document	NNS
# -LRB-	-lrb-	-LRB-
# or	or	CC
# sometimes	sometimes	RB
# ,	,	,
# individual	individual	JJ
# sentences	sentence	NNS
# -RRB-	-rrb-	-RRB-
# that	that	WDT
# have	have	VBP
# been	be	VBN
# hand-annotated	hand-annotated	JJ
# with	with	IN
# the	the	DT
# correct	correct	JJ
# values	value	NNS
# to	to	TO
# be	be	VB
# learned	learn	VBN
# .	.	.
# Many	many	JJ
# different	different	JJ
# classes	class	NNS
# of	of	IN
# machine	machine	NN
# learning	learning	NN
# algorithms	algorithm	NNS
# have	have	VBP
# been	be	VBN
# applied	apply	VBN
# to	to	TO
# NLP	nlp	NN
# tasks	task	NNS
# .	.	.
# These	these	DT
# algorithms	algorithm	NNS
# take	take	VBP
# as	as	RB
# input	input	NN
# a	a	DT
# large	large	JJ
# set	set	NN
# of	of	IN
# ``	``	``
# features	feature	NNS
# ''	''	''
# that	that	WDT
# are	be	VBP
# generated	generate	VBN
# from	from	IN
# the	the	DT
# input	input	NN
# data	datum	NNS
# .	.	.
# Some	some	DT
# of	of	IN
# the	the	DT
# earliest-used	earliest-used	JJ
# algorithms	algorithm	NNS
# ,	,	,
# such	such	JJ
# as	as	IN
# decision	decision	NN
# trees	tree	NNS
# ,	,	,
# produced	produce	VBD
# systems	system	NNS
# of	of	IN
# hard	hard	JJ
# if-then	if-then	JJ
# rules	rule	NNS
# similar	similar	JJ
# to	to	TO
# the	the	DT
# systems	system	NNS
# of	of	IN
# hand-written	hand-written	JJ
# rules	rule	NNS
# that	that	WDT
# were	be	VBD
# then	then	RB
# common	common	JJ
# .	.	.
# Increasingly	increasingly	RB
# ,	,	,
# however	however	RB
# ,	,	,
# research	research	NN
# has	have	VBZ
# focused	focus	VBN
# on	on	IN
# statistical	statistical	JJ
# models	model	NNS
# ,	,	,
# which	which	WDT
# make	make	VBP
# soft	soft	JJ
# ,	,	,
# probabilistic	probabilistic	JJ
# decisions	decision	NNS
# based	base	VBN
# on	on	IN
# attaching	attach	VBG
# real-valued	real-valued	JJ
# weights	weight	NNS
# to	to	TO
# each	each	DT
# input	input	NN
# feature	feature	NN
# .	.	.
# Such	such	JJ
# models	model	NNS
# have	have	VBP
# the	the	DT
# advantage	advantage	NN
# that	that	IN
# they	they	PRP
# can	can	MD
# express	express	VB
# the	the	DT
# relative	relative	JJ
# certainty	certainty	NN
# of	of	IN
# many	many	JJ
# different	different	JJ
# possible	possible	JJ
# answers	answer	NNS
# rather	rather	RB
# than	than	IN
# only	only	RB
# one	one	CD
# ,	,	,
# producing	produce	VBG
# more	more	JJR
# reliable	reliable	JJ
# results	result	NNS
# when	when	WRB
# such	such	PDT
# a	a	DT
# model	model	NN
# is	be	VBZ
# included	include	VBN
# as	as	IN
# a	a	DT
# component	component	NN
# of	of	IN
# a	a	DT
# larger	larger	JJR
# system	system	NN
# .	.	.
# Systems	Systems	NNPS
# based	base	VBN
# on	on	IN
# machine-learning	machine-learning	JJ
# algorithms	algorithm	NNS
# have	have	VBP
# many	many	JJ
# advantages	advantage	NNS
# over	over	IN
# hand-produced	hand-produced	JJ
# rules	rule	NNS
# :	:	:
# The	the	DT
# learning	learn	VBG
# procedures	procedure	NNS
# used	use	VBN
# during	during	IN
# machine	machine	NN
# learning	learning	NN
# automatically	automatically	RB
# focus	focus	VB
# on	on	IN
# the	the	DT
# most	most	RBS
# common	common	JJ
# cases	case	NNS
# ,	,	,
# whereas	whereas	IN
# when	when	WRB
# writing	write	VBG
# rules	rule	NNS
# by	by	IN
# hand	hand	NN
# it	it	PRP
# is	be	VBZ
# often	often	RB
# not	not	RB
# obvious	obvious	JJ
# at	at	IN
# all	all	DT
# where	where	WRB
# the	the	DT
# effort	effort	NN
# should	should	MD
# be	be	VB
# directed	direct	VBN
# .	.	.
# Automatic	Automatic	NNP
# learning	learn	VBG
# procedures	procedure	NNS
# can	can	MD
# make	make	VB
# use	use	NN
# of	of	IN
# statistical	statistical	JJ
# inference	inference	NN
# algorithms	algorithm	NNS
# to	to	TO
# produce	produce	VB
# models	model	NNS
# that	that	WDT
# are	be	VBP
# robust	robust	JJ
# to	to	TO
# unfamiliar	unfamiliar	JJ
# input	input	NN
# -LRB-	-lrb-	-LRB-
# e.g.	e.g.	FW
# containing	contain	VBG
# words	word	NNS
# or	or	CC
# structures	structure	NNS
# that	that	WDT
# have	have	VBP
# not	not	RB
# been	be	VBN
# seen	see	VBN
# before	before	IN
# -RRB-	-rrb-	-RRB-
# and	and	CC
# to	to	TO
# erroneous	erroneous	JJ
# input	input	NN
# -LRB-	-lrb-	-LRB-
# e.g.	e.g.	FW
# with	with	IN
# misspelled	misspell	VBN
# words	word	NNS
# or	or	CC
# words	word	NNS
# accidentally	accidentally	RB
# omitted	omit	VBN
# -RRB-	-rrb-	-RRB-
# .	.	.
# Generally	generally	RB
# ,	,	,
# handling	handle	VBG
# such	such	JJ
# input	input	NN
# gracefully	gracefully	RB
# with	with	IN
# hand-written	hand-written	JJ
# rules	rule	NNS
# --	--	:
# or	or	CC
# more	more	JJR
# generally	generally	RB
# ,	,	,
# creating	create	VBG
# systems	system	NNS
# of	of	IN
# hand-written	hand-written	JJ
# rules	rule	NNS
# that	that	WDT
# make	make	VBP
# soft	soft	JJ
# decisions	decision	NNS
# --	--	:
# extremely	extremely	RB
# difficult	difficult	JJ
# ,	,	,
# error-prone	error-prone	JJ
# and	and	CC
# time-consuming	time-consuming	JJ
# .	.	.
# Systems	Systems	NNPS
# based	base	VBN
# on	on	IN
# automatically	automatically	RB
# learning	learn	VBG
# the	the	DT
# rules	rule	NNS
# can	can	MD
# be	be	VB
# made	make	VBN
# more	more	RBR
# accurate	accurate	JJ
# simply	simply	RB
# by	by	IN
# supplying	supply	VBG
# more	more	JJR
# input	input	NN
# data	datum	NNS
# .	.	.
# However	however	RB
# ,	,	,
# systems	system	NNS
# based	base	VBN
# on	on	IN
# hand-written	hand-written	JJ
# rules	rule	NNS
# can	can	MD
# only	only	RB
# be	be	VB
# made	make	VBN
# more	more	RBR
# accurate	accurate	JJ
# by	by	IN
# increasing	increase	VBG
# the	the	DT
# complexity	complexity	NN
# of	of	IN
# the	the	DT
# rules	rule	NNS
# ,	,	,
# which	which	WDT
# is	be	VBZ
# a	a	DT
# much	much	RB
# more	more	RBR
# difficult	difficult	JJ
# task	task	NN
# .	.	.
# In	in	IN
# particular	particular	JJ
# ,	,	,
# there	there	EX
# is	be	VBZ
# a	a	DT
# limit	limit	NN
# to	to	TO
# the	the	DT
# complexity	complexity	NN
# of	of	IN
# systems	system	NNS
# based	base	VBN
# on	on	IN
# hand-crafted	hand-crafted	JJ
# rules	rule	NNS
# ,	,	,
# beyond	beyond	IN
# which	which	WDT
# the	the	DT
# systems	system	NNS
# become	become	VBP
# more	more	RBR
# and	and	CC
# more	more	RBR
# unmanageable	unmanageable	JJ
# .	.	.
# However	however	RB
# ,	,	,
# creating	create	VBG
# more	more	JJR
# data	datum	NNS
# to	to	TO
# input	input	NN
# to	to	TO
# machine-learning	machine-learning	JJ
# systems	system	NNS
# simply	simply	RB
# requires	require	VBZ
# a	a	DT
# corresponding	corresponding	JJ
# increase	increase	NN
# in	in	IN
# the	the	DT
# number	number	NN
# of	of	IN
# man-hours	man-hours	NN
# worked	work	VBD
# ,	,	,
# generally	generally	RB
# without	without	IN
# significant	significant	JJ
# increases	increase	NNS
# in	in	IN
# the	the	DT
# complexity	complexity	NN
# of	of	IN
# the	the	DT
# annotation	annotation	NN
# process	process	NN
# .	.	.
# The	the	DT
# subfield	subfield	NN
# of	of	IN
# NLP	NLP	NNP
# devoted	devote	VBN
# to	to	IN
# learning	learn	VBG
# approaches	approach	NNS
# is	be	VBZ
# known	know	VBN
# as	as	IN
# Natural	natural	JJ
# Language	language	NN
# Learning	Learning	NNP
# -LRB-	-lrb-	-LRB-
# NLL	NLL	NNP
# -RRB-	-rrb-	-RRB-
# and	and	CC
# its	its	PRP$
# conference	conference	NN
# CoNLL	conll	NN
# and	and	CC
# peak	peak	NN
# body	body	NN
# SIGNLL	SIGNLL	NNP
# are	be	VBP
# sponsored	sponsor	VBN
# by	by	IN
# ACL	acl	NN
# ,	,	,
# recognizing	recognize	VBG
# also	also	RB
# their	they	PRP$
# links	link	NNS
# with	with	IN
# Computational	computational	JJ
# Linguistics	linguistics	NNS
# and	and	CC
# Language	Language	NNP
# Acquisition	Acquisition	NNP
# .	.	.
# When	when	WRB
# the	the	DT
# aims	aim	NNS
# of	of	IN
# computational	computational	JJ
# language	language	NN
# learning	learn	VBG
# research	research	NN
# is	be	VBZ
# to	to	TO
# understand	understand	VB
# more	more	JJR
# about	about	IN
# human	human	JJ
# language	language	NN
# acquisition	acquisition	NN
# ,	,	,
# or	or	CC
# psycholinguistics	psycholinguistic	NNS
# ,	,	,
# NLL	nll	NN
# overlaps	overlap	VBZ
# into	into	IN
# the	the	DT
# related	related	JJ
# field	field	NN
# of	of	IN
# Computational	Computational	NNP
# Psycholinguistics	Psycholinguistics	NNPS
# .	.	.

# %% [markdown]
# ## 55. 固有表現抽出

# %%
for token in root.iter('token'):
    word = token[0].text
    ner = token[5].text
    
    if ner == 'PERSON':
        print(word)
# Out:
# Alan
# Turing
# Joseph
# Weizenbaum
# MARGIE
# Schank
# Wilensky
# Meehan
# Lehnert
# Carbonell
# Lehnert
# Racter
# Jabberwacky
# Moore

# %% [markdown]
# ## 56. 共参照解析

# %% [markdown]
# ### 構造体のまま置換するのは大変なので、文字列の置換とする。

# %%
# coreferenceの取得

corefs = []
for coref in root.iter('coreference'):
    corefs.append(coref)

# %%
# sentenceの取得
sents = {}

for sent in root.iter('sentence'):
    
    try:
        sent_id = sent.attrib['id']
    except KeyError:
        continue
    
    tokens = []
    for token in sent.iter('token'):
          tokens.append(token[0].text)
    
    sents[sent_id] = tokens

# %%
for coref in corefs:
    for mention in coref.iter('mention'):
        rep = ''
        
        # 代表参照表現を取得
        try: 
            if mention.attrib['representative'] == 'true':
                rep_text = mention[4].text
        
        # 参照表現を代表参照表現で置き換える
        except KeyError:
            sent_id = mention[0].text
            start = mention[1].text
            end = mention[2].text
            text = mention[4].text
            
            #　記法： 参照表現 （ 代表参照表現 ) 
            new_text = '{} ( {} )'.format(text, rep_text) 
            new_text = new_text.split(' ')
            
            sent = sents[sent_id]
            new_sent = sent[:int(start)-1] + new_text + sent[int(end):]
            
            print(new_sent)
# Out:
# ['Natural', 'language', 'processing', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', 'is', 'a', 'field', 'of', 'computer', 'science', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')', 'artificial', 'intelligence', ',', 'and', 'linguistics', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', '-LRB-', 'natural', '-RRB-', 'languages', '.']
# ['Starting', 'in', 'the', 'late', '1980s', ',', 'however', ',', 'there', 'was', 'a', 'revolution', 'in', 'NLP', 'with', 'the', 'introduction', 'of', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['This', 'was', 'due', 'to', 'both', 'the', 'steady', 'increase', 'in', 'computational', 'power', 'resulting', 'from', 'Moore', "'s", 'Law', 'and', 'the', 'gradual', 'lessening', 'of', 'the', 'dominance', 'of', 'Chomskyan', 'theories', 'of', 'linguistics', '-LRB-', 'e.g.', 'transformational', 'grammar', '-RRB-', ',', 'whose', 'theoretical', 'underpinnings', 'discouraged', 'the', 'sort', 'of', 'corpus', 'linguistics', 'that', 'underlies', 'the', 'machine-learning', 'approach', 'to', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['The', 'paradigm', 'of', 'machine', 'learning', 'is', 'different', 'from', 'that', 'of', 'most', 'prior', 'attempts', 'at', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['Many', 'challenges', 'in', 'NLP', 'involve', 'natural', 'language', 'understanding', ',', 'that', 'is', ',', 'enabling', 'computers', '(', 'computers', ')', 'derive', 'meaning', 'from', 'human', 'or', 'natural', 'language', 'input', ',', 'and', 'others', 'involve', 'natural', 'language', 'generation', '.']
# ['Up', 'to', 'the', '1980s', ',', 'most', 'NLP', '(', 'NLP', ')', 'were', 'based', 'on', 'complex', 'sets', 'of', 'hand-written', 'rules', '.']
# ['However', ',', 'Part', 'of', 'speech', 'tagging', 'introduced', 'the', 'use', 'of', 'Hidden', 'Markov', 'Models', 'to', 'NLP', '(', 'NLP', ')', 'and', 'increasingly', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'the', 'features', 'making', 'up', 'the', 'input', 'data', '.']
# ['In', '1950', ',', 'Alan', 'Turing', 'published', 'an', 'article', 'titled', '``', 'Computing', 'Machinery', 'and', 'Intelligence', "''", 'which', 'proposed', 'what', 'is', 'now', 'called', 'the', 'Turing', '(', 'Alan', 'Turing', ')', 'as', 'a', 'criterion', 'of', 'intelligence', '.']
# ['The', 'authors', 'claimed', 'that', 'within', 'three', 'or', 'five', 'years', ',', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'be', 'a', 'solved', 'problem', '.']
# ['Little', 'further', 'research', 'in', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'conducted', 'until', 'the', 'late', '1980s', ',', 'when', 'the', 'first', 'statistical', 'machine', 'translation', 'systems', 'were', 'developed', '.']
# ['Many', 'of', 'the', 'notable', 'early', 'successes', 'occurred', 'in', 'the', 'field', 'of', 'machine', 'translation', ',', 'due', 'especially', 'to', 'work', 'at', 'IBM', 'Research', ',', 'where', 'successively', 'more', 'complicated', 'statistical', 'models', 'were', 'developed', '(', 'a', 'solved', 'problem', ')']
# ['Many', 'of', 'the', 'notable', 'early', 'successes', 'occurred', 'in', 'the', 'field', 'of', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'due', 'especially', 'to', 'work', 'at', 'IBM', 'Research', ',', 'where', 'successively', 'more', 'complicated', 'statistical', 'models', 'were', 'developed', '.']
# ['Up', 'to', 'the', '1980s', '(', 'the', 'late', '1980s', ')', 'most', 'NLP', 'systems', 'were', 'based', 'on', 'complex', 'sets', 'of', 'hand-written', 'rules', '.']
# ['Starting', 'in', 'the', 'late', '1980s', '(', 'the', 'late', '1980s', ')', 'however', ',', 'there', 'was', 'a', 'revolution', 'in', 'NLP', 'with', 'the', 'introduction', 'of', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', '.']
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', '(', 'ELIZA', ')', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', 'hurts', '?', "''"]
# ['Some', 'notably', 'successful', 'NLP', 'systems', 'developed', 'in', 'the', '1960s', 'were', 'SHRDLU', ',', 'a', 'natural', 'language', 'system', 'working', 'in', 'restricted', '``', 'blocks', 'worlds', "''", 'with', 'restricted', 'vocabularies', '(', 'SHRDLU', ')', 'and', 'ELIZA', ',', 'a', 'simulation', 'of', 'a', 'Rogerian', 'psychotherapist', ',', 'written', 'by', 'Joseph', 'Weizenbaum', 'between', '1964', 'to', '1966', '.']
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', '(', 'the', '``', 'patient', "''", ')', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', 'hurts', '?', "''"]
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', '(', 'My', 'head', ')', '?', "''"]
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', '(', 'you', ')', 'hurts', '?', "''"]
# ['Examples', 'are', 'MARGIE', '-LRB-', 'Schank', ',', '1975', '-RRB-', ',', 'SAM', '-LRB-', 'Cullingford', ',', '1978', '-RRB-', ',', 'PAM', '-LRB-', 'Wilensky', ',', '1978', '-RRB-', ',', 'TaleSpin', '-LRB-', 'Meehan', ',', '1976', '-RRB-', ',', 'QUALM', '-LRB-', 'Lehnert', ',', '1977', '-RRB-', ',', 'Politics', '-LRB-', 'Carbonell', ',', '1979', '-RRB-', ',', 'and', 'Plot', 'Units', '-LRB-', 'Lehnert', '1981', '(', 'Lehnert', ')', '.']
# ['Examples', 'are', 'MARGIE', '-LRB-', 'Schank', ',', '1975', '-RRB-', ',', 'SAM', '-LRB-', 'Cullingford', ',', '1978', '-RRB-', ',', 'PAM', '-LRB-', 'Wilensky', ',', '1978', '(', '1978', ')', ',', 'TaleSpin', '-LRB-', 'Meehan', ',', '1976', '-RRB-', ',', 'QUALM', '-LRB-', 'Lehnert', ',', '1977', '-RRB-', ',', 'Politics', '-LRB-', 'Carbonell', ',', '1979', '-RRB-', ',', 'and', 'Plot', 'Units', '-LRB-', 'Lehnert', '1981', '-RRB-', '.']
# ['Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', ',', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'the', 'systems', 'of', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'were', 'then', 'common', '.']
# ['Generally', ',', 'handling', 'such', 'input', 'gracefully', 'with', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'or', 'more', 'generally', ',', 'creating', 'systems', 'of', 'hand-written', 'rules', 'that', 'make', 'soft', 'decisions', '--', 'extremely', 'difficult', ',', 'error-prone', 'and', 'time-consuming', '.']
# ['Generally', ',', 'handling', 'such', 'input', 'gracefully', 'with', 'hand-written', 'rules', '--', 'or', 'more', 'generally', ',', 'creating', 'systems', 'of', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'make', 'soft', 'decisions', '--', 'extremely', 'difficult', ',', 'error-prone', 'and', 'time-consuming', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['Some', 'of', 'the', 'earliest-used', 'machine', 'learning', 'algorithms', '(', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', ')', 'such', 'as', 'decision', 'trees', ',', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', '.']
# ['Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', '(', 'decision', 'trees', ')', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'the', 'systems', 'of', 'hand-written', 'rules', 'that', 'were', 'then', 'common', '.']
# ['Prior', 'implementations', 'of', 'language-processing', 'tasks', 'typically', 'involved', 'the', 'direct', 'hand', 'coding', 'of', 'large', 'sets', 'of', 'rules', '(', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', ')']
# ['Systems', 'based', 'on', 'machine-learning', 'algorithms', 'have', 'many', 'advantages', 'over', 'hand-produced', 'rules', ':', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', 'automatically', 'focus', 'on', 'the', 'most', 'common', 'cases', ',', 'whereas', 'when', 'writing', 'rules', '(', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', ')', 'hand', 'it', 'is', 'often', 'not', 'obvious', 'at', 'all', 'where', 'the', 'effort', 'should', 'be', 'directed', '.']
# ['However', ',', 'Part', 'of', 'speech', 'tagging', 'introduced', 'the', 'use', 'of', 'Hidden', 'Markov', 'Models', 'to', 'NLP', ',', 'and', 'increasingly', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'the', 'features', 'making', 'up', 'the', 'input', 'data', '(', 'statistical', 'models', ')']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '(', 'statistical', 'models', ')']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', '(', 'statistical', 'models', ')', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '.']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', '(', 'soft', ',', 'probabilistic', 'decisions', ')', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '.']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', '(', 'real-valued', 'weights', ')', 'each', 'input', 'feature', '.']
# ['These', 'algorithms', 'take', 'as', 'input', 'a', 'large', 'set', 'of', '``', 'features', "''", 'that', 'are', 'generated', 'from', 'the', 'input', 'data', '(', 'the', 'input', 'data', ')']
# ['The', 'cache', 'language', 'models', 'upon', 'which', 'many', 'speech', 'recognition', 'systems', 'now', 'rely', 'are', 'examples', 'of', 'such', 'statistical', 'models', '(', 'The', 'cache', 'language', 'models', 'upon', 'which', 'many', 'speech', 'recognition', 'systems', 'now', 'rely', ')']
# ['These', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')', 'able', 'to', 'take', 'advantage', 'of', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', '.']
# ['However', ',', 'most', 'other', 'systems', 'depended', 'on', 'corpora', 'specifically', 'developed', 'for', 'the', 'tasks', 'implemented', 'by', 'these', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')', 'which', 'was', '-LRB-', 'and', 'often', 'continues', 'to', 'be', '-RRB-', 'a', 'major', 'limitation', 'in', 'the', 'success', 'of', 'these', 'systems', '.']
# ['However', ',', 'most', 'other', 'systems', 'depended', 'on', 'corpora', 'specifically', 'developed', 'for', 'the', 'tasks', 'implemented', 'by', 'these', 'systems', ',', 'which', 'was', '-LRB-', 'and', 'often', 'continues', 'to', 'be', '-RRB-', 'a', 'major', 'limitation', 'in', 'the', 'success', 'of', 'these', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')']
# ['Such', 'models', 'are', 'generally', 'more', 'robust', 'when', 'given', 'unfamiliar', 'input', ',', 'especially', 'input', 'that', 'contains', 'errors', '-LRB-', 'as', 'is', 'very', 'common', 'for', 'real-world', 'data', '-RRB-', '(', 'as', 'input', ')', 'and', 'produce', 'more', 'reliable', 'results', 'when', 'integrated', 'into', 'a', 'larger', 'system', 'comprising', 'multiple', 'subtasks', '.']
# ['These', 'systems', 'were', 'able', 'to', 'take', 'advantage', 'of', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', '(', 'the', 'advantage', ')']
# ['A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '(', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', ')', 'is', 'a', 'set', 'of', 'documents', '-LRB-', 'or', 'sometimes', ',', 'individual', 'sentences', '-RRB-', 'that', 'have', 'been', 'hand-annotated', 'with', 'the', 'correct', 'values', 'to', 'be', 'learned', '.']
# ['Such', 'algorithms', 'are', 'able', 'to', 'learn', 'from', 'data', 'that', 'has', 'not', 'been', 'hand-annotated', 'with', 'the', 'desired', 'answers', '(', 'data', ')', 'or', 'using', 'a', 'combination', 'of', 'annotated', 'and', 'non-annotated', 'data', '.']
# ['Many', 'different', 'classes', 'of', 'machine', 'learning', 'algorithms', '(', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', ')', 'been', 'applied', 'to', 'NLP', 'tasks', '.']
# ['These', 'algorithms', '(', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', ')', 'as', 'input', 'a', 'large', 'set', 'of', '``', 'features', "''", 'that', 'are', 'generated', 'from', 'the', 'input', 'data', '.']
# ['NLP', 'using', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', 'are', 'based', 'on', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'especially', 'statistical', 'machine', 'learning', '.']
# ['The', 'paradigm', 'of', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'different', 'from', 'that', 'of', 'most', 'prior', 'attempts', 'at', 'language', 'processing', '.']
# ['Systems', 'based', 'on', 'machine-learning', 'algorithms', 'have', 'many', 'advantages', 'over', 'hand-produced', 'rules', ':', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'focus', 'on', 'the', 'most', 'common', 'cases', ',', 'whereas', 'when', 'writing', 'rules', 'by', 'hand', 'it', 'is', 'often', 'not', 'obvious', 'at', 'all', 'where', 'the', 'effort', 'should', 'be', 'directed', '.']
# ['A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '-RRB-', 'is', 'a', 'set', 'of', 'documents', '-LRB-', 'or', 'sometimes', ',', 'individual', 'sentences', '-RRB-', 'that', 'have', 'been', 'hand-annotated', 'with', 'the', 'correct', 'values', 'to', 'be', 'learned', '(', 'A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '-RRB-', ')']
# ['Such', 'models', 'have', 'the', 'advantage', 'that', 'they', '(', 'Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', ')', 'express', 'the', 'relative', 'certainty', 'of', 'many', 'different', 'possible', 'answers', 'rather', 'than', 'only', 'one', ',', 'producing', 'more', 'reliable', 'results', 'when', 'such', 'a', 'model', 'is', 'included', 'as', 'a', 'component', 'of', 'a', 'larger', 'system', '.']
# ['However', ',', 'creating', 'more', 'data', 'to', 'input', 'to', 'machine-learning', 'systems', '(', 'Systems', 'based', 'on', 'machine-learning', 'algorithms', ')', 'requires', 'a', 'corresponding', 'increase', 'in', 'the', 'number', 'of', 'man-hours', 'worked', ',', 'generally', 'without', 'significant', 'increases', 'in', 'the', 'complexity', 'of', 'the', 'annotation', 'process', '.']
# ['Automatic', 'learning', 'procedures', '(', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', ')', 'make', 'use', 'of', 'statistical', 'inference', 'algorithms', 'to', 'produce', 'models', 'that', 'are', 'robust', 'to', 'unfamiliar', 'input', '-LRB-', 'e.g.', 'containing', 'words', 'or', 'structures', 'that', 'have', 'not', 'been', 'seen', 'before', '-RRB-', 'and', 'to', 'erroneous', 'input', '-LRB-', 'e.g.', 'with', 'misspelled', 'words', 'or', 'words', 'accidentally', 'omitted', '-RRB-', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', 'can', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '(', 'the', 'rules', ')']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', 'can', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', '(', 'the', 'rules', ')', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', '(', 'the', 'systems', ')', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['The', 'subfield', 'of', 'NLP', 'devoted', 'to', 'learning', 'approaches', 'is', 'known', 'as', 'Natural', 'Language', 'Learning', '-LRB-', 'NLL', '-RRB-', 'and', 'its', '(', 'Natural', 'Language', 'Learning', '-LRB-', 'NLL', '-RRB-', ')', 'CoNLL', 'and', 'peak', 'body', 'SIGNLL', 'are', 'sponsored', 'by', 'ACL', ',', 'recognizing', 'also', 'their', 'links', 'with', 'Computational', 'Linguistics', 'and', 'Language', 'Acquisition', '.']
# ['Natural', 'language', 'processing', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', 'is', 'a', 'field', 'of', 'computer', 'science', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')', 'artificial', 'intelligence', ',', 'and', 'linguistics', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', '-LRB-', 'natural', '-RRB-', 'languages', '.']
# ['Starting', 'in', 'the', 'late', '1980s', ',', 'however', ',', 'there', 'was', 'a', 'revolution', 'in', 'NLP', 'with', 'the', 'introduction', 'of', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['This', 'was', 'due', 'to', 'both', 'the', 'steady', 'increase', 'in', 'computational', 'power', 'resulting', 'from', 'Moore', "'s", 'Law', 'and', 'the', 'gradual', 'lessening', 'of', 'the', 'dominance', 'of', 'Chomskyan', 'theories', 'of', 'linguistics', '-LRB-', 'e.g.', 'transformational', 'grammar', '-RRB-', ',', 'whose', 'theoretical', 'underpinnings', 'discouraged', 'the', 'sort', 'of', 'corpus', 'linguistics', 'that', 'underlies', 'the', 'machine-learning', 'approach', 'to', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['The', 'paradigm', 'of', 'machine', 'learning', 'is', 'different', 'from', 'that', 'of', 'most', 'prior', 'attempts', 'at', 'language', 'processing', '(', 'the', 'free', 'encyclopedia', 'Natural', 'language', 'processing', '-LRB-', 'NLP', '-RRB-', ')']
# ['Many', 'challenges', 'in', 'NLP', 'involve', 'natural', 'language', 'understanding', ',', 'that', 'is', ',', 'enabling', 'computers', '(', 'computers', ')', 'derive', 'meaning', 'from', 'human', 'or', 'natural', 'language', 'input', ',', 'and', 'others', 'involve', 'natural', 'language', 'generation', '.']
# ['Up', 'to', 'the', '1980s', ',', 'most', 'NLP', '(', 'NLP', ')', 'were', 'based', 'on', 'complex', 'sets', 'of', 'hand-written', 'rules', '.']
# ['However', ',', 'Part', 'of', 'speech', 'tagging', 'introduced', 'the', 'use', 'of', 'Hidden', 'Markov', 'Models', 'to', 'NLP', '(', 'NLP', ')', 'and', 'increasingly', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'the', 'features', 'making', 'up', 'the', 'input', 'data', '.']
# ['In', '1950', ',', 'Alan', 'Turing', 'published', 'an', 'article', 'titled', '``', 'Computing', 'Machinery', 'and', 'Intelligence', "''", 'which', 'proposed', 'what', 'is', 'now', 'called', 'the', 'Turing', '(', 'Alan', 'Turing', ')', 'as', 'a', 'criterion', 'of', 'intelligence', '.']
# ['The', 'authors', 'claimed', 'that', 'within', 'three', 'or', 'five', 'years', ',', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'be', 'a', 'solved', 'problem', '.']
# ['Little', 'further', 'research', 'in', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'conducted', 'until', 'the', 'late', '1980s', ',', 'when', 'the', 'first', 'statistical', 'machine', 'translation', 'systems', 'were', 'developed', '.']
# ['Many', 'of', 'the', 'notable', 'early', 'successes', 'occurred', 'in', 'the', 'field', 'of', 'machine', 'translation', ',', 'due', 'especially', 'to', 'work', 'at', 'IBM', 'Research', ',', 'where', 'successively', 'more', 'complicated', 'statistical', 'models', 'were', 'developed', '(', 'a', 'solved', 'problem', ')']
# ['Many', 'of', 'the', 'notable', 'early', 'successes', 'occurred', 'in', 'the', 'field', 'of', 'machine', 'translation', '(', 'a', 'solved', 'problem', ')', 'due', 'especially', 'to', 'work', 'at', 'IBM', 'Research', ',', 'where', 'successively', 'more', 'complicated', 'statistical', 'models', 'were', 'developed', '.']
# ['Up', 'to', 'the', '1980s', '(', 'the', 'late', '1980s', ')', 'most', 'NLP', 'systems', 'were', 'based', 'on', 'complex', 'sets', 'of', 'hand-written', 'rules', '.']
# ['Starting', 'in', 'the', 'late', '1980s', '(', 'the', 'late', '1980s', ')', 'however', ',', 'there', 'was', 'a', 'revolution', 'in', 'NLP', 'with', 'the', 'introduction', 'of', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', '.']
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', '(', 'ELIZA', ')', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', 'hurts', '?', "''"]
# ['Some', 'notably', 'successful', 'NLP', 'systems', 'developed', 'in', 'the', '1960s', 'were', 'SHRDLU', ',', 'a', 'natural', 'language', 'system', 'working', 'in', 'restricted', '``', 'blocks', 'worlds', "''", 'with', 'restricted', 'vocabularies', '(', 'SHRDLU', ')', 'and', 'ELIZA', ',', 'a', 'simulation', 'of', 'a', 'Rogerian', 'psychotherapist', ',', 'written', 'by', 'Joseph', 'Weizenbaum', 'between', '1964', 'to', '1966', '.']
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', '(', 'the', '``', 'patient', "''", ')', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', 'hurts', '?', "''"]
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', 'head', '(', 'My', 'head', ')', '?', "''"]
# ['When', 'the', '``', 'patient', "''", 'exceeded', 'the', 'very', 'small', 'knowledge', 'base', ',', 'ELIZA', 'might', 'provide', 'a', 'generic', 'response', ',', 'for', 'example', ',', 'responding', 'to', '``', 'My', 'head', 'hurts', "''", 'with', '``', 'Why', 'do', 'you', 'say', 'your', '(', 'you', ')', 'hurts', '?', "''"]
# ['Examples', 'are', 'MARGIE', '-LRB-', 'Schank', ',', '1975', '-RRB-', ',', 'SAM', '-LRB-', 'Cullingford', ',', '1978', '-RRB-', ',', 'PAM', '-LRB-', 'Wilensky', ',', '1978', '-RRB-', ',', 'TaleSpin', '-LRB-', 'Meehan', ',', '1976', '-RRB-', ',', 'QUALM', '-LRB-', 'Lehnert', ',', '1977', '-RRB-', ',', 'Politics', '-LRB-', 'Carbonell', ',', '1979', '-RRB-', ',', 'and', 'Plot', 'Units', '-LRB-', 'Lehnert', '1981', '(', 'Lehnert', ')', '.']
# ['Examples', 'are', 'MARGIE', '-LRB-', 'Schank', ',', '1975', '-RRB-', ',', 'SAM', '-LRB-', 'Cullingford', ',', '1978', '-RRB-', ',', 'PAM', '-LRB-', 'Wilensky', ',', '1978', '(', '1978', ')', ',', 'TaleSpin', '-LRB-', 'Meehan', ',', '1976', '-RRB-', ',', 'QUALM', '-LRB-', 'Lehnert', ',', '1977', '-RRB-', ',', 'Politics', '-LRB-', 'Carbonell', ',', '1979', '-RRB-', ',', 'and', 'Plot', 'Units', '-LRB-', 'Lehnert', '1981', '-RRB-', '.']
# ['Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', ',', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'the', 'systems', 'of', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'were', 'then', 'common', '.']
# ['Generally', ',', 'handling', 'such', 'input', 'gracefully', 'with', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'or', 'more', 'generally', ',', 'creating', 'systems', 'of', 'hand-written', 'rules', 'that', 'make', 'soft', 'decisions', '--', 'extremely', 'difficult', ',', 'error-prone', 'and', 'time-consuming', '.']
# ['Generally', ',', 'handling', 'such', 'input', 'gracefully', 'with', 'hand-written', 'rules', '--', 'or', 'more', 'generally', ',', 'creating', 'systems', 'of', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'make', 'soft', 'decisions', '--', 'extremely', 'difficult', ',', 'error-prone', 'and', 'time-consuming', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', '(', 'hand-written', 'rules', ')', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['Some', 'of', 'the', 'earliest-used', 'machine', 'learning', 'algorithms', '(', 'machine', 'learning', 'algorithms', 'for', 'language', 'processing', ')', 'such', 'as', 'decision', 'trees', ',', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', '.']
# ['Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', '(', 'decision', 'trees', ')', 'produced', 'systems', 'of', 'hard', 'if-then', 'rules', 'similar', 'to', 'the', 'systems', 'of', 'hand-written', 'rules', 'that', 'were', 'then', 'common', '.']
# ['Prior', 'implementations', 'of', 'language-processing', 'tasks', 'typically', 'involved', 'the', 'direct', 'hand', 'coding', 'of', 'large', 'sets', 'of', 'rules', '(', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', ')']
# ['Systems', 'based', 'on', 'machine-learning', 'algorithms', 'have', 'many', 'advantages', 'over', 'hand-produced', 'rules', ':', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', 'automatically', 'focus', 'on', 'the', 'most', 'common', 'cases', ',', 'whereas', 'when', 'writing', 'rules', '(', 'hard', 'if-then', 'rules', 'similar', 'to', 'existing', 'hand-written', 'rules', ')', 'hand', 'it', 'is', 'often', 'not', 'obvious', 'at', 'all', 'where', 'the', 'effort', 'should', 'be', 'directed', '.']
# ['However', ',', 'Part', 'of', 'speech', 'tagging', 'introduced', 'the', 'use', 'of', 'Hidden', 'Markov', 'Models', 'to', 'NLP', ',', 'and', 'increasingly', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'the', 'features', 'making', 'up', 'the', 'input', 'data', '(', 'statistical', 'models', ')']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '(', 'statistical', 'models', ')']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', '(', 'statistical', 'models', ')', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '.']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', '(', 'soft', ',', 'probabilistic', 'decisions', ')', 'on', 'attaching', 'real-valued', 'weights', 'to', 'each', 'input', 'feature', '.']
# ['Increasingly', ',', 'however', ',', 'research', 'has', 'focused', 'on', 'statistical', 'models', ',', 'which', 'make', 'soft', ',', 'probabilistic', 'decisions', 'based', 'on', 'attaching', 'real-valued', 'weights', '(', 'real-valued', 'weights', ')', 'each', 'input', 'feature', '.']
# ['These', 'algorithms', 'take', 'as', 'input', 'a', 'large', 'set', 'of', '``', 'features', "''", 'that', 'are', 'generated', 'from', 'the', 'input', 'data', '(', 'the', 'input', 'data', ')']
# ['The', 'cache', 'language', 'models', 'upon', 'which', 'many', 'speech', 'recognition', 'systems', 'now', 'rely', 'are', 'examples', 'of', 'such', 'statistical', 'models', '(', 'The', 'cache', 'language', 'models', 'upon', 'which', 'many', 'speech', 'recognition', 'systems', 'now', 'rely', ')']
# ['These', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')', 'able', 'to', 'take', 'advantage', 'of', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', '.']
# ['However', ',', 'most', 'other', 'systems', 'depended', 'on', 'corpora', 'specifically', 'developed', 'for', 'the', 'tasks', 'implemented', 'by', 'these', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')', 'which', 'was', '-LRB-', 'and', 'often', 'continues', 'to', 'be', '-RRB-', 'a', 'major', 'limitation', 'in', 'the', 'success', 'of', 'these', 'systems', '.']
# ['However', ',', 'most', 'other', 'systems', 'depended', 'on', 'corpora', 'specifically', 'developed', 'for', 'the', 'tasks', 'implemented', 'by', 'these', 'systems', ',', 'which', 'was', '-LRB-', 'and', 'often', 'continues', 'to', 'be', '-RRB-', 'a', 'major', 'limitation', 'in', 'the', 'success', 'of', 'these', 'systems', '(', 'many', 'speech', 'recognition', 'systems', ')']
# ['Such', 'models', 'are', 'generally', 'more', 'robust', 'when', 'given', 'unfamiliar', 'input', ',', 'especially', 'input', 'that', 'contains', 'errors', '-LRB-', 'as', 'is', 'very', 'common', 'for', 'real-world', 'data', '-RRB-', '(', 'as', 'input', ')', 'and', 'produce', 'more', 'reliable', 'results', 'when', 'integrated', 'into', 'a', 'larger', 'system', 'comprising', 'multiple', 'subtasks', '.']
# ['These', 'systems', 'were', 'able', 'to', 'take', 'advantage', 'of', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', '(', 'the', 'advantage', ')']
# ['A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '(', 'existing', 'multilingual', 'textual', 'corpora', 'that', 'had', 'been', 'produced', 'by', 'the', 'Parliament', 'of', 'Canada', 'and', 'the', 'European', 'Union', 'as', 'a', 'result', 'of', 'laws', 'calling', 'for', 'the', 'translation', 'of', 'all', 'governmental', 'proceedings', 'into', 'all', 'official', 'languages', 'of', 'the', 'corresponding', 'systems', 'of', 'government', ')', 'is', 'a', 'set', 'of', 'documents', '-LRB-', 'or', 'sometimes', ',', 'individual', 'sentences', '-RRB-', 'that', 'have', 'been', 'hand-annotated', 'with', 'the', 'correct', 'values', 'to', 'be', 'learned', '.']
# ['Such', 'algorithms', 'are', 'able', 'to', 'learn', 'from', 'data', 'that', 'has', 'not', 'been', 'hand-annotated', 'with', 'the', 'desired', 'answers', '(', 'data', ')', 'or', 'using', 'a', 'combination', 'of', 'annotated', 'and', 'non-annotated', 'data', '.']
# ['Many', 'different', 'classes', 'of', 'machine', 'learning', 'algorithms', '(', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', ')', 'been', 'applied', 'to', 'NLP', 'tasks', '.']
# ['These', 'algorithms', '(', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', ')', 'as', 'input', 'a', 'large', 'set', 'of', '``', 'features', "''", 'that', 'are', 'generated', 'from', 'the', 'input', 'data', '.']
# ['NLP', 'using', 'machine', 'learning', 'Modern', 'NLP', 'algorithms', 'are', 'based', 'on', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'especially', 'statistical', 'machine', 'learning', '.']
# ['The', 'paradigm', 'of', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'different', 'from', 'that', 'of', 'most', 'prior', 'attempts', 'at', 'language', 'processing', '.']
# ['Systems', 'based', 'on', 'machine-learning', 'algorithms', 'have', 'many', 'advantages', 'over', 'hand-produced', 'rules', ':', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', '(', 'machine', 'learning', ',', 'especially', 'statistical', 'machine', 'learning', ')', 'focus', 'on', 'the', 'most', 'common', 'cases', ',', 'whereas', 'when', 'writing', 'rules', 'by', 'hand', 'it', 'is', 'often', 'not', 'obvious', 'at', 'all', 'where', 'the', 'effort', 'should', 'be', 'directed', '.']
# ['A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '-RRB-', 'is', 'a', 'set', 'of', 'documents', '-LRB-', 'or', 'sometimes', ',', 'individual', 'sentences', '-RRB-', 'that', 'have', 'been', 'hand-annotated', 'with', 'the', 'correct', 'values', 'to', 'be', 'learned', '(', 'A', 'corpus', '-LRB-', 'plural', ',', '``', 'corpora', "''", '-RRB-', ')']
# ['Such', 'models', 'have', 'the', 'advantage', 'that', 'they', '(', 'Some', 'of', 'the', 'earliest-used', 'algorithms', ',', 'such', 'as', 'decision', 'trees', ')', 'express', 'the', 'relative', 'certainty', 'of', 'many', 'different', 'possible', 'answers', 'rather', 'than', 'only', 'one', ',', 'producing', 'more', 'reliable', 'results', 'when', 'such', 'a', 'model', 'is', 'included', 'as', 'a', 'component', 'of', 'a', 'larger', 'system', '.']
# ['However', ',', 'creating', 'more', 'data', 'to', 'input', 'to', 'machine-learning', 'systems', '(', 'Systems', 'based', 'on', 'machine-learning', 'algorithms', ')', 'requires', 'a', 'corresponding', 'increase', 'in', 'the', 'number', 'of', 'man-hours', 'worked', ',', 'generally', 'without', 'significant', 'increases', 'in', 'the', 'complexity', 'of', 'the', 'annotation', 'process', '.']
# ['Automatic', 'learning', 'procedures', '(', 'The', 'learning', 'procedures', 'used', 'during', 'machine', 'learning', ')', 'make', 'use', 'of', 'statistical', 'inference', 'algorithms', 'to', 'produce', 'models', 'that', 'are', 'robust', 'to', 'unfamiliar', 'input', '-LRB-', 'e.g.', 'containing', 'words', 'or', 'structures', 'that', 'have', 'not', 'been', 'seen', 'before', '-RRB-', 'and', 'to', 'erroneous', 'input', '-LRB-', 'e.g.', 'with', 'misspelled', 'words', 'or', 'words', 'accidentally', 'omitted', '-RRB-', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', 'can', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '(', 'the', 'rules', ')']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', 'can', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', '(', 'the', 'rules', ')', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['However', ',', 'systems', 'based', 'on', 'hand-written', 'rules', '(', 'the', 'systems', ')', 'only', 'be', 'made', 'more', 'accurate', 'by', 'increasing', 'the', 'complexity', 'of', 'the', 'rules', ',', 'which', 'is', 'a', 'much', 'more', 'difficult', 'task', '.']
# ['The', 'subfield', 'of', 'NLP', 'devoted', 'to', 'learning', 'approaches', 'is', 'known', 'as', 'Natural', 'Language', 'Learning', '-LRB-', 'NLL', '-RRB-', 'and', 'its', '(', 'Natural', 'Language', 'Learning', '-LRB-', 'NLL', '-RRB-', ')', 'CoNLL', 'and', 'peak', 'body', 'SIGNLL', 'are', 'sponsored', 'by', 'ACL', ',', 'recognizing', 'also', 'their', 'links', 'with', 'Computational', 'Linguistics', 'and', 'Language', 'Acquisition', '.']

# %% [markdown]
# ## 57. 係り受け解析

# %% [markdown]
# ## 58. タプルの抽出

# %% [markdown]
# ## 59. S式の解析

# %% [markdown]
# # 第7章: データベース

# %% [markdown]
# ## 60. KVSの構築

# %%
# !head  data/artist.json
# Out:
# {"name": "WIK▲N", "tags": [{"count": 1, "value": "sillyname"}], "sort_name": "WIK▲N", "ended": true, "gid": "8972b1c1-6482-4750-b51f-596d2edea8b1", "id": 805192}
# {"name": "Gustav Ruppke", "sort_name": "Gustav Ruppke", "ended": true, "gid": "b4f76788-7e6f-41b7-ac7b-dfb67f66282e", "type": "Person", "id": 578352}
# {"name": "Pete Moutso", "sort_name": "Moutso, Pete", "ended": true, "gid": "49add228-eac5-4de8-836c-d75cde7369c3", "type": "Person", "id": 371203}
# {"ended": true, "gid": "c112a400-af49-4665-8bba-741531d962a1", "sort_name": "Zachary", "id": 273232, "name": "Zachary"}
# {"name": "The High Level Ranters", "sort_name": "High Level Ranters, The", "ended": true, "gid": "c42eed94-e233-44e2-82b8-3ed6dd9bf318", "type": "Group", "id": 153193}
# {"begin": {"year": 1956}, "end": {"year": 1993}, "name": "The Silhouettes", "area": "United States", "sort_name": "Silhouettes, The", "ended": true, "gid": "ca3f3ee1-c4a7-4bac-a16a-0b888a396c6b", "type": "Group", "id": 101060, "aliases": [{"name": "Silhouettes", "sort_name": "Silhouettes"}, {"name": "The Sihouettes", "sort_name": "The Sihouettes"}]}
# {"ended": true, "gid": "7b4a548e-a01a-49b7-82e7-b49efeb9732c", "sort_name": "Leavitt, Aric", "id": 145773, "name": "Aric Leavitt"}
# {"ended": true, "gid": "60aca66f-e91a-4cb5-9308-b6e293cd833e", "sort_name": "Fonograff", "id": 1076328, "name": "Fonograff"}
# {"name": "Al Street", "area": "United States", "gender": "Male", "sort_name": "Street, Al", "ended": true, "gid": "3e1bd546-d2a7-49cb-b38d-d70904a1d719", "type": "Person", "id": 1172876}
# {"ended": true, "gid": "df120895-f6c6-4a66-b9cf-73350f0beb61", "sort_name": "Love .45", "id": 220155, "name": "Love .45"}

# %%
import redis

r = redis.StrictRedis(host='localhost', port=6379, db=0)

# %%
import json

with open('data/artist.json') as file: 
    cnt  = 0
    for line in file:
        data = json.loads(line)
        if ('name' in data.keys() and 'area' in data.keys()):
            r.set(data['name'], data['area'])

# %% [markdown]
# ## 61. KVSの検索

# %%
r.get('Pete Moutso')

# %%
r.get('Al Street')
# Out:
# b'United States'

# %% [markdown]
# ## 62. KVS内の反復処理

# %%
cnt = 0
for key in r.keys():
    if r.get(key) == b'Japan':
        cnt += 1

# %%
print(cnt)
# Out:
# 22128

# %% [markdown]
# ## 63. オブジェクトを値に格納したKVS

# %%
import json

# アーティスト名に対してのタグを格納
with open('data/artist.json') as file: 
    for line in file:
        data = json.loads(line)
        if 'tags' in data.keys():
            r.hmset(data['name'], {'tags': data['tags']})

# %%
r.keys()
# Out:
# [b'Edgars Naglis',
#  b'\xe3\x82\xb9\xe3\x83\x97\xe3\x83\xbc\xe3\x83\xb3\xe3\x82\xbf\xe3\x83\x83\xe3\x83\x97',
#  b'I Am the Hamster',
#  b'Scoundrels',
#  b'\xe4\xbc\x8a\xe8\x97\xa4\xe5\xa4\x9a\xe8\xb3\x80\xe4\xb9\x8b',
#  b'Luniz',
#  b'Teflon Brothers',
#  b'Mikko Karmila',
#  b'Ain\xc4\x81rs Majors',
#  b'Lena Katina',
#  b'Steve Brookstein',
#  b'Kenny Garrett',
#  b'Lamb',
#  b'Broken Bells',
#  b'Z.O.O.I.',
#  b'Tadday',
#  b'\xd0\xad\xd0\xbc\xd0\xb8\xd0\xbb\xd1\x8c \xd0\x93\xd1\x80\xd0\xb8\xd0\xb3\xd0\xbe\xd1\x80\xd1\x8c\xd0\xb5\xd0\xb2\xd0\xb8\xd1\x87 \xd0\x93\xd0\xb8\xd0\xbb\xd0\xb5\xd0\xbb\xd1\x8c\xd1\x81',
#  b'Clinic',
#  b'Tereskova',
#  b'Big Drill Car',
#  b'The Impalers',
#  b'Automatics',
#  b'Poetrip',
#  b'The Shirelles',
#  b'Michael French',
#  b'Upset Tummy',
#  b'Nicole Kidman',
#  b'ALLY & DIAZ',
#  b'Julian Soule',
#  b'The Cundeez',
#  b'Andr\xc3\xa9 Ceccarelli',
#  b'Jaa9 & OnklP',
#  b'Alex Aris',
#  b'Juris Valainis',
#  b'Le Fiasko',
#  b'ADS',
#  b'Herry Monster',
#  b'Netsky',
#  b'Maximum Boycott',
#  b'TLC',
#  b'Bombay Talkie',
#  b'Freitodt',
#  b'Franti\xc5\xa1ek Kmoch',
#  b'Jesus Chrysler Suicide',
#  b'Frank Hayes',
#  b'Muzio Clementi',
#  b'Volbeat',
#  b'October Rising',
#  b'Sonic Area',
#  b'\xe4\xb8\x8a\xe7\x94\xb0\xe6\xad\xa3\xe6\xa8\xb9',
#  b'Ward 21',
#  b'Aigars \xc5\xa0mits',
#  b'The Sludgefukkas',
#  b'K-System',
#  b'CHPLN',
#  b'Strawberry Path',
#  b'Hint',
#  b'\xe6\xb7\xb1\xe7\x94\xb0\xe6\x81\xad\xe5\xad\x90',
#  b'Szymon Wysocki',
#  b'Rusty Bear',
#  b'G. Coca',
#  b'Joanna Chapman-Smith',
#  b'\xec\xa0\x95\xeb\xaf\xbc',
#  b'Gilbert B\xc3\xa9caud',
#  b'Elmore James',
#  b'Markus Itkonen',
#  b'\xe6\xa3\xae\xe6\xb0\xb8\xe7\x90\x86\xe7\xa7\x91',
#  b'3-Action',
#  b'SONOS',
#  b'Mortician',
#  b'Per Fredrik Kvarme',
#  b'The Paladins',
#  b'Ursus & Nadeschkin',
#  b'\xe4\xb8\x89\xe5\xae\x9d',
#  b'Neil Claxton',
#  b'Total Planet Refreshment',
#  b'\xe3\x82\xaf\xe3\x83\xac\xe3\x82\xa4\xe3\x82\xb8\xe3\x83\xbc\xe3\x82\xad\xe3\x83\xa3\xe3\x83\x83\xe3\x83\x84',
#  b'Adam F',
#  b'Essential',
#  b'Paavoharju',
#  b'Reigning Sound',
#  b'Hecq',
#  b'Big Maceo',
#  b'G\xc3\xa9rard Langella',
#  b'Joel Berglund',
#  b'Ellen Allien',
#  b'Exploding Castro Cigars',
#  b'SPACE GIRLS PLANET',
#  b'Atlantic Connection',
#  b'The Horrorbles',
#  b'\xeb\xa0\x88\xeb\x82\x98\xeb\xa5\xb4',
#  b'The Smiths',
#  b'Dan\xe2\x80\x90E\xe2\x80\x90O',
#  b'Mark Platts',
#  b'\xd0\x98\xd0\xb3\xd0\xbe\xd1\x80\xd1\x8c \xd0\x91\xd0\xb0\xd0\xb9\xd0\xb4\xd1\x83\xd1\x80\xd0\xbe\xd0\xb2',
#  b'Effi Briest',
#  b'R*A*P',
#  b'milan',
#  b'\xe5\xa5\x8f\xe9\x9b\xa8\xe3\x80\x81\xe7\xbe\x8e\xe6\x9c\x88\xe3\x80\x81\xe3\x81\xa8\xe3\x81\xbe\xe3\x81\xa8\xe3\x81\x82\xe3\x81\x84\xe3\x81\x93\xe3\x80\x81\xe8\x91\xb5\xe6\xb5\xb7\xe4\xba\xba',
#  b'Cold Cold Ground',
#  b'The Vanjas',
#  b'Stone Em All',
#  b'\xce\x9a\xcf\x85\xcf\x81\xce\xb9\xce\xac\xce\xba\xce\xbf\xcf\x82 \xce\x9a\xce\xb1\xce\xb6\xce\xac\xce\xba\xce\xbf\xcf\x82',
#  b'The Broken Toys',
#  b'Zane Gudr\xc4\x81',
#  b'Blacktop Harrison',
#  b'Zexon 5',
#  b'Subpop Squeeze',
#  b'Fariborz Lachini',
#  b'Kip Hanrahan',
#  b'Dave Chappelle',
#  b'Lathe',
#  b'Yvonne Catterfeld',
#  b'Benny Bell',
#  b'Tom Blackburn',
#  b'Raghav',
#  b'Fokloras kopa "Ceiruleits"',
#  b'Johnny McElhone',
#  b'Lost Kids',
#  b'Sonique',
#  b'The Funky Man',
#  b'Ryan McGinley',
#  b'Youngblood Brass Band',
#  b'Paul Guiot',
#  b'Habakuk',
#  b'Loxsly',
#  b'Crywolf',
#  b'Stan Perez',
#  b'Plastix',
#  b'Chords',
#  b'Videohippos',
#  b'\xe7\x9f\xb3\xe7\x94\xb0\xe5\xae\x89\xe5\xa5\x88',
#  b'Najwa',
#  b'm0d',
#  b'\xd0\x94\xd0\xb5\xd0\xbc\xd0\xbe',
#  b'Donald s rivera',
#  b'Cris\xc3\xa1lida',
#  b'\xe7\xab\xa5\xe8\x8a\xb7\xe8\x8b\x93',
#  b'Michael Johns',
#  b'The General Foodz',
#  b'Heinz Rudolf Kunze',
#  b'Doomthrone',
#  b'\xe6\x9e\x97\xe5\xbd\xa9\xe4\xb9\x83',
#  b'Peter Lexington',
#  b'Jacques Vidal',
#  b'This Frontier Needs Heroes',
#  b'Karen Matheson',
#  b'Six Appeal',
#  b'Mariano Dubiansky',
#  b'\xe5\xb7\x9d\xe7\x95\x91\xe6\x96\x87\xe5\xad\x90',
#  b'Die Haut',
#  b'Celtic Cross',
#  b'Dean Landon',
#  b'Humble Tip',
#  b'Lesane Parish Crooks',
#  b'Piero Milesi',
#  b'Aleksandrs Sircovs',
#  b'Brain Size 61',
#  b'Madame Mayhem',
#  b'\xd0\x92\xd0\xbe\xd0\xbb\xd1\x87\xd0\xb8\xd0\xb9 \xd0\x98\xd1\x81\xd1\x82\xd0\xbe\xd1\x87\xd0\xbd\xd0\xb8\xd0\xba',
#  b'Eugene Ormandy',
#  b'Imants Paura',
#  b'Cecylia Barczyk',
#  b'Winston Churchill',
#  b'Overlagt Drap',
#  b'Hound Dog Taylor',
#  b'I Am Arrows',
#  b'Sarah Walker',
#  b'Rob Base',
#  b'Casiopea',
#  b'Cheap Art',
#  b'Flor de Loto',
#  b'Capital Scum',
#  b'Phobia',
#  b'\xe5\xae\xb6\xe5\x85\xa5\xe3\x83\xac\xe3\x82\xaa',
#  b'Carlos Prieto',
#  b'Patricia Smith',
#  b'Noah',
#  b'Jake Armerding',
#  b'PeterLicht',
#  b'datavase',
#  b'G. Hoodbar',
#  b'Bonded by Blood',
#  b'Dissection',
#  b'\xe5\x90\x89\xe7\x94\xb0\xe9\x87\x8c\xe6\xb7\xb1',
#  b'Eratomania',
#  b'Jesper Mattsson',
#  b'Hello Bella',
#  b'The Crack',
#  b'Kenny Dorham Septet',
#  b'Geoff Tate',
#  b'Peter Thoms',
#  b'R\xc3\xbc\xc3\xa7han \xc3\x87amay',
#  b'October',
#  b'Chapter Seven',
#  b'Savery',
#  b'Gene Pitney',
#  b'Angela Hewitt',
#  b'Joyce Cochrane',
#  b'Marc Hillman',
#  b'Kira and the Kindred Spirits',
#  b'Graham Perry',
#  b'De Jeugd van Tegenwoordig',
#  b'Glenn Keiles',
#  b'Villagers',
#  b'K4',
#  b'\xe4\xba\x80\xe6\xb8\x95\xe5\x8f\x8b\xe9\xa6\x99',
#  b'Sunday Munich',
#  b'Atomic Filth',
#  b'\xce\x92\xce\xb1\xcf\x83\xce\xaf\xce\xbb\xce\xb7\xcf\x82 \xce\xa0\xce\xb1\xcf\x80\xce\xb1\xce\xba\xcf\x89\xce\xbd\xcf\x83\xcf\x84\xce\xb1\xce\xbd\xcf\x84\xce\xaf\xce\xbd\xce\xbf\xcf\x85',
#  b'Terry Edwards & The Scapegoats',
#  b'Small Jackets',
#  b'Sardool Sikander',
#  b'Garry Sherman',
#  b'\xce\xa4\xce\xac\xcf\x83\xce\xbf\xcf\x82 \xce\x9b\xce\xb5\xce\xb9\xce\xb2\xce\xb1\xce\xb4\xce\xaf\xcf\x84\xce\xb7\xcf\x82',
#  b'Simon Chamberlain',
#  b'\xe3\x82\xb8\xe3\x83\xa7\xe3\x83\x8b\xe3\x83\xbc\xe5\x90\x89\xe9\x95\xb7',
#  b'Stephen C. Biggs',
#  b'DaForce',
#  b'Ricardo Castro',
#  b'Alessandro Scarlatti',
#  b'0xBBninja',
#  b'Bestial Mockery',
#  b'Cut Throat',
#  b'Ten City',
#  b'Amduscia',
#  b'\xe5\xb5\x90',
#  b'The Passengers',
#  b'Machinations',
#  b'Stranglehold',
#  b'Chilly',
#  b'Johnny Palermo',
#  b'Resque',
#  b'X Darawish',
#  b'Matthew Margeson',
#  b'Skullbusters',
#  b'Jacob Hoffman',
#  b'Ch\xc3\xb3r Filharmonii Narodowej',
#  b'The Wasps',
#  b'Photo',
#  b'Sinoath',
#  b'NUMBER GIRL',
#  b'James Galway',
#  b'Arctic Plateau',
#  b'Lila Downs',
#  b'Karcer',
#  b'M. C. Gary / D. J. Barry & The Aggregation',
#  b'Magnus Hohler',
#  b'i',
#  b'Poza Cisz\xc4\x85',
#  b'J. J. Johnson',
#  b'JS',
#  b'Frenchi Blanco',
#  b'The Mellers',
#  b'Androids of Mu',
#  b'Eduardo Rovira',
#  b'Mads R\xc3\xb8ksund',
#  b'Sheryl Crow',
#  b'Jarom\xc3\xadr 99 & The Bombers',
#  b'Victor Cavini & His Music',
#  b'Victor Schertzinger',
#  b'Construction',
#  b'The Dodoz',
#  b'Snow Tha Product',
#  b'New Model Army',
#  b'Phil Ek',
#  b'\xe9\x87\x8e\xe4\xb8\x8a\xe8\x91\xb5',
#  b'Ewa Podle\xc5\x9b',
#  b'Stigger',
#  b'Rudolf Friml',
#  b'Josh Cheuse',
#  b'Andris Rupais',
#  b'Samla Mammas Manna',
#  b'DJ Patife',
#  b'Led Zeppelin2',
#  b'Williams Williamson',
#  b'Vladimir Cosma',
#  b'Ly Lumiste',
#  b'Misery',
#  b'Joyce Andersen',
#  b'Jared Leto',
#  b'Lynn Saoirse',
#  b'Kaspars Borodu\xc5\xa1ko',
#  b'Andrew Johnston',
#  b'Sergejs Simonovs',
#  b'\xd0\x98\xd0\xb2\xd0\xb0\xd0\xbd \xd0\x9c\xd0\xbe\xd0\xbd\xd0\xb8\xd0\xb3\xd0\xb5\xd1\x82\xd1\x82\xd0\xb8',
#  b'Severed Head of State',
#  b'Extra Life',
#  b'Jeff Tymoschuk',
#  b'MARRS',
#  b'Quiet Village',
#  b'Die schwarzen Schafe',
#  b'Fernand Gignac',
#  b'P. Diddy',
#  b'\xd0\x91\xd0\xbe\xd0\xbb\xd1\x8c\xd1\x88\xd0\xbe\xd0\xb9 \xd1\x81\xd0\xb8\xd0\xbc\xd1\x84\xd0\xbe\xd0\xbd\xd0\xb8\xd1\x87\xd0\xb5\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9 \xd0\xbe\xd1\x80\xd0\xba\xd0\xb5\xd1\x81\xd1\x82\xd1\x80 \xd0\xb8\xd0\xbc\xd0\xb5\xd0\xbd\xd0\xb8 \xd0\x9f. \xd0\x98. \xd0\xa7\xd0\xb0\xd0\xb9\xd0\xba\xd0\xbe\xd0\xb2\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe',
#  b'Kari Aronpuro',
#  b'The D Project',
#  b"Flamin' Groovies",
#  b'Michael Kamen',
#  b'The Mekons',
#  b'Jim Lauderdale',
#  b'Frenkie',
#  b'Tom Holkenborg',
#  b'Matt Howells',
#  b'\xe3\x82\xad\xe3\x83\x83\xe3\x82\xb9\xe3\x81\xae\xe4\xb8\x96\xe7\x95\x8c',
#  b'\xe3\x83\x9e\xe3\x83\xa6\xe3\x83\x9f\xe3\x83\xbc\xe3\x83\x8c',
#  b'Konsta Hiekkanen',
#  b'The Bonzo Dog Band',
#  b'Goatsnake',
#  b'Egils Zakovics',
#  b'Sweet Talks',
#  b'The Raveness',
#  b'Orlando Jopling',
#  b'\xe3\x83\x98\xe3\x83\xa1\xe3\x83\xb3\xe3\x82\xa6\xe3\x82\xa7\xe3\x82\xa4',
#  b'\xe5\x86\x85\xe5\xb1\xb1\xe7\x94\xb0\xe6\xb4\x8b\xe3\x81\xa8\xe3\x82\xaf\xe3\x83\xbc\xe3\x83\xab\xe3\x83\xbb\xe3\x83\x95\xe3\x82\xa1\xe3\x82\xa4\xe3\x83\x96',
#  b'Oxygener',
#  b'Andrejs \xc4\xa2\xc4\x93rmanis',
#  b'(\xef\xbd\xa1\xef\xbd\xa5\xef\xbd\x98\xef\xbd\xa5)\xe3\x82\x9d\xef\xbc\x9c\xef\xbd\x82\xef\xbc\x81',
#  b'Four Tet',
#  b'Helene Fischer',
#  b'Herb',
#  b'\xe3\x82\xb3\xe3\x82\xb3\xe3\x83\x9a\xe3\x83\xaa',
#  b'Lee Morris',
#  b'Carel Verbrugge',
#  b'Kristin Molnar',
#  b'Y-Fronts',
#  b'Matt Paxton',
#  b'Scatha',
#  b'Arthur Smith',
#  b'Dominique Cravic',
#  b'DJ Bart',
#  b'J\xc3\xa9r\xc3\xa9mie Kisling',
#  b'Pete Philly & Perquisite',
#  b'Inge Val',
#  b'Pulse',
#  b'\xd0\xad\xd0\xb4\xd0\xb8\xd1\x81\xd0\xbe\xd0\xbd \xd0\x94\xd0\xb5\xd0\xbd\xd0\xb8\xd1\x81\xd0\xbe\xd0\xb2',
#  b'Hazmat',
#  b'Mihails Za\xc4\xbcivko',
#  b'Leonardo Favio',
#  b'Akercocke',
#  b'The Music Machine',
#  b'Willi Herren',
#  b'B. Davies',
#  b'Okkie',
#  b'Posthuman',
#  b'Edgars Roga',
#  b'Kibariye',
#  b'Rocky',
#  b'\xe3\x83\x91\xe3\x83\xaf\xe3\x83\xbc\xe3\x83\xbb\xe3\x83\x8f\xe3\x82\xa6\xe3\x82\xb9',
#  b'Dennis Rollins',
#  b'This House Is Full of Noise',
#  b'European Union Baroque Orchestra',
#  b'Homo Sapiens',
#  b'Public Enemy',
#  b'The One Takes',
#  b'Edv\xc4\xabns Krauklis',
#  b'V.O.I.D.',
#  b'Chris Rae',
#  b'Viktors Andrejevs',
#  b'Cincinnati Pops Orchestra',
#  b'Tony Sadler',
#  b'Noel Hogan',
#  b'Halsbrand',
#  b'Domains',
#  b'Abstract',
#  b'Helping Haiti',
#  b'Paula Cole',
#  b'Jay Tees',
#  b'Anthroprophh',
#  b'Olivier Lavergne',
#  b'Dead Silence',
#  b'\xe8\x8b\xa5\xe6\x9e\x97\xe5\x8a\xa0\xe5\xa5\x88',
#  b'\xe8\xb0\xb7\xe6\x9d\x91\xe5\xbf\x97\xe7\xa9\x82',
#  b'Nemirie',
#  b'Le Milieu',
#  b'\xe3\x82\xb6\xe3\x83\xbb\xe3\x83\x81\xe3\x83\xab\xe3\x83\x89\xe3\x83\xac\xe3\x83\xb3',
#  b'The Domino State',
#  b'The Wimps',
#  b'Bambix',
#  b'Santarita Sakkascia',
#  b'AG Dolla',
#  b'The Freebooters',
#  b'\xd8\xb4\xd9\x87\xd8\xb1\xd8\xa7\xd9\x85 \xd9\x86\xd8\xa7\xd8\xb8\xd8\xb1\xdb\x8c',
#  b'AskAak',
#  b'Michael Timmins',
#  b'John Mellencamp',
#  b'The Ugly',
#  b'Melky Sedeck',
#  b'\xe9\x99\x88\xe6\x80\x9d',
#  b'Eivind Aarset',
#  b'White Skull',
#  b'DJ Die',
#  b'KOD',
#  b'Joseph Eastborn Winner',
#  b'Nik Kershaw',
#  b'Gorgoroth',
#  b'Megalomaniacs',
#  b'Curly Howard',
#  b'Marty Robbins',
#  b'1/2',
#  b'Bog Morok',
#  b'Julius Baker',
#  b'Peter Amidon',
#  b'Thomas Crecquillon',
#  b'Uniikki',
#  b'Rene Garza',
#  b'Margherita Rinaldi',
#  b'Standar',
#  b'Krona',
#  b'C. J\xc3\xa9r\xc3\xb4me',
#  b'Chris Thomas',
#  b'Arteries Shaking',
#  b'Ray Bierl',
#  b'22-20s',
#  b'Mele Marce',
#  b'Adamski',
#  b'Gouryella',
#  b'Cranes',
#  b'Danny Wyatt',
#  b'Poerocks',
#  b'Pilli Bebek',
#  b'Gece Yolcular\xc4\xb1',
#  b'\xe3\x82\xaf\xe3\x83\xa9\xe3\x83\x83\xe3\x82\xb7\xe3\x83\xa5\xe3\x82\xae\xe3\x83\xa3\xe3\x83\xab\xe3\x82\xba',
#  b'\xe5\xaf\xba\xe7\x94\xb0\xe7\x94\xba',
#  b'Exposure',
#  b'Show Me Island',
#  b'Frank Loesser',
#  b'Ajs Nigrutin',
#  b'Scott McCormick',
#  b'J\xc3\xa9r\xc3\xb4me Grey',
#  b'\xe6\xb8\x9a\xe5\x8d\x81\xe5\x90\xbe',
#  b'Orlin Anastassov',
#  b'Shortlived',
#  b'Skurk',
#  b'Ubaldo de L\xc3\xado',
#  b'Sigmund Groven',
#  b'Noromi Lucalen',
#  b'AK1200',
#  b'Connie Breukhoven',
#  b'Hugues Ripoll',
#  b'Use M\xc3\xb6re Gas',
#  b'Warren Haynes',
#  b'Sean Magee',
#  b'John Hyatt',
#  b'The Notting Hillbillies',
#  b'DJ Codomo',
#  b'Alec Ven',
#  b'GO 2 \xef\xbc\xbbFASTWAY vs. ACE\xef\xbc\xbd',
#  b'Grahame Leslie',
#  b'Spoon, Harris & Obernik',
#  b'Betsie Larkin',
#  b'Anti-G',
#  b'W.F.N.',
#  b'Francis Poulenc',
#  b'K. Morris',
#  b'Adam Carse',
#  b'Peak',
#  b'Happy Flowers',
#  b'Guillermo de la Barreda',
#  b'Zensor',
#  b'Bobby Green',
#  b'StiTcH',
#  b'Carminho',
#  b'Christophe Le Van',
#  b'Ponytail',
#  b'\xe5\xb1\xb1\xe6\xa0\xb9\xe3\x83\x9f\xe3\x83\x81\xe3\x83\xab',
#  b'Matt Robson-Scott',
#  b'Paavo Berglund',
#  b'D\xc3\xa9pression',
#  b'Mysterious Footsteps',
#  b'\xe6\x9d\x89\xe7\x94\xb0\xe4\xba\x8c\xe9\x83\x8e',
#  b'Extrem Exem',
#  b'Alfonse',
#  b'La Perfecta',
#  b'Bisaid',
#  b'Sam La More',
#  b'Frontal Attack',
#  b'Naranjito Blues',
#  b'B. Baker',
#  b'Ivy James',
#  b'The Dispossessed',
#  b'Pelotan',
#  b'Gavin Hope',
#  b'Jeanphilip',
#  b'\xe5\x9c\xb0\xe7\x90\x83\xe4\xb8\x89\xe5\x85\x84\xe5\xbc\x9f',
#  b'Chuck E. Weiss',
#  b'Tal',
#  b'Gender ID',
#  b'Xavier Cantat',
#  b'The Many Few',
#  b'Suzannes',
#  b'Juuso Nieminen',
#  b'Muriel Robin',
#  b'Valva',
#  b'Katharine McPhee',
#  b'\xd0\x90\xd0\xba\xd0\xb2\xd0\xb0\xd1\x80\xd0\xb8\xd1\x83\xd0\xbc',
#  b'No Alternative',
#  b'Anwech',
#  b'Brinton Averil Smith',
#  b'Tones on Tail',
#  b'Miley Cyrus',
#  b'Sickidz',
#  b'L\xc4\xabga Ozola',
#  b'Ernst Linko',
#  b'Gretchen Peters',
#  b'David Wolfert',
#  b'Hirama Satoko',
#  b'Danny Brown',
#  b'Bourvil',
#  b'Doug Young',
#  b'Peven Everett',
#  b'\xe3\x83\x84\xe3\x83\x81\xe3\x83\xa4\xe3\x83\x8b\xe3\x83\x9c\xe3\x83\xb3\xe3\x83\x89',
#  b'A. St\xc5\xabr\xc4\xabtis',
#  b'Jet Bronx & The Forbidden',
#  b'Boycot',
#  b'Thorsten Schepers',
#  b'Decayed Corpulence',
#  b'DJ Miccs',
#  b'Bet On',
#  b'Scourge',
#  b'A. Gardener',
#  b'The Toasters',
#  b'Really Red',
#  b'Digitalis Purpurea',
#  b'\xe5\xb1\xb1\xe6\x9c\xac\xe3\x82\xb9\xe3\x83\xbc\xe3\x82\xb6\xe3\x83\xb3\xe4\xb9\x85\xe7\xbe\x8e\xe5\xad\x90',
#  b'Mundtot',
#  b'Georg Ots',
#  b'Cartoons',
#  b'Haujobb',
#  b'\xeb\x8d\x94\xeb\x8d\x94',
#  b'Perpetual Dilemma',
#  b'Donkey Rollers',
#  b'DJ Sakin & Friends',
#  b'Gompie',
#  b'St\xc3\xa9phane Venant',
#  b'Drawing4-5',
#  b'Arachnoid',
#  b'Dubmood',
#  b'\xe5\xae\xae\xe4\xb8\x8b\xe7\x9b\xb4\xe7\xb4\x80',
#  b'John Mayall',
#  b'Dhampyr',
#  b'Pseudo Existors',
#  b'Frankie Rose',
#  b'Dissecting Table',
#  b'L.A.M.F.',
#  b'Avrigus',
#  b'Leon Else',
#  b'Octavion',
#  b'Lucerne Festival Orchestra',
#  b'Nazbrok',
#  b'Frank Goldwasser',
#  b'Jean-Paul Renus',
#  b'\xe9\x99\xb3\xe5\xb0\x8f\xe9\x9c\x9e',
#  b'Dona Dumitru Siminic\xc4\x83',
#  b'The Letters',
#  b'BaR',
#  b'Grade',
#  b'Alan Van Kleef',
#  b'G. Foster',
#  b'Zabili Mi \xc5\xbb\xc3\xb3\xc5\x82wia',
#  b'Jamie N Commons',
#  b'\xe8\x8b\xa5\xe8\x8d\x89\xe5\x85\x90\xe7\xab\xa5\xe5\x90\x88\xe5\x94\xb1\xe5\x9b\xa3',
#  b'Hirilorn',
#  b'The Owl Service',
#  b'Folkloras kopa "Laiksne"',
#  b'Orhan Hakalmaz',
#  b'McFly',
#  b'Jonathan Tabareau',
#  b'Arcadia',
#  b'Fredy-7',
#  b'Milanese',
#  b'James Bell',
#  b'Karim R\xc3\xa9veill\xc3\xa9',
#  b'Bah\xc3\xada In\xc3\xbatil',
#  b'Adam Nitti',
#  b'\xe5\x90\x89\xe6\xb2\xa2\xe6\xa2\xa8\xe7\xb5\xb5',
#  b'Faz\xc4\xb1l Say',
#  b'Hi-CLASS',
#  b'Nick Seybert',
#  b'\xe3\x82\xb9\xe3\x83\x91\xe3\x83\x8a',
#  b'Antony Hegarty',
#  b'Richard Rodgers',
#  b'EMBASSYLIGHTS',
#  b'Fall of an Empire',
#  b'Grown Up Avenger Stuff',
#  b'Robert Lockwood, Jr.',
#  b'Will Slater',
#  b'Scientifik',
#  b'Dirlewanger',
#  b'Geir Ola Brandal',
#  b'State Logik',
#  b'Yolanda Adams',
#  b'Endangered Species',
#  b'Crucial Cause',
#  b'Eken\xc3\xa4s Gossk\xc3\xb6r',
#  b'Christa Jehser',
#  b'Colin Macdonald',
#  b'Ram\xc3\xb3n Valle Trio',
#  b'Port Noir',
#  b'Stylorouge',
#  b'Flipsyde',
#  b'Gerk',
#  b'Adrenalin O.D.',
#  b'Yves Duteil',
#  b'Money Trench',
#  b'Peter and the Kibbutznik',
#  b'\xe2\x86\x92\xe2\x86\x91\xe2\x86\x92',
#  b'Ramata Diakit\xc3\xa9',
#  b'Chupacabra Jr.',
#  b'\xe6\x9c\x89\xe5\xb1\xb1\xe6\xb7\xb3\xe5\x8f\xb8',
#  b'D-Trix',
#  b'Maggot Slayer Overdrive',
#  b'Gints Stank\xc4\x93vi\xc4\x8ds',
#  b'\xc3\x96zkan Turgay',
#  b'\xe5\xaf\x8c\xe5\xb7\x9d\xe6\x98\xa5\xe7\xbe\x8e',
#  b'Exeroica',
#  b'Alain Cluzeau',
#  b'The Left',
#  b'TOJIN BATTLE ROYAL',
#  b'Get Ugly',
#  b'.moneen.',
#  b'\xe7\xb4\xa0',
#  b'K\xc4\x81rlis Skalbe',
#  b'Pony Pony Run Run',
#  b'Viktors Zemgals',
#  b'Abismo Nuclear',
#  b'The Filthy Radicals',
#  b'The F Models',
#  b'NEC Chorus & NEC Jewish Music Ensemble',
#  b'Guenther Birner',
#  b'Effluo',
#  b'Len Beadle',
#  b'Edgar',
#  b'Madredeus',
#  b'DJ ASARI',
#  b'\xe9\x95\xb7\xe8\xb0\xb7\xe5\xb7\x9d\xe8\x90\x8c\xe7\xbe\x8e',
#  b'Iven Schmidt',
#  b'Phil Parnell',
#  b'Mafia K\xe2\x80\x991 Fry',
#  b'DC Breaks',
#  b'Adesa',
#  b'The Fiend',
#  b'Cherry Ghost',
#  b'Naked Nick',
#  b'Time to Think',
#  b'La Pat\xc3\xa8re Rose',
#  b'Daveit Ferris',
#  b'Stage Dolls',
#  b'El Gran Chufle',
#  b'Mighty Baby',
#  b'Phat Kat',
#  b'The Revelevens',
#  b'Rize',
#  b'\xc4\x92riks Garkulis',
#  b'Mista Silva',
#  b'200 Sachen',
#  b'Dirt Bike Annie',
#  b'Indra Karlsone',
#  b'Pol\xc3\xadticos Muertos',
#  b'\xe5\xa4\xa7\xe6\xb2\xa2\xe6\xa8\xb9\xe7\x94\x9f',
#  b'A Current Affair',
#  b'Sacrimony',
#  b'Sensuuri',
#  b'Undead',
#  b'3 Screaming Popes',
#  b'Battle Axe',
#  b'Inrigo Ar\xc4\x81js',
#  b'xhm\xc2\xb2',
#  b'Golden Tanks',
#  b'Ryan Carter',
#  b'Supersonic Piss',
#  b'Kraku',
#  b'The Right Now',
#  b'Cinquecento',
#  b'The Seize',
#  b'Manfred Mann\xe2\x80\x99s Earth Band',
#  b'Eric D. Thompson',
#  b'Carol Barratt',
#  b'Adolphe Adam',
#  b'Housemaster Boyz',
#  b'GAM',
#  b'Bob Rock',
#  b'Storybox',
#  b'San Francisco Symphony Chorus',
#  b'Morten B. Nielsen',
#  b'Those Helicopters',
#  b'Flipside',
#  b'Jonathan Welch',
#  b"MICRON' STUFF",
#  b'Boomerang',
#  b'Tac Dibar',
#  b'The Musgraves',
#  b'Genocide Organ',
#  b'Kapetan Leshi',
#  b'Detached',
#  b'\xce\xa7\xcf\x81\xce\xae\xcf\x83\xcf\x84\xce\xbf\xcf\x82 \xce\x98\xce\xb7\xce\xb2\xce\xb1\xce\xaf\xce\xbf\xcf\x82',
#  b'Terrence Stith',
#  b'Amaury Wallez',
#  b'Bradley Prill',
#  b'\xc3\x89gypto',
#  b'Krooked',
#  b'blues.the-butcher-590213',
#  b'Tommy Rot',
#  b'\xe8\xa5\xbf\xe5\xb7\x9d\xe5\xb3\xb0\xe5\xad\x90',
#  b'Theodore Shapiro',
#  b'Untermensch',
#  b'Panic! at the Disco',
#  b'Jerry Ross',
#  b'Andrea Rocca',
#  b'Alpha Jerk',
#  b'Sophie Hyde-Parker',
#  b'Cannibal Ox',
#  b'Viesturs Gr\xc4\xabnbergs',
#  b'Grow-Up',
#  b'FLAT122',
#  b'\xd0\xa1\xd0\xb5\xd1\x80\xd1\x91\xd0\xb3\xd0\xb0',
#  b'FlyEr',
#  b'Osman Giuseppe Gioia',
#  b'The Bottle Doom Lazy Band',
#  b'ACIDMAN',
#  b'Leanne Barbo',
#  b'X Fader',
#  b'DJ M\xc3\xb8ller',
#  b'Dave Newton',
#  b'Raimo Laukka',
#  b'Louis Prima',
#  b'R\xc3\xa9gis Ceccarelli',
#  b'Nigma',
#  b'\xd8\xa3\xd9\x85 \xd9\x83\xd9\x84\xd8\xab\xd9\x88\xd9\x85',
#  b'Paraf',
#  b'Sultans of Ping F.C.',
#  b'Klips 1988',
#  b'Mareks Skraj\xc4\x81ns',
#  b"MICCLOCK'S",
#  b'Darol Anger',
#  b'Joe Craven',
#  b'Anna Le Hair',
#  b'\xe9\x99\x88\xe7\xa3\x8a',
#  b'Juliana Diniz',
#  b'General Larry Platt',
#  b'Gertrude Lawrence',
#  b'MC Marco & MC Gor\xc3\xb3',
#  b'Doug Lazy',
#  b'Nanda Devi',
#  b'Four80East',
#  b'ALiENPiG',
#  b'\xe5\xba\xb7\xe7\x8f\x8d\xe5\x8c\x96',
#  b"Aphrodite's Child",
#  b'Christophe Zurfluh',
#  b'Erica Nicole Daking',
#  b'Bedlam',
#  b'Statik Motion',
#  b'Sielun Veljet',
#  b'Corpus Christi',
#  b'Norman Ludwin',
#  b'EGNISH',
#  b'\xd0\x94\xd0\xbe \xd0\xa1\xd0\xba\xd0\xbe\xd0\xbd\xd1\x83',
#  b'Kraak & Smaak',
#  b'Carleen Anderson',
#  b'Rigor Sardonicous',
#  b'Martin York',
#  b'detroit7',
#  b'Natasha Jeanne',
#  b'Electro-Motive Force',
#  b'\xe5\x86\x85\xe7\x94\xb0\xe3\x81\x82\xe3\x81\x8b\xe3\x82\x8a',
#  b'Al Houghton',
#  b'Butch Cassidy Sound System',
#  b'\xe6\x9f\xb3\xe5\x8e\x9f\xe5\xb9\xbc\xe4\xb8\x80\xe9\x83\x8e',
#  b'MAHO\xe5\xa0\x82',
#  b'John Rowcroft',
#  b'P\xc3\xbcdelsi',
#  b'Cher',
#  b'State Funeral',
#  b'Matt Montez',
#  b'\xe4\xbd\x90\xe8\x97\xa4\xe7\x9c\x9f\xe7\x94\xb1\xe7\xbe\x8e',
#  b'The Rodeo',
#  b'Joey Waronker',
#  b'Elfo Negro',
#  b'Jebediah',
#  b'Projetil Paralelo',
#  b'Displaced Paranormals',
#  b'Lisa Beznosiuk',
#  b'Julie Dexter',
#  b'Stephen Metcalf',
#  b'Burzum',
#  b'Diali Cissokho & Kaira Ba',
#  b"L'Alphalpha",
#  b'Metric',
#  b'WordsManifest',
#  b'Rich Polseno',
#  b'Pier Simone Agostini',
#  b'\xe7\xbe\x8e\xe5\x8b\x87\xe4\xbc\x9d',
#  b'Zbig G\xc3\xb3rny and His Orchestra',
#  b'The Pointer Sisters',
#  b'Mike Melillo',
#  b'Trashlords',
#  b'\xe6\xb0\xb4\xe7\x80\xac\xe4\xbc\x8a\xe7\xb9\x94',
#  b'\xc3\x98yvind Gimse',
#  b'T.Banzai',
#  b'\xce\x92\xce\xb1\xcf\x83\xce\xaf\xce\xbb\xce\xb7\xcf\x82 \xce\x9a\xce\xb1\xce\xb6\xce\xbf\xcf\x8d\xce\xbb\xce\xbb\xce\xb7\xcf\x82',
#  b'bazooie',
#  b'SIAM SHADE',
#  b'Kasun Kalhara Jayawardhana',
#  b'Vargsang',
#  b'Feargal Sharkey',
#  b'Colin Willsher',
#  b'RICKIE-G',
#  b'TRIPLE CLUTCH',
#  b'\xe9\xa1\xbe\xe9\xa6\x99\xe5\x90\x9b',
#  b'Mario Torella',
#  b'Famelik',
#  b'Energy',
#  b'Sarah Lacy',
#  b'Aleksei Saks',
#  b'Destry Hampton & The Wolves From Hell',
#  b'Blankus Larry',
#  b'\xe6\x88\xb4\xe6\x84\x9b\xe7\x8e\xb2',
#  b'Symbyosis',
#  b'8 Bit Instrumental',
#  b'Gene Wilder',
#  b'DJ High Yane',
#  b'Mychael Danna',
#  b'Guy',
#  b'Shirley & Company',
#  b'\xe3\x82\x86\xe3\x81\x86\xe3\x81\xbe',
#  b'Marianna Tarasova',
#  b'Silly Wizard',
#  b'Rattlesnake Men',
#  b'Blues Gang',
#  b'MKDELTA',
#  b'Laurence Saywood',
#  b'Michael Gielen',
#  b'Coco Steel & Lovebomb',
#  b'Sandra Gr\xc4\xabnberga',
#  b'Vinyl Floor',
#  b'The Rotters',
#  b'Bob Hall',
#  b'Dub FX',
#  b'Yggdrasil Quartet',
#  b'The Fixx',
#  b'Nick Arundel',
#  b'Lucy Kaplansky',
#  b'The Arlenes',
#  b'Jerry Lee Lewis',
#  b'Mantronix',
#  b'Plajia',
#  b'GoA - Gathering of Arrangers',
#  b'Billie the Vision & The Dancers',
#  b'Electroflex',
#  b'Noel Harrison',
#  b'Clive Carroll',
#  b'\xce\x9d\xcf\x84\xcf\x8c\xce\xbc\xce\xb9\xce\xbd\xce\xb9 \xce\x9b\xcf\x85\xce\xbc\xcf\x80\xce\xad\xcf\x81\xce\xb7',
#  b'Popperklopper',
#  b'Katie Crippen',
#  b'Mark Cooksey',
#  b'Blitz Kids',
#  b'Southport',
#  b'Stella Maria',
#  b'Infernal Wrath',
#  b'MC Darrison',
#  b'M.o.t.N.',
#  b'Secret Garden',
#  b'?',
#  b'Sebastian Wronski',
#  b'No Class',
#  b'Three Piece Lawsuit',
#  b'brutishbulldogs',
#  b'Black Shape of Nexus',
#  b'\xe6\xb5\x85\xe9\x87\x8e\xe6\x99\xba\xe5\x8d\x9a',
#  b'Sculpture Music',
#  b'Earthman',
#  b'Menudo',
#  b'Opera Multi Steel',
#  b'Scum Rats',
#  b'Maria Theresia von Paradis',
#  b'Plebs',
#  b'Pistol Annies',
#  b'Superchunk',
#  b'Huey, Dewey & Louie',
#  b'Athaudia',
#  b'Lu\xc3\xadsa Hana\xc3\xaa Matsushita',
#  b'Siva Pacifica',
#  b'Malveillance',
#  b'\xe8\x8a\xae\xe6\x81\xa9',
#  b'Klarisa Jovanovi\xc4\x87',
#  b'Nigel Kennedy',
#  b'Hauke Gabriel',
#  b'Dum Dum Girls',
#  b'Angerfist',
#  b'Aabsynthum',
#  b'Joshua Gordon',
#  b'Here Be Dragons',
#  b'Uncle Father',
#  b'Positiv Hate',
#  b'Dog Faced Hermans',
#  b'Bal\xc3\xa1zs Szokolay',
#  b'All Gone Dead',
#  b'\xe3\x81\x82\xe3\x81\xb6\xe3\x82\x89\xe3\x81\xa0\xe3\x81\x93',
#  b'Patrick Gauthier',
#  b'Xavier Nasse',
#  b'Balstyrko',
#  b'Lex Loofah',
#  b'George Marino',
#  b'Astrogat',
#  b'Wilhelm Meister',
#  b'Steam Powered Giraffe',
#  b'Emanuel Borok',
#  b'B\xc4\x93rnu grupa "Ekspresija"',
#  b'Liz Winstanley',
#  b'Andy Kim',
#  b'Freakangel',
#  b'Cynikal',
#  b'Darkthrone',
#  b'Johnny Mike',
#  b'\xe6\xa1\x9c\xe5\xb7\x9d\xe3\x81\xb2\xe3\x82\x81\xe3\x81\x93',
#  b'New Assholes',
#  b'Magnus & Erik Band',
#  b'Paraforce',
#  b'Les Mokos',
#  b'\xe9\x9d\x92\xe6\x9c\xa8\xe5\xad\x9d\xe6\x98\x8e',
#  b'\xe8\xb5\xa4\xe5\x9d\x82\xe8\x8a\xb3\xe6\x81\xb5',
#  b'Phi-Life Cypher',
#  b'Bow Wow',
#  b'Keith Lawrence',
#  b'MC Vad',
#  b'Pocahaunted',
#  b'Immanu El',
#  b'\xe3\x82\xad\xe3\x83\xa5\xe3\x82\xa6\xe3\x82\xbd\xe3\x83\x8d\xe3\x82\xb3\xe3\x82\xab\xe3\x83\x9f',
#  b'JUDI CHICAGO',
#  b'Lethargy of Death',
#  b'Les Tambours du Bronx',
#  b'Stephanie McIntosh',
#  b'Arvo P\xc3\xa4rt',
#  b'OS Isaak Iselin',
#  b'B. Aplin',
#  b'Truth',
#  b'Envoy',
#  b'Basic Unit',
#  b'\xe5\xb0\x9a\xe9\x95\xbf\xe8\x8d\xa3',
#  b'Another Tale',
#  b'Henning R\xc3\xbcte',
#  b'2 In Line',
#  b'Samuel Stockton',
#  b'Jake Kelly',
#  b'\xe3\x82\xb9\xe3\x83\x9a\xe3\x82\xb7\xe3\x83\xa3\xe3\x83\xab\xe3\x82\xac\xe3\x83\xbc\xe3\x83\xab\xe3\x82\xba',
#  b'Glen Duncan',
#  b'Decoder Ring',
#  b'Sch\xc3\xb6ngeist',
#  b'',
#  b'Job: \xe0\xb8\x9a\xe0\xb8\xa3\xe0\xb8\xa3\xe0\xb8\x88\xe0\xb8\x9a',
#  b'Ivars Gaide',
#  b'\xe6\xb3\x89\xe3\x81\x93\xe3\x81\xaa\xe3\x81\x9f',
#  b'Dillinger',
#  b'\xe6\x9d\xbf\xe9\x87\x8e\xe5\x8f\x8b\xe7\xbe\x8e',
#  b'Brian McNeil',
#  b'Lord Jamar',
#  b'M\xc4\x81ris Kristapsons',
#  b'P.C.T',
#  b'Avenpitch',
#  b'Grave Robber',
#  b'Juli',
#  b'Steaming Heathen',
#  b'Robin Wright',
#  b'\xe9\xab\x98\xe6\xa9\x8b\xe5\xbe\xb9\xe4\xb9\x9f',
#  b'Lego 5',
#  b'Metamora',
#  b'\xe6\xb2\x96\xe7\x94\xb0\xe5\xbd\xa9\xe8\x8f\xaf',
#  b'D\xc3\xbambala Canalla',
#  b'\xe6\xa8\xb9\xe5\x8e\x9f\xe4\xba\x9c\xe7\xb4\x80',
#  b'Suburban Mutilation',
#  b'Richard Maltby, Jr.',
#  b'Os Mutantes',
#  b'Leon P. Moorrees',
#  b'P. Fletcher',
#  b'\xe5\xb0\x8f\xe6\x9e\x97\xe6\xb8\x85\xe7\xbe\x8e',
#  b'\xe2\x80\x9cPapa\xe2\x80\x9d Charlie McCoy',
#  b'Mr. Ego',
#  b'',
#  b'Blutsturz',
#  b'Thomas Harper',
#  b'ZSK',
#  b'Ice Ages',
#  b'Otto Rensen',
#  b'Matteo Campanella',
#  b'Insanguine',
#  b'Mindless Paradise',
#  b'Domlebo',
#  b'P. Luste',
#  b'Like A Storm',
#  b'Al Petteway',
#  b'Leonid Hambro',
#  b'PZK',
#  b'The Tronics',
#  b'Fega p\xc3\xa5hopp',
#  b'\xe3\x82\xb8\xe3\x82\xa1\xe3\x82\xa4\xe3\x82\xa2\xe3\x83\xb3\xe3\x83\x88\xe3\x82\xb9\xe3\x83\x86\xe3\x83\x83\xe3\x83\x97',
#  b'Dip*N*Steam (D*N*S)',
#  b'Tuff Lion',
#  b'YUP',
#  b'\xe9\xa2\xa8\xe5\x88\xa9\xe9\x8a\x83\xe6\x81\x90\xe7\xab\x9c',
#  b'Tom McFall',
#  ...]

# %%
r.hmget(b'Edgars Naglis', 'tags')
# Out:
# [b"[{'value': 'latvian', 'count': 1}, {'value': 'unknown year', 'count': 1}]"]

# %% [markdown]
# ## 64. MongoDBの構築

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017) # if empty, connect default host and port

# getting a database
db = client['nlp100']

# getting a connection
artists = db['artists']

# %%
import json

with open('data/artist.json') as file:
    for line in file:
        artist = json.loads(line)
        
        # insert
        artist_id = artists.insert_one(artist).inserted_id

# %%
# check db connections
db.collection_names(include_system_collections=False)
# Out:
# ['artists']

# %%
artists.count()
# Out:
# 1924995

# %%
import pprint
pprint.pprint(artists.find_one())
# Out:
# {'_id': ObjectId('5a646993a6640c1835232a75'),
#  'ended': True,
#  'gid': '8972b1c1-6482-4750-b51f-596d2edea8b1',
#  'id': 805192,
#  'name': 'WIK▲N',
#  'sort_name': 'WIK▲N',
#  'tags': [{'count': 1, 'value': 'sillyname'}]}

# %% [markdown]
# ### create index ( name, aliases.name, tags.value, rating.value )

# %%
import pymongo

# %%
result = db.profiles.create_index([('name', pymongo.ASCENDING)], unique=True)

# %%
sorted(list(db.profiles.index_information()))
# Out:
# ['_id_', 'aliases.name_1', 'name_1', 'rating.value_1', 'tags.value_1']

# %%
result = db.profiles.create_index([('name', pymongo.ASCENDING)], unique=True)

# %%
result2 = db.profiles.create_index([('aliases.name', pymongo.ASCENDING)], unique=False)

# %%
result3 = db.profiles.create_index([('tags.value', pymongo.ASCENDING)], unique=False)

# %%
result4 = db.profiles.create_index([('rating.value', pymongo.ASCENDING)], unique=False)

# %% [markdown]
# ### drop index

# %%
db.profiles.drop_index("tags.value_1")

# %% [markdown]
# ## 65. MongoDBの検索

# %% [markdown]
# in mongo interactive shell,
#
# ### select database
# > use nlp100
#
# switched to db nlp100
#
# ### count records
# > db.artists.count()
#
# 1924995
#
# ### search for "Queen"
# > db.artists.find({"name": "Queen"})
#
# { "_id" : ObjectId("5a646bbfa6640c18353bb224"), "gid" : "420ca290-76c5-41af-999e-564d7c71f1a7", "ended" : true, "id" : 701492, "name" : "Queen", "tags" : [ { "value" : "kamen rider w", "count" : 1 }, { "value" : "related-akb48", "count" : 1 } ], "sort_name" : "Queen", "aliases" : [ { "name" : "Queen", "sort_name" : "Queen" } ], "area" : "Japan", "type" : "Character", "gender" : "Female" }
# { "_id" : ObjectId("5a646bcda6640c18353c78d0"), "ended" : true, "name" : "Queen", "rating" : { "value" : 92, "count" : 24 }, "sort_name" : "Queen", "tags" : [ { "value" : "hard rock", "count" : 2 }, { "value" : "70s", "count" : 1 }, { "value" : "queen family", "count" : 1 }, { "value" : "90s", "count" : 1 }, { "value" : "80s", "count" : 1 }, { "value" : "glam rock", "count" : 1 }, { "value" : "british", "count" : 4 }, { "value" : "english", "count" : 1 }, { "value" : "uk", "count" : 2 }, { "value" : "pop/rock", "count" : 1 }, { "value" : "pop-rock", "count" : 1 }, { "value" : "britannique", "count" : 1 }, { "value" : "classic pop and rock", "count" : 1 }, { "value" : "queen", "count" : 1 }, { "value" : "united kingdom", "count" : 1 }, { "value" : "langham 1 studio bbc", "count" : 1 }, { "value" : "kind of magic", "count" : 1 }, { "value" : "band", "count" : 1 }, { "value" : "rock", "count" : 6 }, { "value" : "platinum", "count" : 1 } ], "type" : "Group", "begin" : { "year" : 1970, "month" : 6, "date" : 27 }, "area" : "United Kingdom", "gid" : "0383dadf-2a4e-4d10-a46a-e9e041da8eb3", "id" : 192, "aliases" : [ { "name" : "女王", "sort_name" : "女王" } ] }
# { "_id" : ObjectId("5a646beda6640c18353e3328"), "gid" : "5eecaf18-02ec-47af-a4f2-7831db373419", "ended" : true, "id" : 992994, "name" : "Queen", "sort_name" : "Queen" }

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017) # if empty, connect default host and port

# getting a database
db = client['nlp100']

# getting a connection
artists = db['artists']

# %%
artists.count()
# Out:
# 1924995

# %%
cursor = db.artists.find({"name": "Queen"})

for document in cursor:
    print(document)
# Out:
# {'aliases': [{'name': 'Queen', 'sort_name': 'Queen'}], 'tags': [{'count': 1, 'value': 'kamen rider w'}, {'count': 1, 'value': 'related-akb48'}], 'gender': 'Female', 'name': 'Queen', 'id': 701492, 'area': 'Japan', 'sort_name': 'Queen', '_id': ObjectId('5a646bbfa6640c18353bb224'), 'ended': True, 'type': 'Character', 'gid': '420ca290-76c5-41af-999e-564d7c71f1a7'}
# {'rating': {'count': 24, 'value': 92}, 'sort_name': 'Queen', 'ended': True, 'gid': '0383dadf-2a4e-4d10-a46a-e9e041da8eb3', 'tags': [{'count': 2, 'value': 'hard rock'}, {'count': 1, 'value': '70s'}, {'count': 1, 'value': 'queen family'}, {'count': 1, 'value': '90s'}, {'count': 1, 'value': '80s'}, {'count': 1, 'value': 'glam rock'}, {'count': 4, 'value': 'british'}, {'count': 1, 'value': 'english'}, {'count': 2, 'value': 'uk'}, {'count': 1, 'value': 'pop/rock'}, {'count': 1, 'value': 'pop-rock'}, {'count': 1, 'value': 'britannique'}, {'count': 1, 'value': 'classic pop and rock'}, {'count': 1, 'value': 'queen'}, {'count': 1, 'value': 'united kingdom'}, {'count': 1, 'value': 'langham 1 studio bbc'}, {'count': 1, 'value': 'kind of magic'}, {'count': 1, 'value': 'band'}, {'count': 6, 'value': 'rock'}, {'count': 1, 'value': 'platinum'}], 'name': 'Queen', 'id': 192, 'area': 'United Kingdom', 'type': 'Group', '_id': ObjectId('5a646bcda6640c18353c78d0'), 'begin': {'month': 6, 'date': 27, 'year': 1970}, 'aliases': [{'name': '女王', 'sort_name': '女王'}]}
# {'name': 'Queen', 'id': 992994, 'sort_name': 'Queen', '_id': ObjectId('5a646beda6640c18353e3328'), 'ended': True, 'gid': '5eecaf18-02ec-47af-a4f2-7831db373419'}

# %%
cursor.count()
# Out:
# 3

# %% [markdown]
# ## 66. 検索件数の取得

# %% [markdown]
# in mongo shell
#
# ### search and count
# > db.artists.find({"area" : "Japan"}).count()
#
# 32975

# %% [markdown]
# ## 67. 複数のドキュメントの取得

# %%
cursol = artists.find({"aliases.name" : "Queen"})

for doc in cursol:
    print(doc)
# Out:
# {'aliases': [{'name': 'Queen', 'sort_name': 'Queen'}], 'tags': [{'count': 1, 'value': 'kamen rider w'}, {'count': 1, 'value': 'related-akb48'}], 'gender': 'Female', 'name': 'Queen', 'id': 701492, 'area': 'Japan', 'sort_name': 'Queen', '_id': ObjectId('5a646bbfa6640c18353bb224'), 'ended': True, 'type': 'Character', 'gid': '420ca290-76c5-41af-999e-564d7c71f1a7'}

# %% [markdown]
# ## 68. ソート

# %%
import pymongo
cursol = artists.find({"tags.value" : "dance"}).sort([("rating.count", pymongo.DESCENDING)])

for doc in cursol[:10]:
    print('{}\t{}'.format(doc['name'],  doc.get("rating")))
# Out:
# Madonna	{'count': 26, 'value': 88}
# Björk	{'count': 23, 'value': 84}
# The Prodigy	{'count': 23, 'value': 90}
# Rihanna	{'count': 15, 'value': 68}
# Britney Spears	{'count': 13, 'value': 83}
# Britney Spears	{'count': 13, 'value': 83}
# Britney Spears	{'count': 13, 'value': 83}
# Maroon 5	{'count': 11, 'value': 60}
# Adam Lambert	{'count': 7, 'value': 100}
# Adam Lambert	{'count': 7, 'value': 100}

# %% [markdown]
# ## 69. Webアプリケーションの作成

# %% [markdown]
# # 第8章: 機械学習
